# %%
import pandas as pd
import numpy as np

from ast import literal_eval                                  # 문자열 파싱 라이브러리
from sklearn.feature_extraction.text import CountVectorizer   # 
from sklearn.metrics.pairwise import cosine_similarity        # 코사인 유사도 라이브러리

import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# # 걍 한 번에 처리하기

# %%
def find_sim_beer_ver1(beer_data, sorted_ind, beer_name, top_n=3):
    
    beer_name = beer_data[beer_data['맥주이름'] == beer_name]
    
    beer_index = beer_name.index.values
    similar_indexes = sorted_ind[beer_index, :(top_n)]
    
    similar_inidexes = similar_indexes.reshape(-1)
    
    return beer_data.iloc[similar_inidexes]

# %%
# 데이터 가져오기(맥주 데이터)
beer_load = pd.read_csv('맥주이름_특징_tag_완료_최종.csv',encoding='utf-8', index_col=0)
rating = pd.read_csv('맥주_10.csv', encoding='utf-8', index_col=0)

# %%
# beer_rating: 맥주 종류별 평점평균
beer_rating = pd.DataFrame(columns=['맥주이름','평점평균','평가횟수'])
beer_rating['맥주이름'] = list(set(rating['맥주']))
beer_rating

# 평점평균 구하기
for beer in beer_rating['맥주이름']:
    temp = rating[beer==rating['맥주']]['평점'].mean()
    beer_rating['평점평균'][beer_rating['맥주이름']==beer]=temp
    
# 평가횟수 구하기
for beer in beer_rating['맥주이름']:
    temp = len(rating[beer==rating['맥주']])
    beer_rating['평가횟수'][beer_rating['맥주이름']==beer]=temp
    
# 총 데이터 합병
beer_data = pd.merge(beer_load, beer_rating)
    
# 데이터 준비 및 정재 list 형태로 바꿔주기 
# beer_data에서 총 6개의 feature(Aroma, Flavor, Balance, Season, Paring  Food, Body)를 가져온다 
beer_df = pd.DataFrame(beer_data, columns = ['Aroma','Flavor','Balance','Season','Paring Food', 'Body'])

# str형태에서 list로 변환
beer_df['Aroma'] = beer_df['Aroma'].apply(literal_eval)
beer_df['Flavor'] = beer_df['Flavor'].apply(literal_eval)
beer_df['Balance'] = beer_df['Balance'].apply(literal_eval)
beer_df['Season'] = beer_df['Season'].apply(literal_eval)
beer_df['Paring Food'] = beer_df['Paring Food'].apply(literal_eval)
beer_df['Body'] = beer_df['Body'].apply(literal_eval)

# %%
# ========================================= #
# 데이터 로드
beer_data = pd.read_csv('맥주_cbf_data.csv', encoding='utf-8')
beer_df = pd.read_csv('맥주_cbf_feature.csv', encoding='utf-8')

# str형태에서 list로 변환
beer_df['Aroma'] = beer_df['Aroma'].apply(literal_eval)
beer_df['Flavor'] = beer_df['Flavor'].apply(literal_eval)
beer_df['Balance'] = beer_df['Balance'].apply(literal_eval)
beer_df['Season'] = beer_df['Season'].apply(literal_eval)
beer_df['Paring Food'] = beer_df['Paring Food'].apply(literal_eval)
beer_df['Body'] = beer_df['Body'].apply(literal_eval)

# something = 'Aroma'
# something = 'Flavor'
# something = 'Balance'
# something = 'Paring Food'
something = 'Body'

# CountVectorizer를 활용하기 위한 전처리 
beer_df[something +'_literal'] = beer_df[something].apply(lambda x : (' ').join(x))

#CountVectorizer로 학습시키기
count_vect = CountVectorizer(min_df=0, ngram_range=(1,2))   # 특징 2개(ngram_range: 1<= n <=2)
something_mat = count_vect.fit_transform(beer_df[something + '_literal'])

# 77개의 맥주에 대한 가각 유사한 맥주들이 계산 됨
something_sim = cosine_similarity(something_mat,something_mat)

# 유사도 높은순으로 역순 배치 후 인덱스 추출
something_sim_sorted_ind = something_sim.argsort()[:, ::-1]

# 10개의 맥주 추천 결과
# Pilsner Urquel로 검색한 결과, 대체로 필스터 혹은 비슷한 성질을 가진 페일에일이 추천되는 것을 알 수 있다.

beer_name = 'Cass Fresh'

similar_beers = find_sim_beer_ver1(beer_data, something_sim_sorted_ind, beer_name, 4)

similar_beers = similar_beers[similar_beers['맥주이름'] != beer_name]

similar_beers
# Out:
#     Unnamed: 0  Unnamed: 0.1                    맥주이름  \
# 5            5             7           Stella Artois
# 27          27            31               Budweiser
# 0            0             0  Kloud Original Gravity
#
#                                    맥주스타일 Main Category  \
# 5   Pale Lager - International / Premium            라거
# 27                 Pale Lager - American            라거
# 0   Pale Lager - International / Premium            라거
#
#                                              Aroma  \
# 5   ['고소한 맥아향', '강한 향', '매운 향', '플로랄 홉향', '가벼운 향']
# 27                             ['고소한 맥아향', '강한 향']
# 0      ['고소한 맥아향', '강한 향', '빵 향', '달콤한 향', '풀잎 향']
#
#                                Flavor  Balance     Season  \
# 5   ['쓴 맛', '상쾌함', '약간의 단맛', '맥아 풍미']  ['미디엄']  ['연중 내내']
# 27                     ['쓴 맛', '상쾌함']  ['미디엄']  ['연중 내내']
# 0             ['쓴 맛', '상쾌함', '생강 힌트']  ['미디엄']  ['연중 내내']
#
#                 Paring Food                             Body      평점평균  평가횟수
# 5   ['생선 요리', '해산물', '샐러드']  ['드라이', '깔끔함', '가벼움', '적당한 탄산']  2.452250  1822
# 27  ['생선 요리', '해산물', '샐러드']  ['드라이', '깔끔함', '가벼움', '적당한 탄산']  1.486199  1739
# 0   ['생선 요리', '해산물', '샐러드']      ['드라이', '깔끔함', '가벼움', '탄산']  2.292500    80

# %%
tmp = beer_data[beer_data['맥주이름']==beer_name]
tmp
# Out:
#    Unnamed: 0  Unnamed: 0.1        맥주이름                                 맥주스타일  \
# 7           7            13  Cass Fresh  Pale Lager - International / Premium
#
#   Main Category                         Aroma  \
# 7            라거  ['고소한 맥아향', '강한 향', '가벼운 향']
#
#                                  Flavor  Balance     Season  \
# 7  ['쓴 맛', '상쾌함', '약간 단맛', '김치에 좋은 맥주']  ['미디엄']  ['연중 내내']
#
#                Paring Food                             Body     평점평균  평가횟수
# 7  ['생선 요리', '해산물', '샐러드']  ['드라이', '깔끔함', '가벼움', '적당한 탄산']  1.74823   226

# %%
result = ['Cass Fresh', 'A', 'B']

# %%
category=[], food=[], select=[]
for i in range(len(result)):
    category.append(beer_data[beer_data['맥주이름']==result[i]])
    select.

# %%
beer_data[beer_data['맥주이름']=='Cass Fresh']['Paring Food'].values[0]
# Out:
# "['생선 요리', '해산물', '샐러드']"

# %%
beer_data.맥주이름.unique()
# Out:
# array(['Kloud Original Gravity', 'Asahi Super Dry', 'Tsingtao',
#        'Heineken', 'Kirin Ichiban', 'Stella Artois', 'San Miguel',
#        'Cass Fresh', 'Victoria Bitter', 'Bintang Pilsener',
#        "Suntory The Premium Malt's", 'Tiger Beer', 'Sapporo Yebisu',
#        'Peroni Nastro Azzurro', 'Holsten Premium Bier',
#        'Lapin Kulta IV A', 'Grolsch Premium Lager',
#        'Castlemaine XXXX Gold Lager', 'Löwenbräu Original (4.2%)',
#        'Harbin Beer', "Beck's", 'Kloud Fitz Super Clear',
#        'OB Premier Pilsner', 'Hite D (Dry Finish)', 'Hite Prime Max',
#        'Hite Extra Cold', 'Miller Genuine Draft (MGD)', 'Budweiser',
#        'Stephans Bräu Premium Lager', 'Guinness Draught',
#        'Kronenbourg 1664 Blanc', 'Jeju Wit Ale', 'Pilsner Urquell',
#        'Gambrinus Originál 10° (Desítka)', 'Krombacher Weizen',
#        'Tsingtao Wheat Beer', 'Erdinger Weissbier',
#        'Paulaner Hefe-Weissbier', 'Edelweiss Weissbier Snowfresh',
#        'Stephans Bräu Hefe-Weizen Naturtrüb',
#        'Volfas Engelman Grünberger Hefeweizen', 'Tiger Radler Lemon',
#        'Egger Grapefruit Radler', 'Schöfferhofer Grapefruit',
#        'Reeper B. Exotisches IPA', 'Carlsberg Pilsner',
#        'Stephans Bräu Premium Pilsener', 'Eichbaum Apostel Bräu',
#        'Berliner Kindl Jubiläums Pilsener Premium',
#        'Warsteiner Premium Verum', 'Hoegaarden', 'Desperados',
#        'Heineken Dark Lager', 'Asahi Super Dry Black',
#        'Kozel Černý (Dark) 10°', 'Egger Märzenbier',
#        'Bavaria 8.6 (Original)', 'Hoegaarden Rosée', 'Red Rock',
#        'Erdinger Weissbier Dunkel'], dtype=object)

# %%
beer_data[beer_data['맥주이름']=='Edelweiss Weissbier Snowfresh']['Main Category'].values
# Out:
# array(['컨티넨털 에일/바이스비어/에일-라거하이브리드'], dtype=object)

# %%
beer_data[beer_data['맥주이름']=='Edelweiss Weissbier Snowfresh']['Paring Food'].values
# Out:
# array(["['샐러드', '해산물', '가벼운 음식', '바이스부르스트', '바나나 케이크', '바베큐 케이준', '저크 피시', '닭고기', '돼지고기', '애플 파이', '매운 음식', '태국 음식', '커리', '오믈렛', '에그 베네딕트', '베이컨', '달걀']"],
#       dtype=object)

# %%
category = similar_beers['Main Category'].tolist()

# %%
select = similar_beers['Flavor'].tolist()
select
# Out:
# ["['달콤한 맥아', '캐러멜', '사츠 홉의 풍미', '쌉쌀한 풍미', '쓴 맛', '섬세함']",
#  "['달콤한 맥아', '캐러멜', '사츠 홉의 풍미', '쌉쌀한 풍미', '쓴 맛', '섬세함', '단 맛', '빵 껍질']",
#  "['강한 쓴맛', '쓴 맛', '섬세함', '캐러멜', '단맛']"]

# %%
aroma = similar_beers['Aroma'].tolist()
aroma[2]
# Out:
# "['깔끔한 맥아향', '허브향', '민트향', '노블 홉향', '강한 향', '소나무향', '약한 빵 향']"

# %%
similar_beers['Main Category'].tolist()
# Out:
# ['라거', '라거', '라거']

# %%
result = similar_beers['맥주이름'].tolist()

# %%
result[0]
# Out:
# 'Gambrinus Originál 10° (Desítka)'

# %%
# 총 데이터 합병
beer_data = pd.merge(beer_load, beer_rating)
beer_data.tail(50)
# Out:
#     Unnamed: 0.1                                       맥주이름  \
# 10            24                 Suntory The Premium Malt's
# 11            27                                 Tiger Beer
# 12            33                             Sapporo Yebisu
# 13            36                      Peroni Nastro Azzurro
# 14            51                       Holsten Premium Bier
# 15            56                           Lapin Kulta IV A
# 16            57                      Grolsch Premium Lager
# 17            59                Castlemaine XXXX Gold Lager
# 18            61                  Löwenbräu Original (4.2%)
# 19            63                                Harbin Beer
# 20            64                                     Beck's
# 21             1                     Kloud Fitz Super Clear
# 22            12                         OB Premier Pilsner
# 23            15                        Hite D (Dry Finish)
# 24            16                             Hite Prime Max
# 25            17                            Hite Extra Cold
# 26            21                 Miller Genuine Draft (MGD)
# 27            31                                  Budweiser
# 28            45                Stephans Bräu Premium Lager
# 29             8                           Guinness Draught
# 30             9                     Kronenbourg 1664 Blanc
# 31            43                               Jeju Wit Ale
# 32            10                            Pilsner Urquell
# 33            58           Gambrinus Originál 10° (Desítka)
# 34            20                          Krombacher Weizen
# 35            28                        Tsingtao Wheat Beer
# 36            29                         Erdinger Weissbier
# 37            34                    Paulaner Hefe-Weissbier
# 38            37              Edelweiss Weissbier Snowfresh
# 39            46        Stephans Bräu Hefe-Weizen Naturtrüb
# 40            70      Volfas Engelman Grünberger Hefeweizen
# 41            23                         Tiger Radler Lemon
# 42            53                    Egger Grapefruit Radler
# 43            69                   Schöfferhofer Grapefruit
# 44            26                   Reeper B. Exotisches IPA
# 45            30                          Carlsberg Pilsner
# 46            44             Stephans Bräu Premium Pilsener
# 47            48                      Eichbaum Apostel Bräu
# 48            71  Berliner Kindl Jubiläums Pilsener Premium
# 49            75                   Warsteiner Premium Verum
# 50            32                                 Hoegaarden
# 51            35                                 Desperados
# 52            38                        Heineken Dark Lager
# 53            62                      Asahi Super Dry Black
# 54            39                     Kozel Černý (Dark) 10°
# 55            50                           Egger Märzenbier
# 56            55                     Bavaria 8.6 (Original)
# 57            65                           Hoegaarden Rosée
# 58            73                                   Red Rock
# 59            74                  Erdinger Weissbier Dunkel
#
#                                    맥주스타일             Main Category  \
# 10  Pale Lager - International / Premium                        라거
# 11  Pale Lager - International / Premium                        라거
# 12  Pale Lager - International / Premium                        라거
# 13  Pale Lager - International / Premium                        라거
# 14  Pale Lager - International / Premium                        라거
# 15  Pale Lager - International / Premium                        라거
# 16  Pale Lager - International / Premium                        라거
# 17  Pale Lager - International / Premium                        라거
# 18  Pale Lager - International / Premium                        라거
# 19  Pale Lager - International / Premium                        라거
# 20  Pale Lager - International / Premium                        라거
# 21                 Pale Lager - American                        라거
# 22                 Pale Lager - American                        라거
# 23                 Pale Lager - American                        라거
# 24                 Pale Lager - American                        라거
# 25                 Pale Lager - American                        라거
# 26                 Pale Lager - American                        라거
# 27                 Pale Lager - American                        라거
# 28                 Pale Lager - American                        라거
# 29                   Stout - Dry / Irish                영국-아일랜드 에일
# 30           Witbier / Belgian White Ale  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 31           Witbier / Belgian White Ale  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 32           Pilsener - Bohemian / Czech                        라거
# 33           Pilsener - Bohemian / Czech                        라거
# 34                Weissbier - Hefeweizen  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 35                Weissbier - Hefeweizen  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 36                Weissbier - Hefeweizen  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 37                Weissbier - Hefeweizen  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 38                Weissbier - Hefeweizen  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 39                Weissbier - Hefeweizen  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 40                Weissbier - Hefeweizen  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 41                       Radler / Shandy                미국-크래프트 맥주
# 42                       Radler / Shandy                미국-크래프트 맥주
# 43                       Radler / Shandy                미국-크래프트 맥주
# 44                                   IPA                미국-크래프트 맥주
# 45             Pilsener / Pils / Pilsner                        라거
# 46             Pilsener / Pils / Pilsner                        라거
# 47             Pilsener / Pils / Pilsner                        라거
# 48             Pilsener / Pils / Pilsner                        라거
# 49             Pilsener / Pils / Pilsner                        라거
# 50                             Wheat Ale                    벨기에 맥주
# 51                      Flavored - Other                        기타
# 52  Dark Lager - International / Premium                        라거
# 53  Dark Lager - International / Premium                        라거
# 54           Dark Lager - Dunkel / Tmavý                        라거
# 55             Märzen / Oktoberfest Bier                        라거
# 56                   Pilsener - Imperial                        라거
# 57                      Flavored - Fruit                미국-크래프트 맥주
# 58  Amber Lager - International / Vienna                        라거
# 59              Weissbier - Dunkelweizen  컨티넨털 에일/바이스비어/에일-라거하이브리드
#
#                                                 Aroma  \
# 10                      ['고소한 맥아향', '강한 향', '거친 맥아향']
# 11                     ['고소한 맥아향', '강한 향', '달콤한 맥아향']
# 12                     ['고소한 맥아향', '강한 향', '달콤한 맥아향']
# 13               ['고소한 맥아향', '강한 향', '스컹크 향', '풀잎 향']
# 14                                ['고소한 맥아향', '강한 향']
# 15  ['고소한 맥아향', '강한 향', '약한 향', '약한 스컹스 향', '약한 과일향']
# 16     ['고소한 맥아향', '강한 향', '풀잎 향', '쿠키향', '약한 스컹크 향']
# 17                         ['고소한 맥아향', '강한 향', '과일향']
# 18             ['고소한 맥아향', '강한 향', '달콤한 맥아향', '꽃 향기']
# 19                       ['고소한 맥아향', '강한 향', '옥수수 향']
# 20             ['고소한 맥아향', '강한 향', '캐러멜향', '창백한 맥아향']
# 21                                ['고소한 맥아향', '강한 향']
# 22                                ['고소한 맥아향', '강한 향']
# 23              ['고소한 맥아향', '강한 향', '달콤한 맥아향', '풀잎향']
# 24                         ['고소한 맥아향', '강한 향', '풀잎향']
# 25                                ['고소한 맥아향', '강한 향']
# 26         ['고소한 맥아향', '강한 향', '옥수수 향', '약한 캐라멜 멕아향']
# 27                                ['고소한 맥아향', '강한 향']
# 28              ['고소한 맥아향', '강한 향', '꽃향기', '달콤한 맥아향']
# 29        ['로스팅 보리향', '커피향', '홉 아로마 거의 없음', '약한 빵 향']
# 30                  ['스파이시한 효모향', '오렌지', '고수', '과일향']
# 31        ['스파이시한 효모향', '오렌지', '고수', '순한 고수향', '밀 향']
# 32  ["'깔끔한 맥아향', '사츠홉향','스파이시한 향','허브향'", '약한 빵 향'...
# 33              ["'깔끔한 맥아향', '사츠홉향','스파이시한 향','허브향'"]
# 34                      ['과일향', '스파이시한 향', '은은한 맥아향']
# 35             ['과일향', '스파이시한 향', '은은한 맥아향', '바나나 향']
# 36              ['과일향', '스파이시한 향', '은은한 맥아향', '바나나향']
# 37                      ['과일향', '스파이시한 향', '은은한 맥아향']
# 38                      ['과일향', '스파이시한 향', '은은한 맥아향']
# 39                      ['과일향', '스파이시한 향', '은은한 맥아향']
# 40                      ['과일향', '스파이시한 향', '은은한 맥아향']
# 41                                     ['과일향', '레몬향']
# 42                                      ['과일향', '단맛']
# 43                                     ['과일향', '자몽향']
# 44                               ['과일향', '홉향', '맥아향']
# 45          ['깔끔한 맥아향', '허브향', '민트향', '노블 홉향', '후추향']
# 46      ['깔끔한 맥아향', '허브향', '민트향', '노블 홉향', '가벼운 곡물향']
# 47      ['깔끔한 맥아향', '허브향', '민트향', '노블 홉향', '약간의 과일향']
# 48       ['깔끔한 맥아향', '허브향', '민트향', '노블 홉향', '약한 빵 향']
# 49                 ['깔끔한 맥아향', '허브향', '민트향', '노블 홉향']
# 50                                 ['과일향', '스파이시한 향']
# 51                                   ['캐러멜 향', '허브향']
# 52        ['맥아향', '초콜렛 향', '캐러멜 향', '맥아향', '멕아 로스팅향']
# 53                          ['맥아향', '초콜렛 향', '캐러멜 향']
# 54                           ['맥아향', '초콜렛 향', '카라멜향']
# 55          ['고소한 맥아향', '캐러멜향', '쿠키향', '홉 아로마 거의 없음']
# 56  ['깔끔한 맥아향', '허브향', '민트향', '노블 홉향', '강한 향', '소나...
# 57                                   ['과일향', '라즈베리향']
# 58                ['과일향', '고소한 맥아향', '약한 빵 향', '허브향']
# 59                         ['과일향', '스파이시한 향', '캐러멜향']
#
#                                                Flavor  \
# 10                                     ['쓴 맛', '상쾌함']
# 11                           ['쓴 맛', '상쾌함', '옥수수 단맛']
# 12                            ['쓴 맛', '상쾌함', '약한 단맛']
# 13                                     ['쓴 맛', '상쾌함']
# 14                              ['쓴 맛', '상쾌함', '단 맛']
# 15                                     ['쓴 맛', '상쾌함']
# 16                                     ['쓴 맛', '상쾌함']
# 17                                     ['쓴 맛', '상쾌함']
# 18                     ['쓴 맛', '상쾌함', '단 맛', '옥수수 맛']
# 19                              ['쓴 맛', '상쾌함', '단 맛']
# 20                              ['쓴 맛', '상쾌함', '캐러멜']
# 21                                     ['쓴 맛', '상쾌함']
# 22                              ['쓴 맛', '상쾌함', '단 맛']
# 23                 ['쓴 맛', '상쾌함', '약한 단맛', '약한 떫은 맛']
# 24                                     ['쓴 맛', '상쾌함']
# 25               ['쓴 맛', '상쾌함', '옅은 옥수수 향', '옅은 맥아향']
# 26                              ['쓴 맛', '상쾌함', '캐러멜']
# 27                                     ['쓴 맛', '상쾌함']
# 28                            ['쓴 맛', '상쾌함', '약한 단맛']
# 29                           ['쓴 맛', '약간 크리미', '초콜렛']
# 30            ['드라이한 크림 풍미', '부드러움', '시큼한 끝맛', '사과맛']
# 31                   ['드라이한 크림 풍미', '부드러움', '시큼한 끝맛']
# 32  ['달콤한 맥아', '캐러멜', '사츠 홉의 풍미', '쌉쌀한 풍미', '쓴 맛',...
# 33  ['달콤한 맥아', '캐러멜', '사츠 홉의 풍미', '쌉쌀한 풍미', '쓴 맛',...
# 34  ['밀크세이크 질감', '가벼운 곡물 풍미', '홉의 풍미 많지 않음', '고도의 ...
# 35  ['밀크세이크 질감', '가벼운 곡물 풍미', '홉의 풍미 많지 않음', '고도의 ...
# 36  ['밀크세이크 질감', '가벼운 곡물 풍미', '홉의 풍미 많지 않음', '고도의 ...
# 37  ['밀크세이크 질감', '가벼운 곡물 풍미', '홉의 풍미 많지 않음', '고도의 ...
# 38  ['밀크세이크 질감', '가벼운 곡물 풍미', '홉의 풍미 많지 않음', '고도의 ...
# 39  ['밀크세이크 질감', '가벼운 곡물 풍미', '홉의 풍미 많지 않음', '고도의 ...
# 40  ['밀크세이크 질감', '가벼운 곡물 풍미', '홉의 풍미 많지 않음', '고도의 ...
# 41                     ['낮은 알코올', '탄산수', '단맛', '달콤함']
# 42                                  ['낮은 알코올', '탄산수']
# 43                            ['낮은 알코올', '탄산수', '신맛']
# 44  ['깔끔한 맥아 풍미', '캐러멜', '깔끔함', '청량함', '쌉쌀한 끝맛', '...
# 45  ['청량함', '매끄러운 맥아 풍미', '허브 풍미', '할러타우 홉', '견고한 ...
# 46  ['청량함', '매끄러운 맥아 풍미', '허브 풍미', '할러타우 홉', '견고한 ...
# 47  ['청량함', '매끄러운 맥아 풍미', '허브 풍미', '할러타우 홉', '견고한 ...
# 48  ['청량함', '매끄러운 맥아 풍미', '허브 풍미', '할러타우 홉', '견고한 ...
# 49  ['청량함', '매끄러운 맥아 풍미', '허브 풍미', '할러타우 홉', '견고한 ...
# 50  ['밀크세이크 질감', '가벼운 곡물 풍미', '홉의 풍미 많지 않음', '고도의 ...
# 51                              ['데킬라맛', '단맛', '달콤함']
# 52  ['구운 풍미', '쌉쌀한 풍미', '섬세한', '캐러멜', '부드러움', '약한 ...
# 53  ['구운 풍미', '쌉쌀한 풍미', '섬세한', '캐러멜', '부드러움', '약한 ...
# 54  ['구운 풍미', '쌉쌀한 풍미', '섬세한', '캐러멜', '초콜릿', '빵 껍질...
# 55                     ['캐러멜', '달콤한 쿠기 풍미', '약간 쌉쌀함']
# 56               ['강한 쓴맛', '쓴 맛', '섬세함', '캐러멜', '단맛']
# 57                 ['과일 풍미', '시큼한 풍미', '크리미함', '달콤함']
# 58        ['구운 풍미', '쓴 맛', '견과류 맥아 풍미', '가벼움', '단 맛']
# 59  ['밀크세이크 질감', '가벼운 곡물 풍미', '홉의 풍미 많지 않음', '고도의 ...
#
#                                           Balance  \
# 10                                        ['미디엄']
# 11                     ['미디엄', '홉에 의한 밸런스 거의 없음']
# 12                                        ['미디엄']
# 13                                        ['미디엄']
# 14                                 ['미디엄', '크리미']
# 15                                        ['미디엄']
# 16                                 ['미디엄', '크리미']
# 17                                        ['미디엄']
# 18                                 ['미디엄', '크리미']
# 19                                        ['미디엄']
# 20                                 ['미디엄', '상쾌함']
# 21                                        ['미디엄']
# 22                                        ['미디엄']
# 23                                        ['미디엄']
# 24                                        ['미디엄']
# 25                                 ['미디엄', '단 맛']
# 26                                        ['미디엄']
# 27                                        ['미디엄']
# 28                                        ['미디엄']
# 29                              ['매우 드라이', '청량함']
# 30           ['밀크셰이크 질감', '드라이', '약간 시큼함', '크리미']
# 31                  ['밀크셰이크 질감', '드라이', '약간 시큼함']
# 32                            ['홉의 풍미', '쌉쌀한 끝맛']
# 33                            ['홉의 풍미', '쌉쌀한 끝맛']
# 34         ['드라이', '맥아 풍미', '곡물 풍미', '리치', '크리미']
# 35         ['드라이', '맥아 풍미', '곡물 풍미', '리치', '크리미']
# 36         ['드라이', '맥아 풍미', '곡물 풍미', '리치', '크리미']
# 37  ['드라이', '맥아 풍미', '곡물 풍미', '리치', '크리미', '크리미']
# 38         ['드라이', '맥아 풍미', '곡물 풍미', '리치', '크리미']
# 39         ['드라이', '맥아 풍미', '곡물 풍미', '리치', '크리미']
# 40         ['드라이', '맥아 풍미', '곡물 풍미', '리치', '크리미']
# 41                                             []
# 42                                             []
# 43                                             []
# 44                ['미디엄', '청량함', '쌉쌀한 끝맛', '크리미']
# 45                  ['균형', '드라이', '비터', '깔끔한 끝맛']
# 46                  ['균형', '드라이', '비터', '깔끔한 끝맛']
# 47           ['균형', '드라이', '비터', '깔끔한 끝맛', '크리미']
# 48                  ['균형', '드라이', '비터', '깔끔한 끝맛']
# 49                  ['균형', '드라이', '비터', '깔끔한 끝맛']
# 50         ['드라이', '맥아 풍미', '곡물 풍미', '리치', '크리미']
# 51                                             []
# 52                                      ['맥아 풍미']
# 53                                      ['맥아 풍미']
# 54                                 ['균형', '부드러움']
# 55                   ['맥아 풍미', '홉에 의한 밸런스 거의 없음']
# 56                  ['균형', '드라이', '비터', '깔끔한 끝맛']
# 57           ['청량함', '드라이', '약간 달콤', '일정 수준의 신맛']
# 58                                        ['청럄함']
# 59         ['드라이', '맥아 풍미', '곡물 풍미', '리치', '크리미']
#
#                              Season  \
# 10                        ['연중 내내']
# 11                        ['연중 내내']
# 12                        ['연중 내내']
# 13                        ['연중 내내']
# 14                        ['연중 내내']
# 15                        ['연중 내내']
# 16                        ['연중 내내']
# 17                        ['연중 내내']
# 18                   ['연중 내내', '봄']
# 19                        ['연중 내내']
# 20                        ['연중 내내']
# 21                        ['연중 내내']
# 22                        ['연중 내내']
# 23                        ['연중 내내']
# 24                        ['연중 내내']
# 25                        ['연중 내내']
# 26                        ['연중 내내']
# 27                        ['연중 내내']
# 28                        ['연중 내내']
# 29                        ['연중 내내']
# 30              ['연중 내내', '따뜻한 날씨']
# 31              ['연중 내내', '따뜻한 날씨']
# 32                        ['연중 내내']
# 33                        ['연중 내내']
# 34                  ['연중 내내', '여름']
# 35                  ['연중 내내', '여름']
# 36                  ['연중 내내', '여름']
# 37                  ['연중 내내', '여름']
# 38                  ['연중 내내', '여름']
# 39                  ['연중 내내', '여름']
# 40                  ['연중 내내', '여름']
# 41                        ['연중 내내']
# 42                        ['연중 내내']
# 43                        ['연중 내내']
# 44                        ['연중 내내']
# 45              ['연중 내내', '따듯한 날씨']
# 46              ['연중 내내', '따듯한 날씨']
# 47              ['연중 내내', '따듯한 날씨']
# 48              ['연중 내내', '따듯한 날씨']
# 49              ['연중 내내', '따듯한 날씨']
# 50                  ['연중 내내', '여름']
# 51                               []
# 52  ['견과류', '기름진 음식', '파자', '마른안주']
# 53  ['견과류', '기름진 음식', '파자', '마른안주']
# 54                        ['연중 내내']
# 55            ['9월', '10월', '연중내내']
# 56              ['연중 내내', '따듯한 날씨']
# 57                        ['연중 내내']
# 58                        ['연중 내내']
# 59                  ['연중 내내', '여름']
#
#                                           Paring Food  \
# 10                            ['생선 요리', '해산물', '샐러드']
# 11                  ['생선 요리', '해산물', '샐러드', '아시아 음식']
# 12                            ['생선 요리', '해산물', '샐러드']
# 13                            ['생선 요리', '해산물', '샐러드']
# 14                            ['생선 요리', '해산물', '샐러드']
# 15                            ['생선 요리', '해산물', '샐러드']
# 16                            ['생선 요리', '해산물', '샐러드']
# 17                            ['생선 요리', '해산물', '샐러드']
# 18                            ['생선 요리', '해산물', '샐러드']
# 19                            ['생선 요리', '해산물', '샐러드']
# 20                            ['생선 요리', '해산물', '샐러드']
# 21                            ['생선 요리', '해산물', '샐러드']
# 22         ['생선 요리', '해산물', '샐러드', '매운 음식', '무거운 음식']
# 23                            ['생선 요리', '해산물', '샐러드']
# 24                            ['생선 요리', '해산물', '샐러드']
# 25                            ['생선 요리', '해산물', '샐러드']
# 26                            ['생선 요리', '해산물', '샐러드']
# 27                            ['생선 요리', '해산물', '샐러드']
# 28                            ['생선 요리', '해산물', '샐러드']
# 29  ['스테이크', '고기 파이', '리치한 음식', '든든한 음식', '굴', '초콜릿']
# 30                        ['홍합', '연어', '닭', '가벼운 음식']
# 31                        ['홍합', '연어', '닭', '가벼운 음식']
# 32  ['닭', '샐러드', '연어', '가벼운 음식', '알싸한 쓴 음식', '기름기 ...
# 33  ['닭', '샐러드', '연어', '가벼운 음식', '알싸한 쓴 음식', '기름기 ...
# 34  ['샐러드', '해산물', '가벼운 음식', '바이스부르스트', '바나나 케이크',...
# 35  ['샐러드', '해산물', '가벼운 음식', '바이스부르스트', '바나나 케이크',...
# 36  ['샐러드', '해산물', '가벼운 음식', '바이스부르스트', '바나나 케이크',...
# 37  ['샐러드', '해산물', '가벼운 음식', '바이스부르스트', '바나나 케이크',...
# 38  ['샐러드', '해산물', '가벼운 음식', '바이스부르스트', '바나나 케이크',...
# 39  ['샐러드', '해산물', '가벼운 음식', '바이스부르스트', '바나나 케이크',...
# 40  ['샐러드', '해산물', '가벼운 음식', '바이스부르스트', '바나나 케이크',...
# 41                                              ['빵']
# 42                                              ['빵']
# 43                                              ['빵']
# 44  ['여러 광범위한 음식', '버거', '체다 치즈', '스테이크', '프렌치프라이'...
# 45  ['샐러드', '해산물 요리', '브라트부르스트', '가벼운 음식', '후추', '...
# 46  ['샐러드', '해산물 요리', '브라트부르스트', '가벼운 음식', '후추', '...
# 47  ['샐러드', '해산물 요리', '브라트부르스트', '가벼운 음식', '후추', '...
# 48  ['샐러드', '해산물 요리', '브라트부르스트', '가벼운 음식', '후추', '...
# 49  ['샐러드', '해산물 요리', '브라트부르스트', '가벼운 음식', '후추', '...
# 50                ['샐러드', '해산물', '가벼운 음식', '바이스부르스트']
# 51                                                 []
# 52  ['돼지고기 구이', '오리 구이', '연어 구이', '소시지', '케이준 생선',...
# 53  ['돼지고기 구이', '오리 구이', '연어 구이', '소시지', '케이준 생선',...
# 54  ['돼지고기 구이', '오리 구이', '연어 구이', '소시지', '케이준 생선',...
# 55          ['멕시코 요리', '매운 요리', '닭', '소시지', '마일드 치즈']
# 56  ['샐러드', '해산물 요리', '브라트부르스트', '가벼운 음식', '후추', '...
# 57                       ['샐러드', '가벼운 음식', '가벼운 디저트']
# 58  ['구운 붉은 고기', '바비큐 고기', '햄', '고구마 튀김', '살코기 생선'...
# 59                ['샐러드', '해산물', '가벼운 음식', '바이스부르스트']
#
#                                        Body     평점평균  평가횟수
# 10                 ['드라이', '깔끔함', '적당한 탄산']  2.65205   146
# 11                 ['드라이', '깔끔함', '적당한 탄산']  2.11764  1253
# 12                ['드라이', '깔끔함', '적당한 탄산화']  2.47789   285
# 13                    ['드라이', '깔끔함', '가벼움']  2.16743  1182
# 14                           ['드라이', '깔끔함']  2.33961   361
# 15                    ['드라이', '깔끔함', '가벼움']  2.20375   320
# 16                ['드라이', '깔끔함', '적당한 탄산화']  2.51545  1469
# 17                           ['드라이', '깔끔함']  1.83333   129
# 18                    ['드라이', '깔끔함', '가벼움']  1.95909    22
# 19                  ['드라이', '깔끔함', '많은 탄산']  2.02442   258
# 20           ['드라이', '깔끔함', '가벼움', '적은 탄산']  2.30972  1564
# 21                           ['드라이', '깔끔함']  1.76667    21
# 22                     ['드라이', '깔끔함', '탄산']  2.18571    49
# 23                           ['드라이', '깔끔함']  1.99423    52
# 24                           ['드라이', '깔끔함']  1.87579    95
# 25                           ['드라이', '깔끔함']  2.11081    37
# 26                           ['드라이', '깔끔함']  1.54985  1350
# 27          ['드라이', '깔끔함', '가벼움', '적당한 탄산']   1.4862  1739
# 28          ['드라이', '깔끔함', '가벼움', '풍부한 탄산']  2.04615    39
# 29               ['드라이', '가벼운 탄산화', '부드러움']   3.3069  2100
# 30          ['드라이', '미디엄', '매우 크리미', '크리미']  2.69866   674
# 31          ['드라이', '미디엄', '매우 크리미', '크리미']  2.87857    14
# 32              ['미디엄', '깔끔함', '탄산', '가벼움']  3.24791  2077
# 33              ['미디엄', '깔끔함', '탄산', '가벼움']  2.51777   332
# 34                     ['걸쭉', '드라이', '가벼움']  3.13954   526
# 35              ['걸쭉', '드라이', '미디엄', '상쾌함']    2.824    25
# 36                   ['걸쭉', '드라이', '많은 탄산']  3.10871  1630
# 37                            ['걸쭉', '드라이']  3.55755  1807
# 38                            ['걸쭉', '드라이']  3.22254   284
# 39                     ['걸쭉', '드라이', '가벼움']  2.60625    80
# 40                            ['걸쭉', '드라이']     3.06    10
# 41                     ['탄산', '가벼움', '깔끔함']     2.01    20
# 42                        ['탄산', '불쾌한 탄산화']  2.32889    45
# 43                                   ['탄산']   2.7752   492
# 44                           ['청량함', '드라이']   2.4375    16
# 45             ['청량함', '드라이', '가벼움', '깔끔함']  2.20463  1232
# 46  ['청량함', '드라이', '가벼움', '깔끔함', '적절한 탄산화']  2.08491    53
# 47             ['청량함', '드라이', '가벼움', '깔끔함']  2.45303   132
# 48             ['청량함', '드라이', '가벼움', '깔끔함']   2.6291   244
# 49             ['청량함', '드라이', '가벼움', '깔끔함']  2.68616  1582
# 50                     ['걸쭉', '드라이', '가벼움']  3.46274  2048
# 51                                       []  1.69048   630
# 52                           ['미디엄', '가벼움']  2.65792   404
# 53                           ['미디엄', '가벼움']  2.62525    99
# 54                           ['가벼움', '미디움']  3.00755   728
# 55                                  ['미디엄']  2.52025   158
# 56                     ['깔끔함', '탄산', '가벼움']  2.17543   293
# 57                           ['라이트', '미디엄']  2.47854   466
# 58                                  ['가벼움']  1.78571    14
# 59                            ['걸쭉', '드라이']  3.20258  1354

# %%
beer_load.tail(50)
# Out:
#     Unnamed: 0.1                                               맥주이름  \
# 27            16                                     Hite Prime Max
# 28            17                                    Hite Extra Cold
# 29            21                         Miller Genuine Draft (MGD)
# 30            31                                          Budweiser
# 31            41                                             FiLite
# 32            45                        Stephans Bräu Premium Lager
# 33             8                                   Guinness Draught
# 34             9                             Kronenbourg 1664 Blanc
# 35            43                                       Jeju Wit Ale
# 36            66                                 Platinum White Ale
# 37            10                                    Pilsner Urquell
# 38            58                   Gambrinus Originál 10° (Desítka)
# 39            14                                              Stout
# 40            20                                  Krombacher Weizen
# 41            25                        Reeper B. Blondes Weissbier
# 42            28                                Tsingtao Wheat Beer
# 43            29                                 Erdinger Weissbier
# 44            34                            Paulaner Hefe-Weissbier
# 45            37                      Edelweiss Weissbier Snowfresh
# 46            46                Stephans Bräu Hefe-Weizen Naturtrüb
# 47            52  Franziskaner Hefe-Weissbier / Weissbier Naturtrub
# 48            70              Volfas Engelman Grünberger Hefeweizen
# 49            22                                  Hoegaarden Cherry
# 50            23                                 Tiger Radler Lemon
# 51            53                            Egger Grapefruit Radler
# 52            69                           Schöfferhofer Grapefruit
# 53            26                           Reeper B. Exotisches IPA
# 54            30                                  Carlsberg Pilsner
# 55            44                     Stephans Bräu Premium Pilsener
# 56            48                              Eichbaum Apostel Bräu
# 57            71          Berliner Kindl Jubiläums Pilsener Premium
# 58            75                           Warsteiner Premium Verum
# 59            32                                         Hoegaarden
# 60            35                                         Desperados
# 61            38                                Heineken Dark Lager
# 62            62                              Asahi Super Dry Black
# 63            39                             Kozel Černý (Dark) 10°
# 64            40                Guinness Original 4.2% (Ireland/UK)
# 65            42                                   ARK Seoulite Ale
# 66            67                                  Platinum Pale Ale
# 67            49                                       Egger Zwickl
# 68            50                                   Egger Märzenbier
# 69            55                             Bavaria 8.6 (Original)
# 70            60                        Leffe Brune / Bruin / Brown
# 71            65                                   Hoegaarden Rosée
# 72            72                         Burge Meester Shandy Lemon
# 73            68     Mallaskosken Kuohu Amber Lager Special Edition
# 74            73                                           Red Rock
# 75            74                          Erdinger Weissbier Dunkel
# 76            76                            Queen's Ale Blonde Type
#
#                                    맥주스타일             Main Category  \
# 27                 Pale Lager - American                        라거
# 28                 Pale Lager - American                        라거
# 29                 Pale Lager - American                        라거
# 30                 Pale Lager - American                        라거
# 31                 Pale Lager - American                        라거
# 32                 Pale Lager - American                        라거
# 33                   Stout - Dry / Irish                영국-아일랜드 에일
# 34           Witbier / Belgian White Ale  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 35           Witbier / Belgian White Ale  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 36           Witbier / Belgian White Ale  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 37           Pilsener - Bohemian / Czech                        라거
# 38           Pilsener - Bohemian / Czech                        라거
# 39                                Porter                영국-아일랜드 에일
# 40                Weissbier - Hefeweizen  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 41                Weissbier - Hefeweizen  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 42                Weissbier - Hefeweizen  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 43                Weissbier - Hefeweizen  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 44                Weissbier - Hefeweizen  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 45                Weissbier - Hefeweizen  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 46                Weissbier - Hefeweizen  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 47                Weissbier - Hefeweizen  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 48                Weissbier - Hefeweizen  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 49                       Radler / Shandy                미국-크래프트 맥주
# 50                       Radler / Shandy                미국-크래프트 맥주
# 51                       Radler / Shandy                미국-크래프트 맥주
# 52                       Radler / Shandy                미국-크래프트 맥주
# 53                                   IPA                미국-크래프트 맥주
# 54             Pilsener / Pils / Pilsner                        라거
# 55             Pilsener / Pils / Pilsner                        라거
# 56             Pilsener / Pils / Pilsner                        라거
# 57             Pilsener / Pils / Pilsner                        라거
# 58             Pilsener / Pils / Pilsner                        라거
# 59                             Wheat Ale                    벨기에 맥주
# 60                      Flavored - Other                        기타
# 61  Dark Lager - International / Premium                        라거
# 62  Dark Lager - International / Premium                        라거
# 63           Dark Lager - Dunkel / Tmavý                        라거
# 64                                 Stout                영국-아일랜드 에일
# 65             Pale Ale - American (APA)                미국-크래프트 맥주
# 66             Pale Ale - American (APA)                미국-크래프트 맥주
# 67   Zwickelbier / Kellerbier / Landbier                        라거
# 68             Märzen / Oktoberfest Bier                        라거
# 69                   Pilsener - Imperial                        라거
# 70            Belgian Ale - Dark / Amber                미국-크래프트 맥주
# 71                      Flavored - Fruit                미국-크래프트 맥주
# 72                      Flavored - Fruit                미국-크래프트 맥주
# 73  Amber Lager - International / Vienna                        라거
# 74  Amber Lager - International / Vienna                        라거
# 75              Weissbier - Dunkelweizen  컨티넨털 에일/바이스비어/에일-라거하이브리드
# 76                    Pale Ale - English                영국-아일랜드 에일
#
#                                                 Aroma  \
# 27                         ['고소한 맥아향', '강한 향', '풀잎향']
# 28                                ['고소한 맥아향', '강한 향']
# 29         ['고소한 맥아향', '강한 향', '옥수수 향', '약한 캐라멜 멕아향']
# 30                                ['고소한 맥아향', '강한 향']
# 31                                ['고소한 맥아향', '강한 향']
# 32              ['고소한 맥아향', '강한 향', '꽃향기', '달콤한 맥아향']
# 33        ['로스팅 보리향', '커피향', '홉 아로마 거의 없음', '약한 빵 향']
# 34                  ['스파이시한 효모향', '오렌지', '고수', '과일향']
# 35        ['스파이시한 효모향', '오렌지', '고수', '순한 고수향', '밀 향']
# 36                         ['스파이시한 효모향', '오렌지', '고수']
# 37  ["'깔끔한 맥아향', '사츠홉향','스파이시한 향','허브향'", '약한 빵 향'...
# 38              ["'깔끔한 맥아향', '사츠홉향','스파이시한 향','허브향'"]
# 39         ['맥아 로스팅향', '홉 아로마 거의 없음', '초콜렛 향', '커피향']
# 40                      ['과일향', '스파이시한 향', '은은한 맥아향']
# 41                      ['과일향', '스파이시한 향', '은은한 맥아향']
# 42             ['과일향', '스파이시한 향', '은은한 맥아향', '바나나 향']
# 43              ['과일향', '스파이시한 향', '은은한 맥아향', '바나나향']
# 44                      ['과일향', '스파이시한 향', '은은한 맥아향']
# 45                      ['과일향', '스파이시한 향', '은은한 맥아향']
# 46                      ['과일향', '스파이시한 향', '은은한 맥아향']
# 47             ['과일향', '스파이시한 향', '은은한 맥아향', '바나나 향']
# 48                      ['과일향', '스파이시한 향', '은은한 맥아향']
# 49                                            ['과일향']
# 50                                     ['과일향', '레몬향']
# 51                                      ['과일향', '단맛']
# 52                                     ['과일향', '자몽향']
# 53                               ['과일향', '홉향', '맥아향']
# 54          ['깔끔한 맥아향', '허브향', '민트향', '노블 홉향', '후추향']
# 55      ['깔끔한 맥아향', '허브향', '민트향', '노블 홉향', '가벼운 곡물향']
# 56      ['깔끔한 맥아향', '허브향', '민트향', '노블 홉향', '약간의 과일향']
# 57       ['깔끔한 맥아향', '허브향', '민트향', '노블 홉향', '약한 빵 향']
# 58                 ['깔끔한 맥아향', '허브향', '민트향', '노블 홉향']
# 59                                 ['과일향', '스파이시한 향']
# 60                                   ['캐러멜 향', '허브향']
# 61        ['맥아향', '초콜렛 향', '캐러멜 향', '맥아향', '멕아 로스팅향']
# 62                          ['맥아향', '초콜렛 향', '캐러멜 향']
# 63                           ['맥아향', '초콜렛 향', '카라멜향']
# 64                 ['볶은 맥아향', '홉 아로마 거의 없음', '달콤한 향']
# 65                            ['맥아향', '과일향', '북미 홉향']
# 66                            ['맥아향', '과일향', '북미 홉향']
# 67                                            ['과일향']
# 68          ['고소한 맥아향', '캐러멜향', '쿠키향', '홉 아로마 거의 없음']
# 69  ['깔끔한 맥아향', '허브향', '민트향', '노블 홉향', '강한 향', '소나...
# 70              ['약한 빵 향', '과일향', '스파이시한 향', '카라멜 향']
# 71                                   ['과일향', '라즈베리향']
# 72                                            ['과일향']
# 73                ['과일향', '고소한 맥아향', '약한 빵 향', '허브향']
# 74                ['과일향', '고소한 맥아향', '약한 빵 향', '허브향']
# 75                         ['과일향', '스파이시한 향', '캐러멜향']
# 76                   ['깔끔한 맥아향', '풀향', '허브향', '카라멜향']
#
#                                                Flavor  \
# 27                                     ['쓴 맛', '상쾌함']
# 28               ['쓴 맛', '상쾌함', '옅은 옥수수 향', '옅은 맥아향']
# 29                              ['쓴 맛', '상쾌함', '캐러멜']
# 30                                     ['쓴 맛', '상쾌함']
# 31                              ['쓴 맛', '상쾌함', '역겨움']
# 32                            ['쓴 맛', '상쾌함', '약한 단맛']
# 33                           ['쓴 맛', '약간 크리미', '초콜렛']
# 34            ['드라이한 크림 풍미', '부드러움', '시큼한 끝맛', '사과맛']
# 35                   ['드라이한 크림 풍미', '부드러움', '시큼한 끝맛']
# 36                   ['드라이한 크림 풍미', '부드러움', '시큼한 끝맛']
# 37  ['달콤한 맥아', '캐러멜', '사츠 홉의 풍미', '쌉쌀한 풍미', '쓴 맛',...
# 38  ['달콤한 맥아', '캐러멜', '사츠 홉의 풍미', '쌉쌀한 풍미', '쓴 맛',...
# 39  ['로스팅과 구운 풍미', '크리미한 맥아 풍미', '홉 풍미 거의 없음', '커피...
# 40  ['밀크세이크 질감', '가벼운 곡물 풍미', '홉의 풍미 많지 않음', '고도의 ...
# 41  ['밀크세이크 질감', '가벼운 곡물 풍미', '홉의 풍미 많지 않음', '고도의 ...
# 42  ['밀크세이크 질감', '가벼운 곡물 풍미', '홉의 풍미 많지 않음', '고도의 ...
# 43  ['밀크세이크 질감', '가벼운 곡물 풍미', '홉의 풍미 많지 않음', '고도의 ...
# 44  ['밀크세이크 질감', '가벼운 곡물 풍미', '홉의 풍미 많지 않음', '고도의 ...
# 45  ['밀크세이크 질감', '가벼운 곡물 풍미', '홉의 풍미 많지 않음', '고도의 ...
# 46  ['밀크세이크 질감', '가벼운 곡물 풍미', '홉의 풍미 많지 않음', '고도의 ...
# 47  ['밀크세이크 질감', '가벼운 곡물 풍미', '홉의 풍미 많지 않음', '고도의 ...
# 48  ['밀크세이크 질감', '가벼운 곡물 풍미', '홉의 풍미 많지 않음', '고도의 ...
# 49                                  ['낮은 알코올', '탄산수']
# 50                     ['낮은 알코올', '탄산수', '단맛', '달콤함']
# 51                                  ['낮은 알코올', '탄산수']
# 52                            ['낮은 알코올', '탄산수', '신맛']
# 53  ['깔끔한 맥아 풍미', '캐러멜', '깔끔함', '청량함', '쌉쌀한 끝맛', '...
# 54  ['청량함', '매끄러운 맥아 풍미', '허브 풍미', '할러타우 홉', '견고한 ...
# 55  ['청량함', '매끄러운 맥아 풍미', '허브 풍미', '할러타우 홉', '견고한 ...
# 56  ['청량함', '매끄러운 맥아 풍미', '허브 풍미', '할러타우 홉', '견고한 ...
# 57  ['청량함', '매끄러운 맥아 풍미', '허브 풍미', '할러타우 홉', '견고한 ...
# 58  ['청량함', '매끄러운 맥아 풍미', '허브 풍미', '할러타우 홉', '견고한 ...
# 59  ['밀크세이크 질감', '가벼운 곡물 풍미', '홉의 풍미 많지 않음', '고도의 ...
# 60                              ['데킬라맛', '단맛', '달콤함']
# 61  ['구운 풍미', '쌉쌀한 풍미', '섬세한', '캐러멜', '부드러움', '약한 ...
# 62  ['구운 풍미', '쌉쌀한 풍미', '섬세한', '캐러멜', '부드러움', '약한 ...
# 63  ['구운 풍미', '쌉쌀한 풍미', '섬세한', '캐러멜', '초콜릿', '빵 껍질...
# 64                      ['로스팅 보리향', '캐러멜', '약한 홉 풍미']
# 65  ['신선한 홉 풍미', '견과류 맥아 풍미', '건포도', '캐러멜', '청량한 끝...
# 66  ['신선한 홉 풍미', '견과류 맥아 풍미', '건포도', '캐러멜', '청량한 끝...
# 67                              ['캐러멜', '단 맛', '상큼함']
# 68                     ['캐러멜', '달콤한 쿠기 풍미', '약간 쌉쌀함']
# 69               ['강한 쓴맛', '쓴 맛', '섬세함', '캐러멜', '단맛']
# 70            ['섬세한 맥아 풍미', '약한 캐러멜', '깔끔한 쓴맛', '단맛']
# 71                 ['과일 풍미', '시큼한 풍미', '크리미함', '달콤함']
# 72                        ['과일 풍미', '시큼한 풍미', '크리미함']
# 73        ['구운 풍미', '쓴 맛', '견과류 맥아 풍미', '가벼움', '단 맛']
# 74        ['구운 풍미', '쓴 맛', '견과류 맥아 풍미', '가벼움', '단 맛']
# 75  ['밀크세이크 질감', '가벼운 곡물 풍미', '홉의 풍미 많지 않음', '고도의 ...
# 76                (['청량함', '견과류 풍미', '스파이시', '쓴 맛'],)
#
#                                            Balance  \
# 27                                         ['미디엄']
# 28                                  ['미디엄', '단 맛']
# 29                                         ['미디엄']
# 30                                         ['미디엄']
# 31                                         ['미디엄']
# 32                                         ['미디엄']
# 33                               ['매우 드라이', '청량함']
# 34            ['밀크셰이크 질감', '드라이', '약간 시큼함', '크리미']
# 35                   ['밀크셰이크 질감', '드라이', '약간 시큼함']
# 36                   ['밀크셰이크 질감', '드라이', '약간 시큼함']
# 37                             ['홉의 풍미', '쌉쌀한 끝맛']
# 38                             ['홉의 풍미', '쌉쌀한 끝맛']
# 39  ['다양한 밸런스를 가진 제품 존재', '다양한 정도의 로스팅 풍미', '크리미']
# 40          ['드라이', '맥아 풍미', '곡물 풍미', '리치', '크리미']
# 41          ['드라이', '맥아 풍미', '곡물 풍미', '리치', '크리미']
# 42          ['드라이', '맥아 풍미', '곡물 풍미', '리치', '크리미']
# 43          ['드라이', '맥아 풍미', '곡물 풍미', '리치', '크리미']
# 44   ['드라이', '맥아 풍미', '곡물 풍미', '리치', '크리미', '크리미']
# 45          ['드라이', '맥아 풍미', '곡물 풍미', '리치', '크리미']
# 46          ['드라이', '맥아 풍미', '곡물 풍미', '리치', '크리미']
# 47   ['드라이', '맥아 풍미', '곡물 풍미', '리치', '크리미', '크리미']
# 48          ['드라이', '맥아 풍미', '곡물 풍미', '리치', '크리미']
# 49                                              []
# 50                                              []
# 51                                              []
# 52                                              []
# 53                 ['미디엄', '청량함', '쌉쌀한 끝맛', '크리미']
# 54                   ['균형', '드라이', '비터', '깔끔한 끝맛']
# 55                   ['균형', '드라이', '비터', '깔끔한 끝맛']
# 56            ['균형', '드라이', '비터', '깔끔한 끝맛', '크리미']
# 57                   ['균형', '드라이', '비터', '깔끔한 끝맛']
# 58                   ['균형', '드라이', '비터', '깔끔한 끝맛']
# 59          ['드라이', '맥아 풍미', '곡물 풍미', '리치', '크리미']
# 60                                              []
# 61                                       ['맥아 풍미']
# 62                                       ['맥아 풍미']
# 63                                  ['균형', '부드러움']
# 64                      ['매우 드라이', '매우 달콤', '크리미']
# 65                        ['미디엄', '청량함', '쌉쌀한 끝맛']
# 66                        ['미디엄', '청량함', '쌉쌀한 끝맛']
# 67                                         ['청량함']
# 68                    ['맥아 풍미', '홉에 의한 밸런스 거의 없음']
# 69                   ['균형', '드라이', '비터', '깔끔한 끝맛']
# 70          ['균형', '균등', '청량함', '드라이한 끝맛', '부드러움']
# 71            ['청량함', '드라이', '약간 달콤', '일정 수준의 신맛']
# 72            ['청량함', '드라이', '약간 달콤', '일정 수준의 신맛']
# 73                                         ['청럄함']
# 74                                         ['청럄함']
# 75          ['드라이', '맥아 풍미', '곡물 풍미', '리치', '크리미']
# 76                   ['균형', '드라이', '비터', '깨끗한 끝맛']
#
#                              Season  \
# 27                        ['연중 내내']
# 28                        ['연중 내내']
# 29                        ['연중 내내']
# 30                        ['연중 내내']
# 31                        ['연중 내내']
# 32                        ['연중 내내']
# 33                        ['연중 내내']
# 34              ['연중 내내', '따뜻한 날씨']
# 35              ['연중 내내', '따뜻한 날씨']
# 36              ['연중 내내', '따뜻한 날씨']
# 37                        ['연중 내내']
# 38                        ['연중 내내']
# 39              ['연중 내내', '서늘한 계절']
# 40                  ['연중 내내', '여름']
# 41                  ['연중 내내', '여름']
# 42                  ['연중 내내', '여름']
# 43                  ['연중 내내', '여름']
# 44                  ['연중 내내', '여름']
# 45                  ['연중 내내', '여름']
# 46                  ['연중 내내', '여름']
# 47                  ['연중 내내', '여름']
# 48                  ['연중 내내', '여름']
# 49                        ['연중 내내']
# 50                        ['연중 내내']
# 51                        ['연중 내내']
# 52                        ['연중 내내']
# 53                        ['연중 내내']
# 54              ['연중 내내', '따듯한 날씨']
# 55              ['연중 내내', '따듯한 날씨']
# 56              ['연중 내내', '따듯한 날씨']
# 57              ['연중 내내', '따듯한 날씨']
# 58              ['연중 내내', '따듯한 날씨']
# 59                  ['연중 내내', '여름']
# 60                               []
# 61  ['견과류', '기름진 음식', '파자', '마른안주']
# 62  ['견과류', '기름진 음식', '파자', '마른안주']
# 63                        ['연중 내내']
# 64                        ['연중 내내']
# 65                        ['연중 내내']
# 66                        ['연중 내내']
# 67                        ['연중 내내']
# 68            ['9월', '10월', '연중내내']
# 69              ['연중 내내', '따듯한 날씨']
# 70                        ['연중 내내']
# 71                        ['연중 내내']
# 72                        ['연중 내내']
# 73                        ['연중 내내']
# 74                        ['연중 내내']
# 75                  ['연중 내내', '여름']
# 76                        ['연중 내내']
#
#                                           Paring Food  \
# 27                            ['생선 요리', '해산물', '샐러드']
# 28                            ['생선 요리', '해산물', '샐러드']
# 29                            ['생선 요리', '해산물', '샐러드']
# 30                            ['생선 요리', '해산물', '샐러드']
# 31                            ['생선 요리', '해산물', '샐러드']
# 32                            ['생선 요리', '해산물', '샐러드']
# 33  ['스테이크', '고기 파이', '리치한 음식', '든든한 음식', '굴', '초콜릿']
# 34                        ['홍합', '연어', '닭', '가벼운 음식']
# 35                        ['홍합', '연어', '닭', '가벼운 음식']
# 36                        ['홍합', '연어', '닭', '가벼운 음식']
# 37  ['닭', '샐러드', '연어', '가벼운 음식', '알싸한 쓴 음식', '기름기 ...
# 38  ['닭', '샐러드', '연어', '가벼운 음식', '알싸한 쓴 음식', '기름기 ...
# 39       ['바베큐', '소시지', '초콜릿칩 쿠키', '구운 음식', '훈제된 음식']
# 40  ['샐러드', '해산물', '가벼운 음식', '바이스부르스트', '바나나 케이크',...
# 41  ['샐러드', '해산물', '가벼운 음식', '바이스부르스트', '바나나 케이크',...
# 42  ['샐러드', '해산물', '가벼운 음식', '바이스부르스트', '바나나 케이크',...
# 43  ['샐러드', '해산물', '가벼운 음식', '바이스부르스트', '바나나 케이크',...
# 44  ['샐러드', '해산물', '가벼운 음식', '바이스부르스트', '바나나 케이크',...
# 45  ['샐러드', '해산물', '가벼운 음식', '바이스부르스트', '바나나 케이크',...
# 46  ['샐러드', '해산물', '가벼운 음식', '바이스부르스트', '바나나 케이크',...
# 47  ['샐러드', '해산물', '가벼운 음식', '바이스부르스트', '바나나 케이크',...
# 48  ['샐러드', '해산물', '가벼운 음식', '바이스부르스트', '바나나 케이크',...
# 49                                              ['빵']
# 50                                              ['빵']
# 51                                              ['빵']
# 52                                              ['빵']
# 53  ['여러 광범위한 음식', '버거', '체다 치즈', '스테이크', '프렌치프라이'...
# 54  ['샐러드', '해산물 요리', '브라트부르스트', '가벼운 음식', '후추', '...
# 55  ['샐러드', '해산물 요리', '브라트부르스트', '가벼운 음식', '후추', '...
# 56  ['샐러드', '해산물 요리', '브라트부르스트', '가벼운 음식', '후추', '...
# 57  ['샐러드', '해산물 요리', '브라트부르스트', '가벼운 음식', '후추', '...
# 58  ['샐러드', '해산물 요리', '브라트부르스트', '가벼운 음식', '후추', '...
# 59                ['샐러드', '해산물', '가벼운 음식', '바이스부르스트']
# 60                                                 []
# 61  ['돼지고기 구이', '오리 구이', '연어 구이', '소시지', '케이준 생선',...
# 62  ['돼지고기 구이', '오리 구이', '연어 구이', '소시지', '케이준 생선',...
# 63  ['돼지고기 구이', '오리 구이', '연어 구이', '소시지', '케이준 생선',...
# 64  ['스테이크', '고기 파이', '리치한 음식', '든든한 음식', '굴', '초콜릿']
# 65  ['여러 광범위한 음식', '버거', '체다치즈', '스테이크', '프렌치프라이',...
# 66  ['여러 광범위한 음식', '버거', '체다치즈', '스테이크', '프렌치프라이',...
# 67                                      ['딤섬', '떡볶이']
# 68          ['멕시코 요리', '매운 요리', '닭', '소시지', '마일드 치즈']
# 69  ['샐러드', '해산물 요리', '브라트부르스트', '가벼운 음식', '후추', '...
# 70             ['라이트한 치즈', '홍합', '해산물 요리', '광범위한 음식']
# 71                       ['샐러드', '가벼운 음식', '가벼운 디저트']
# 72                       ['샐러드', '가벼운 음식', '가벼운 디저트']
# 73  ['구운 붉은 고기', '바비큐 고기', '햄', '고구마 튀김', '살코기 생선'...
# 74  ['구운 붉은 고기', '바비큐 고기', '햄', '고구마 튀김', '살코기 생선'...
# 75                ['샐러드', '해산물', '가벼운 음식', '바이스부르스트']
# 76                       ['다양한 음식', '고기 파이', '영국 치즈']
#
#                                        Body
# 27                           ['드라이', '깔끔함']
# 28                           ['드라이', '깔끔함']
# 29                           ['드라이', '깔끔함']
# 30          ['드라이', '깔끔함', '가벼움', '적당한 탄산']
# 31                           ['드라이', '깔끔함']
# 32          ['드라이', '깔끔함', '가벼움', '풍부한 탄산']
# 33               ['드라이', '가벼운 탄산화', '부드러움']
# 34          ['드라이', '미디엄', '매우 크리미', '크리미']
# 35          ['드라이', '미디엄', '매우 크리미', '크리미']
# 36          ['드라이', '미디엄', '매우 크리미', '크리미']
# 37              ['미디엄', '깔끔함', '탄산', '가벼움']
# 38              ['미디엄', '깔끔함', '탄산', '가벼움']
# 39                                  ['미디엄']
# 40                     ['걸쭉', '드라이', '가벼움']
# 41                     ['걸쭉', '드라이', '미디엄']
# 42              ['걸쭉', '드라이', '미디엄', '상쾌함']
# 43                   ['걸쭉', '드라이', '많은 탄산']
# 44                            ['걸쭉', '드라이']
# 45                            ['걸쭉', '드라이']
# 46                     ['걸쭉', '드라이', '가벼움']
# 47                            ['걸쭉', '드라이']
# 48                            ['걸쭉', '드라이']
# 49                                   ['탄산']
# 50                     ['탄산', '가벼움', '깔끔함']
# 51                        ['탄산', '불쾌한 탄산화']
# 52                                   ['탄산']
# 53                           ['청량함', '드라이']
# 54             ['청량함', '드라이', '가벼움', '깔끔함']
# 55  ['청량함', '드라이', '가벼움', '깔끔함', '적절한 탄산화']
# 56             ['청량함', '드라이', '가벼움', '깔끔함']
# 57             ['청량함', '드라이', '가벼움', '깔끔함']
# 58             ['청량함', '드라이', '가벼움', '깔끔함']
# 59                     ['걸쭉', '드라이', '가벼움']
# 60                                       []
# 61                           ['미디엄', '가벼움']
# 62                           ['미디엄', '가벼움']
# 63                           ['가벼움', '미디움']
# 64                           ['드라이', '미디엄']
# 65                                  ['미디엄']
# 66                                  ['미디엄']
# 67                                       []
# 68                                  ['미디엄']
# 69                     ['깔끔함', '탄산', '가벼움']
# 70                                  ['미디엄']
# 71                           ['라이트', '미디엄']
# 72                           ['라이트', '미디엄']
# 73                                  ['가벼움']
# 74                                  ['가벼움']
# 75                            ['걸쭉', '드라이']
# 76               ['청량함', '드라이', '진한 맥아 풍미']

# %%
# 데이터 준비 및 정재 list 형태로 바꿔주기 
# beer_data에서 총 6개의 feature(Aroma, Flavor, Balance, Season, Paring  Food, Body)를 가져온다 
beer_df = pd.DataFrame(beer_data, columns = ['Aroma','Flavor','Balance','Season','Paring Food', 'Body'])


# 데이터 타입 확인: data셀 하나에 들어있는 내용들은 str
type(beer_df['Aroma'].iloc[0])
beer_df['Aroma'].iloc[0]


# str형태에서 list로 변환
beer_df['Aroma'] = beer_df['Aroma'].apply(literal_eval)
beer_df['Flavor'] = beer_df['Flavor'].apply(literal_eval)
beer_df['Balance'] = beer_df['Balance'].apply(literal_eval)
beer_df['Season'] = beer_df['Season'].apply(literal_eval)
beer_df['Paring Food'] = beer_df['Paring Food'].apply(literal_eval)
beer_df['Body'] = beer_df['Body'].apply(literal_eval)

# %%
beer_df
# Out:
#                                                Aroma  \
# 0                  [고소한 맥아향, 강한 향, 빵 향, 달콤한 향, 풀잎 향]
# 1                         [고소한 맥아향, 강한 향, 쌀 향, 풀잎 향]
# 2                          [고소한 맥아향, 강한 향, 희미한 옥수수향]
# 3                   [고소한 맥아향, 강한 향, 가벼운 스컹스 향, 풀잎 향]
# 4                       [고소한 맥아향, 강한 향, 가벼운 낱알 몰트 향]
# 5               [고소한 맥아향, 강한 향, 매운 향, 플로랄 홉향, 가벼운 향]
# 6                         [고소한 맥아향, 강한 향, 약한 향, 과일향]
# 7                             [고소한 맥아향, 강한 향, 가벼운 향]
# 8                   [고소한 맥아향, 강한 향, 스파이시한 향, 약한 빵 향]
# 9                             [고소한 맥아향, 강한 향, 가벼운 향]
# 10                           [고소한 맥아향, 강한 향, 거친 맥아향]
# 11                          [고소한 맥아향, 강한 향, 달콤한 맥아향]
# 12                          [고소한 맥아향, 강한 향, 달콤한 맥아향]
# 13                      [고소한 맥아향, 강한 향, 스컹크 향, 풀잎 향]
# 14                                   [고소한 맥아향, 강한 향]
# 15           [고소한 맥아향, 강한 향, 약한 향, 약한 스컹스 향, 약한 과일향]
# 16              [고소한 맥아향, 강한 향, 풀잎 향, 쿠키향, 약한 스컹크 향]
# 17                              [고소한 맥아향, 강한 향, 과일향]
# 18                    [고소한 맥아향, 강한 향, 달콤한 맥아향, 꽃 향기]
# 19                            [고소한 맥아향, 강한 향, 옥수수 향]
# 20                    [고소한 맥아향, 강한 향, 캐러멜향, 창백한 맥아향]
# 21                                   [고소한 맥아향, 강한 향]
# 22                                   [고소한 맥아향, 강한 향]
# 23                     [고소한 맥아향, 강한 향, 달콤한 맥아향, 풀잎향]
# 24                              [고소한 맥아향, 강한 향, 풀잎향]
# 25                                   [고소한 맥아향, 강한 향]
# 26                [고소한 맥아향, 강한 향, 옥수수 향, 약한 캐라멜 멕아향]
# 27                                   [고소한 맥아향, 강한 향]
# 28                     [고소한 맥아향, 강한 향, 꽃향기, 달콤한 맥아향]
# 29               [로스팅 보리향, 커피향, 홉 아로마 거의 없음, 약한 빵 향]
# 30                         [스파이시한 효모향, 오렌지, 고수, 과일향]
# 31                 [스파이시한 효모향, 오렌지, 고수, 순한 고수향, 밀 향]
# 32  ['깔끔한 맥아향', '사츠홉향','스파이시한 향','허브향', 약한 빵 향, 꽃향기]
# 33               ['깔끔한 맥아향', '사츠홉향','스파이시한 향','허브향']
# 34                           [과일향, 스파이시한 향, 은은한 맥아향]
# 35                    [과일향, 스파이시한 향, 은은한 맥아향, 바나나 향]
# 36                     [과일향, 스파이시한 향, 은은한 맥아향, 바나나향]
# 37                           [과일향, 스파이시한 향, 은은한 맥아향]
# 38                           [과일향, 스파이시한 향, 은은한 맥아향]
# 39                           [과일향, 스파이시한 향, 은은한 맥아향]
# 40                           [과일향, 스파이시한 향, 은은한 맥아향]
# 41                                        [과일향, 레몬향]
# 42                                         [과일향, 단맛]
# 43                                        [과일향, 자몽향]
# 44                                    [과일향, 홉향, 맥아향]
# 45                   [깔끔한 맥아향, 허브향, 민트향, 노블 홉향, 후추향]
# 46               [깔끔한 맥아향, 허브향, 민트향, 노블 홉향, 가벼운 곡물향]
# 47               [깔끔한 맥아향, 허브향, 민트향, 노블 홉향, 약간의 과일향]
# 48                [깔끔한 맥아향, 허브향, 민트향, 노블 홉향, 약한 빵 향]
# 49                        [깔끔한 맥아향, 허브향, 민트향, 노블 홉향]
# 50                                    [과일향, 스파이시한 향]
# 51                                      [캐러멜 향, 허브향]
# 52                 [맥아향, 초콜렛 향, 캐러멜 향, 맥아향, 멕아 로스팅향]
# 53                               [맥아향, 초콜렛 향, 캐러멜 향]
# 54                                [맥아향, 초콜렛 향, 카라멜향]
# 55                 [고소한 맥아향, 캐러멜향, 쿠키향, 홉 아로마 거의 없음]
# 56    [깔끔한 맥아향, 허브향, 민트향, 노블 홉향, 강한 향, 소나무향, 약한 빵 향]
# 57                                      [과일향, 라즈베리향]
# 58                       [과일향, 고소한 맥아향, 약한 빵 향, 허브향]
# 59                              [과일향, 스파이시한 향, 캐러멜향]
#
#                                                Flavor  \
# 0                                   [쓴 맛, 상쾌함, 생강 힌트]
# 1                   [쓴 맛, 상쾌함, 쌀 풍미, 약간의 단맛, 약간의 쓴 맛]
# 2               [쓴 맛, 상쾌함, 가벼운 맥아 풍미, 옥수수 풍미, 약간의 쓴맛]
# 3                                  [쓴 맛, 상쾌함, 스컹크 풍미]
# 4                                   [쓴 맛, 상쾌함, 맥아 풍미]
# 5                           [쓴 맛, 상쾌함, 약간의 단맛, 맥아 풍미]
# 6                       [쓴 맛, 상쾌함, 보조 맥아 힌트, 사과 주스 맛]
# 7                        [쓴 맛, 상쾌함, 약간 단맛, 김치에 좋은 맥주]
# 8                               [쓴 맛, 상쾌함, 순함, 약한 쓴맛]
# 9                               [쓴 맛, 상쾌함, 약한 달콤한 맥아]
# 10                                         [쓴 맛, 상쾌함]
# 11                                 [쓴 맛, 상쾌함, 옥수수 단맛]
# 12                                  [쓴 맛, 상쾌함, 약한 단맛]
# 13                                         [쓴 맛, 상쾌함]
# 14                                    [쓴 맛, 상쾌함, 단 맛]
# 15                                         [쓴 맛, 상쾌함]
# 16                                         [쓴 맛, 상쾌함]
# 17                                         [쓴 맛, 상쾌함]
# 18                             [쓴 맛, 상쾌함, 단 맛, 옥수수 맛]
# 19                                    [쓴 맛, 상쾌함, 단 맛]
# 20                                    [쓴 맛, 상쾌함, 캐러멜]
# 21                                         [쓴 맛, 상쾌함]
# 22                                    [쓴 맛, 상쾌함, 단 맛]
# 23                         [쓴 맛, 상쾌함, 약한 단맛, 약한 떫은 맛]
# 24                                         [쓴 맛, 상쾌함]
# 25                       [쓴 맛, 상쾌함, 옅은 옥수수 향, 옅은 맥아향]
# 26                                    [쓴 맛, 상쾌함, 캐러멜]
# 27                                         [쓴 맛, 상쾌함]
# 28                                  [쓴 맛, 상쾌함, 약한 단맛]
# 29                                 [쓴 맛, 약간 크리미, 초콜렛]
# 30                    [드라이한 크림 풍미, 부드러움, 시큼한 끝맛, 사과맛]
# 31                         [드라이한 크림 풍미, 부드러움, 시큼한 끝맛]
# 32  [달콤한 맥아, 캐러멜, 사츠 홉의 풍미, 쌉쌀한 풍미, 쓴 맛, 섬세함, 단 맛,...
# 33          [달콤한 맥아, 캐러멜, 사츠 홉의 풍미, 쌉쌀한 풍미, 쓴 맛, 섬세함]
# 34  [밀크세이크 질감, 가벼운 곡물 풍미, 홉의 풍미 많지 않음, 고도의 탄산, 구운 ...
# 35  [밀크세이크 질감, 가벼운 곡물 풍미, 홉의 풍미 많지 않음, 고도의 탄산, 구운 ...
# 36  [밀크세이크 질감, 가벼운 곡물 풍미, 홉의 풍미 많지 않음, 고도의 탄산, 구운 ...
# 37  [밀크세이크 질감, 가벼운 곡물 풍미, 홉의 풍미 많지 않음, 고도의 탄산, 구운 ...
# 38  [밀크세이크 질감, 가벼운 곡물 풍미, 홉의 풍미 많지 않음, 고도의 탄산, 구운 ...
# 39  [밀크세이크 질감, 가벼운 곡물 풍미, 홉의 풍미 많지 않음, 고도의 탄산, 구운 ...
# 40  [밀크세이크 질감, 가벼운 곡물 풍미, 홉의 풍미 많지 않음, 고도의 탄산, 구운 ...
# 41                             [낮은 알코올, 탄산수, 단맛, 달콤함]
# 42                                      [낮은 알코올, 탄산수]
# 43                                  [낮은 알코올, 탄산수, 신맛]
# 44  [깔끔한 맥아 풍미, 캐러멜, 깔끔함, 청량함, 쌉쌀한 끝맛, 강렬함, 쓴 맛, 캐러멜]
# 45  [청량함, 매끄러운 맥아 풍미, 허브 풍미, 할러타우 홉, 견고한 쓴맛, 섬세함, 단맛]
# 46  [청량함, 매끄러운 맥아 풍미, 허브 풍미, 할러타우 홉, 견고한 쓴맛, 섬세함, ...
# 47      [청량함, 매끄러운 맥아 풍미, 허브 풍미, 할러타우 홉, 견고한 쓴맛, 섬세함]
# 48      [청량함, 매끄러운 맥아 풍미, 허브 풍미, 할러타우 홉, 견고한 쓴맛, 섬세함]
# 49      [청량함, 매끄러운 맥아 풍미, 허브 풍미, 할러타우 홉, 견고한 쓴맛, 섬세함]
# 50  [밀크세이크 질감, 가벼운 곡물 풍미, 홉의 풍미 많지 않음, 고도의 탄산, 구운 풍미]
# 51                                    [데킬라맛, 단맛, 달콤함]
# 52  [구운 풍미, 쌉쌀한 풍미, 섬세한, 캐러멜, 부드러움, 약한 쓴맛, 약한 단맛, ...
# 53      [구운 풍미, 쌉쌀한 풍미, 섬세한, 캐러멜, 부드러움, 약한 쓴맛, 약한 단맛]
# 54      [구운 풍미, 쌉쌀한 풍미, 섬세한, 캐러멜, 초콜릿, 빵 껍질, 달콤함, 단맛]
# 55                           [캐러멜, 달콤한 쿠기 풍미, 약간 쌉쌀함]
# 56                         [강한 쓴맛, 쓴 맛, 섬세함, 캐러멜, 단맛]
# 57                         [과일 풍미, 시큼한 풍미, 크리미함, 달콤함]
# 58                  [구운 풍미, 쓴 맛, 견과류 맥아 풍미, 가벼움, 단 맛]
# 59  [밀크세이크 질감, 가벼운 곡물 풍미, 홉의 풍미 많지 않음, 고도의 탄산, 캐러멜...
#
#                               Balance                   Season  \
# 0                               [미디엄]                  [연중 내내]
# 1                               [미디엄]                  [연중 내내]
# 2                               [미디엄]                  [연중 내내]
# 3                               [미디엄]                  [연중 내내]
# 4                               [미디엄]                  [연중 내내]
# 5                               [미디엄]                  [연중 내내]
# 6                               [미디엄]           [연중 내내, 더운 여름]
# 7                               [미디엄]                  [연중 내내]
# 8                           [미디엄, 균형]                  [연중 내내]
# 9                               [미디엄]                  [연중 내내]
# 10                              [미디엄]                  [연중 내내]
# 11             [미디엄, 홉에 의한 밸런스 거의 없음]                  [연중 내내]
# 12                              [미디엄]                  [연중 내내]
# 13                              [미디엄]                  [연중 내내]
# 14                         [미디엄, 크리미]                  [연중 내내]
# 15                              [미디엄]                  [연중 내내]
# 16                         [미디엄, 크리미]                  [연중 내내]
# 17                              [미디엄]                  [연중 내내]
# 18                         [미디엄, 크리미]               [연중 내내, 봄]
# 19                              [미디엄]                  [연중 내내]
# 20                         [미디엄, 상쾌함]                  [연중 내내]
# 21                              [미디엄]                  [연중 내내]
# 22                              [미디엄]                  [연중 내내]
# 23                              [미디엄]                  [연중 내내]
# 24                              [미디엄]                  [연중 내내]
# 25                         [미디엄, 단 맛]                  [연중 내내]
# 26                              [미디엄]                  [연중 내내]
# 27                              [미디엄]                  [연중 내내]
# 28                              [미디엄]                  [연중 내내]
# 29                      [매우 드라이, 청량함]                  [연중 내내]
# 30       [밀크셰이크 질감, 드라이, 약간 시큼함, 크리미]          [연중 내내, 따뜻한 날씨]
# 31            [밀크셰이크 질감, 드라이, 약간 시큼함]          [연중 내내, 따뜻한 날씨]
# 32                    [홉의 풍미, 쌉쌀한 끝맛]                  [연중 내내]
# 33                    [홉의 풍미, 쌉쌀한 끝맛]                  [연중 내내]
# 34       [드라이, 맥아 풍미, 곡물 풍미, 리치, 크리미]              [연중 내내, 여름]
# 35       [드라이, 맥아 풍미, 곡물 풍미, 리치, 크리미]              [연중 내내, 여름]
# 36       [드라이, 맥아 풍미, 곡물 풍미, 리치, 크리미]              [연중 내내, 여름]
# 37  [드라이, 맥아 풍미, 곡물 풍미, 리치, 크리미, 크리미]              [연중 내내, 여름]
# 38       [드라이, 맥아 풍미, 곡물 풍미, 리치, 크리미]              [연중 내내, 여름]
# 39       [드라이, 맥아 풍미, 곡물 풍미, 리치, 크리미]              [연중 내내, 여름]
# 40       [드라이, 맥아 풍미, 곡물 풍미, 리치, 크리미]              [연중 내내, 여름]
# 41                                 []                  [연중 내내]
# 42                                 []                  [연중 내내]
# 43                                 []                  [연중 내내]
# 44            [미디엄, 청량함, 쌉쌀한 끝맛, 크리미]                  [연중 내내]
# 45              [균형, 드라이, 비터, 깔끔한 끝맛]          [연중 내내, 따듯한 날씨]
# 46              [균형, 드라이, 비터, 깔끔한 끝맛]          [연중 내내, 따듯한 날씨]
# 47         [균형, 드라이, 비터, 깔끔한 끝맛, 크리미]          [연중 내내, 따듯한 날씨]
# 48              [균형, 드라이, 비터, 깔끔한 끝맛]          [연중 내내, 따듯한 날씨]
# 49              [균형, 드라이, 비터, 깔끔한 끝맛]          [연중 내내, 따듯한 날씨]
# 50       [드라이, 맥아 풍미, 곡물 풍미, 리치, 크리미]              [연중 내내, 여름]
# 51                                 []                       []
# 52                            [맥아 풍미]  [견과류, 기름진 음식, 파자, 마른안주]
# 53                            [맥아 풍미]  [견과류, 기름진 음식, 파자, 마른안주]
# 54                         [균형, 부드러움]                  [연중 내내]
# 55           [맥아 풍미, 홉에 의한 밸런스 거의 없음]          [9월, 10월, 연중내내]
# 56              [균형, 드라이, 비터, 깔끔한 끝맛]          [연중 내내, 따듯한 날씨]
# 57       [청량함, 드라이, 약간 달콤, 일정 수준의 신맛]                  [연중 내내]
# 58                              [청럄함]                  [연중 내내]
# 59       [드라이, 맥아 풍미, 곡물 풍미, 리치, 크리미]              [연중 내내, 여름]
#
#                                           Paring Food  \
# 0                                   [생선 요리, 해산물, 샐러드]
# 1                                   [생선 요리, 해산물, 샐러드]
# 2                            [생선 요리, 해산물, 샐러드, 매운 음식]
# 3                                   [생선 요리, 해산물, 샐러드]
# 4                                   [생선 요리, 해산물, 샐러드]
# 5                                   [생선 요리, 해산물, 샐러드]
# 6                                   [생선 요리, 해산물, 샐러드]
# 7                                   [생선 요리, 해산물, 샐러드]
# 8                                   [생선 요리, 해산물, 샐러드]
# 9                                   [생선 요리, 해산물, 샐러드]
# 10                                  [생선 요리, 해산물, 샐러드]
# 11                          [생선 요리, 해산물, 샐러드, 아시아 음식]
# 12                                  [생선 요리, 해산물, 샐러드]
# 13                                  [생선 요리, 해산물, 샐러드]
# 14                                  [생선 요리, 해산물, 샐러드]
# 15                                  [생선 요리, 해산물, 샐러드]
# 16                                  [생선 요리, 해산물, 샐러드]
# 17                                  [생선 요리, 해산물, 샐러드]
# 18                                  [생선 요리, 해산물, 샐러드]
# 19                                  [생선 요리, 해산물, 샐러드]
# 20                                  [생선 요리, 해산물, 샐러드]
# 21                                  [생선 요리, 해산물, 샐러드]
# 22                   [생선 요리, 해산물, 샐러드, 매운 음식, 무거운 음식]
# 23                                  [생선 요리, 해산물, 샐러드]
# 24                                  [생선 요리, 해산물, 샐러드]
# 25                                  [생선 요리, 해산물, 샐러드]
# 26                                  [생선 요리, 해산물, 샐러드]
# 27                                  [생선 요리, 해산물, 샐러드]
# 28                                  [생선 요리, 해산물, 샐러드]
# 29              [스테이크, 고기 파이, 리치한 음식, 든든한 음식, 굴, 초콜릿]
# 30                                [홍합, 연어, 닭, 가벼운 음식]
# 31                                [홍합, 연어, 닭, 가벼운 음식]
# 32  [닭, 샐러드, 연어, 가벼운 음식, 알싸한 쓴 음식, 기름기 많은 생선, 톡 쏘는...
# 33  [닭, 샐러드, 연어, 가벼운 음식, 알싸한 쓴 음식, 기름기 많은 생선, 톡 쏘는...
# 34  [샐러드, 해산물, 가벼운 음식, 바이스부르스트, 바나나 케이크, 바베큐 케이준, ...
# 35  [샐러드, 해산물, 가벼운 음식, 바이스부르스트, 바나나 케이크, 바베큐 케이준, ...
# 36  [샐러드, 해산물, 가벼운 음식, 바이스부르스트, 바나나 케이크, 바베큐 케이준, ...
# 37  [샐러드, 해산물, 가벼운 음식, 바이스부르스트, 바나나 케이크, 바베큐 케이준, ...
# 38  [샐러드, 해산물, 가벼운 음식, 바이스부르스트, 바나나 케이크, 바베큐 케이준, ...
# 39  [샐러드, 해산물, 가벼운 음식, 바이스부르스트, 바나나 케이크, 바베큐 케이준, ...
# 40  [샐러드, 해산물, 가벼운 음식, 바이스부르스트, 바나나 케이크, 바베큐 케이준, ...
# 41                                                [빵]
# 42                                                [빵]
# 43                                                [빵]
# 44  [여러 광범위한 음식, 버거, 체다 치즈, 스테이크, 프렌치프라이, 샌드위치, 어니...
# 45  [샐러드, 해산물 요리, 브라트부르스트, 가벼운 음식, 후추, 기름기 많은 생선, ...
# 46  [샐러드, 해산물 요리, 브라트부르스트, 가벼운 음식, 후추, 기름기 많은 생선, ...
# 47  [샐러드, 해산물 요리, 브라트부르스트, 가벼운 음식, 후추, 기름기 많은 생선, ...
# 48  [샐러드, 해산물 요리, 브라트부르스트, 가벼운 음식, 후추, 기름기 많은 생선, ...
# 49  [샐러드, 해산물 요리, 브라트부르스트, 가벼운 음식, 후추, 기름기 많은 생선, ...
# 50                        [샐러드, 해산물, 가벼운 음식, 바이스부르스트]
# 51                                                 []
# 52  [돼지고기 구이, 오리 구이, 연어 구이, 소시지, 케이준 생선, 흰색 육류, 스테...
# 53  [돼지고기 구이, 오리 구이, 연어 구이, 소시지, 케이준 생선, 흰색 육류, 스테...
# 54  [돼지고기 구이, 오리 구이, 연어 구이, 소시지, 케이준 생선, 흰색 육류, 스테...
# 55                    [멕시코 요리, 매운 요리, 닭, 소시지, 마일드 치즈]
# 56  [샐러드, 해산물 요리, 브라트부르스트, 가벼운 음식, 후추, 기름기 많은 생선, ...
# 57                             [샐러드, 가벼운 음식, 가벼운 디저트]
# 58  [구운 붉은 고기, 바비큐 고기, 햄, 고구마 튀김, 살코기 생선, 퀘사디야, 필라...
# 59                        [샐러드, 해산물, 가벼운 음식, 바이스부르스트]
#
#                              Body
# 0             [드라이, 깔끔함, 가벼움, 탄산]
# 1       [드라이, 깔끔함, 가벼움, 약간의 매끄러움]
# 2         [드라이, 깔끔함, 가벼움, 가벼운 탄산]
# 3                  [드라이, 깔끔함, 탄산]
# 4              [드라이, 깔끔함, 적당한 탄산]
# 5         [드라이, 깔끔함, 가벼움, 적당한 탄산]
# 6              [드라이, 깔끔함, 적당한 탄산]
# 7         [드라이, 깔끔함, 가벼움, 적당한 탄산]
# 8       [드라이, 깔끔함, 부드러움, 가벼움, 탄산]
# 9                 [드라이, 깔끔함, 가벼움]
# 10             [드라이, 깔끔함, 적당한 탄산]
# 11             [드라이, 깔끔함, 적당한 탄산]
# 12            [드라이, 깔끔함, 적당한 탄산화]
# 13                [드라이, 깔끔함, 가벼움]
# 14                     [드라이, 깔끔함]
# 15                [드라이, 깔끔함, 가벼움]
# 16            [드라이, 깔끔함, 적당한 탄산화]
# 17                     [드라이, 깔끔함]
# 18                [드라이, 깔끔함, 가벼움]
# 19              [드라이, 깔끔함, 많은 탄산]
# 20         [드라이, 깔끔함, 가벼움, 적은 탄산]
# 21                     [드라이, 깔끔함]
# 22                 [드라이, 깔끔함, 탄산]
# 23                     [드라이, 깔끔함]
# 24                     [드라이, 깔끔함]
# 25                     [드라이, 깔끔함]
# 26                     [드라이, 깔끔함]
# 27        [드라이, 깔끔함, 가벼움, 적당한 탄산]
# 28        [드라이, 깔끔함, 가벼움, 풍부한 탄산]
# 29           [드라이, 가벼운 탄산화, 부드러움]
# 30        [드라이, 미디엄, 매우 크리미, 크리미]
# 31        [드라이, 미디엄, 매우 크리미, 크리미]
# 32            [미디엄, 깔끔함, 탄산, 가벼움]
# 33            [미디엄, 깔끔함, 탄산, 가벼움]
# 34                 [걸쭉, 드라이, 가벼움]
# 35            [걸쭉, 드라이, 미디엄, 상쾌함]
# 36               [걸쭉, 드라이, 많은 탄산]
# 37                      [걸쭉, 드라이]
# 38                      [걸쭉, 드라이]
# 39                 [걸쭉, 드라이, 가벼움]
# 40                      [걸쭉, 드라이]
# 41                 [탄산, 가벼움, 깔끔함]
# 42                  [탄산, 불쾌한 탄산화]
# 43                           [탄산]
# 44                     [청량함, 드라이]
# 45           [청량함, 드라이, 가벼움, 깔끔함]
# 46  [청량함, 드라이, 가벼움, 깔끔함, 적절한 탄산화]
# 47           [청량함, 드라이, 가벼움, 깔끔함]
# 48           [청량함, 드라이, 가벼움, 깔끔함]
# 49           [청량함, 드라이, 가벼움, 깔끔함]
# 50                 [걸쭉, 드라이, 가벼움]
# 51                             []
# 52                     [미디엄, 가벼움]
# 53                     [미디엄, 가벼움]
# 54                     [가벼움, 미디움]
# 55                          [미디엄]
# 56                 [깔끔함, 탄산, 가벼움]
# 57                     [라이트, 미디엄]
# 58                          [가벼움]
# 59                      [걸쭉, 드라이]

# %%
beer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 59
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Aroma         60 non-null     object
#  1   Flavor        60 non-null     object
#  2   Balance       60 non-null     object
#  3   Season        60 non-null     object
#  4   Paring Food   60 non-null     object
#  5   Body          60 non-null     object
#  6   Body_literal  60 non-null     object
# dtypes: object(7)
# memory usage: 3.8+ KB

# %% [markdown]
# # 추출한 Feature별 컨텐츠 유사도 측정

# %% [markdown]
# ## Something에 무엇을 넣느냐에 따라 달라진다.
# ### 총 5개의 항목 'Aroma', 'Flavor', 'Balance', 'Paring Food', 'Body'

# %%
# something = 'Aroma'
# something = 'Flavor'
# something = 'Balance'
# something = 'Paring Food'
something = 'Body'

# %%
# CountVectorizer를 활용하기 위한 전처리 
beer_df[something +'_literal'] = beer_df[something].apply(lambda x : (' ').join(x))
beer_df[something +'_literal']
# Out:
# 0              드라이 깔끔함 가벼움 탄산
# 1        드라이 깔끔함 가벼움 약간의 매끄러움
# 2          드라이 깔끔함 가벼움 가벼운 탄산
# 3                  드라이 깔끔함 탄산
# 4              드라이 깔끔함 적당한 탄산
# 5          드라이 깔끔함 가벼움 적당한 탄산
# 6              드라이 깔끔함 적당한 탄산
# 7          드라이 깔끔함 가벼움 적당한 탄산
# 8         드라이 깔끔함 부드러움 가벼움 탄산
# 9                 드라이 깔끔함 가벼움
# 10             드라이 깔끔함 적당한 탄산
# 11             드라이 깔끔함 적당한 탄산
# 12            드라이 깔끔함 적당한 탄산화
# 13                드라이 깔끔함 가벼움
# 14                    드라이 깔끔함
# 15                드라이 깔끔함 가벼움
# 16            드라이 깔끔함 적당한 탄산화
# 17                    드라이 깔끔함
# 18                드라이 깔끔함 가벼움
# 19              드라이 깔끔함 많은 탄산
# 20          드라이 깔끔함 가벼움 적은 탄산
# 21                    드라이 깔끔함
# 22                 드라이 깔끔함 탄산
# 23                    드라이 깔끔함
# 24                    드라이 깔끔함
# 25                    드라이 깔끔함
# 26                    드라이 깔끔함
# 27         드라이 깔끔함 가벼움 적당한 탄산
# 28         드라이 깔끔함 가벼움 풍부한 탄산
# 29           드라이 가벼운 탄산화 부드러움
# 30         드라이 미디엄 매우 크리미 크리미
# 31         드라이 미디엄 매우 크리미 크리미
# 32             미디엄 깔끔함 탄산 가벼움
# 33             미디엄 깔끔함 탄산 가벼움
# 34                 걸쭉 드라이 가벼움
# 35             걸쭉 드라이 미디엄 상쾌함
# 36               걸쭉 드라이 많은 탄산
# 37                     걸쭉 드라이
# 38                     걸쭉 드라이
# 39                 걸쭉 드라이 가벼움
# 40                     걸쭉 드라이
# 41                 탄산 가벼움 깔끔함
# 42                 탄산 불쾌한 탄산화
# 43                         탄산
# 44                    청량함 드라이
# 45            청량함 드라이 가벼움 깔끔함
# 46    청량함 드라이 가벼움 깔끔함 적절한 탄산화
# 47            청량함 드라이 가벼움 깔끔함
# 48            청량함 드라이 가벼움 깔끔함
# 49            청량함 드라이 가벼움 깔끔함
# 50                 걸쭉 드라이 가벼움
# 51
# 52                    미디엄 가벼움
# 53                    미디엄 가벼움
# 54                    가벼움 미디움
# 55                        미디엄
# 56                 깔끔함 탄산 가벼움
# 57                    라이트 미디엄
# 58                        가벼움
# 59                     걸쭉 드라이
# Name: Body_literal, dtype: object

# %%
#CountVectorizer로 학습시키기
count_vect = CountVectorizer(min_df=0, ngram_range=(1,2))   # 특징 2개(ngram_range: 1<= n <=2)
something_mat = count_vect.fit_transform(beer_df[something + '_literal'])

# 77개의 맥주 중에 178개 Aroma의 'Aroma 매트릭스'가 생성됨
print(something_mat.shape)
# Out:
# (60, 65)

# %%
something_mat
# Out:
# <60x65 sparse matrix of type '<class 'numpy.int64'>'
# 	with 329 stored elements in Compressed Sparse Row format>

# %%
# 77개의 맥주 중에 65개 Aroma의 'Aroma 매트릭스'가 생성됨
count_vect2 = CountVectorizer(min_df=1, ngram_range=(1,1))   
something_mat2 = count_vect2.fit_transform(beer_df[something+'_literal'])
print(something_mat2.shape)
# Out:
# (60, 23)

# %%
something_mat2
# Out:
# <60x23 sparse matrix of type '<class 'numpy.int64'>'
# 	with 193 stored elements in Compressed Sparse Row format>

# %%
# 77개의 맥주에 대한 가각 유사한 맥주들이 계산 됨

something_sim = cosine_similarity(something_mat,something_mat)
print(something_sim.shape)
print(something_sim)
# Out:
# (60, 60)
# [[1.         0.62994079 0.75592895 ... 0.         0.37796447 0.21821789]
#  [0.62994079 1.         0.55555556 ... 0.         0.33333333 0.19245009]
#  [0.75592895 0.55555556 1.         ... 0.         0.33333333 0.19245009]
#  ...
#  [0.         0.         0.         ... 1.         0.         0.        ]
#  [0.37796447 0.33333333 0.33333333 ... 0.         1.         0.        ]
#  [0.21821789 0.19245009 0.19245009 ... 0.         0.         1.        ]]

# %%
# 순서 보기
# 숫자가 작을수록 유사도가 높은 맥주
something_sim_sorted_ind = something_sim.argsort()[:, ::-1]
print(something_sim_sorted_ind[:1])
# Out:
# [[ 0 18  9 13 15  2  5 28 20 27  8  7  3 22 24 23 26 17 21 14 25  1 19 11
#    4  6 10 56 41 12 47 49 48 45 32 33 16 43 58 46 34 39 50 36 59 37 38 40
#   44 52 53 54 42 35 29 30 31 51 55 57]]

# %% [markdown]
# # 코사인 유사도로 맥주 추천

# %%
def find_sim_beer_ver1(beer_data, sorted_ind, beer_name, top_n=10):
    
    beer_name = beer_data[beer_data['맥주이름'] == beer_name]
    
    beer_index = beer_name.index.values
    similar_indexes = sorted_ind[beer_index, :(top_n)]
    
    print(similar_indexes)
    
    similar_inidexes = similar_indexes.reshape(-1)
    
    return beer_data.iloc[similar_inidexes]

# %%
# 10개의 맥주 추천 결과
# Pilsner Urquel로 검색한 결과, 대체로 필스터 혹은 비슷한 성질으 가진 페일에일이 추천되는 것을 알 수 있다.

similar_beers = find_sim_beer_ver1(beer_data, something_sim_sorted_ind, 'Pilsner Urquell',10)
similar_beers[['맥주이름','맥주스타일',something,'평점평균','평가횟수']]
# Out:
# [[33 32 56 41 22  3 53 52  0 28]]
#                                 맥주이름                                 맥주스타일  \
# 33  Gambrinus Originál 10° (Desítka)           Pilsener - Bohemian / Czech
# 32                   Pilsner Urquell           Pilsener - Bohemian / Czech
# 56            Bavaria 8.6 (Original)                   Pilsener - Imperial
# 41                Tiger Radler Lemon                       Radler / Shandy
# 22                OB Premier Pilsner                 Pale Lager - American
# 3                           Heineken  Pale Lager - International / Premium
# 53             Asahi Super Dry Black  Dark Lager - International / Premium
# 52               Heineken Dark Lager  Dark Lager - International / Premium
# 0             Kloud Original Gravity  Pale Lager - International / Premium
# 28       Stephans Bräu Premium Lager                 Pale Lager - American
#
#                                Body     평점평균  평가횟수
# 33      ['미디엄', '깔끔함', '탄산', '가벼움']  2.51777   332
# 32      ['미디엄', '깔끔함', '탄산', '가벼움']  3.24791  2077
# 56             ['깔끔함', '탄산', '가벼움']  2.17543   293
# 41             ['탄산', '가벼움', '깔끔함']     2.01    20
# 22             ['드라이', '깔끔함', '탄산']  2.18571    49
# 3              ['드라이', '깔끔함', '탄산']  2.08413  1953
# 53                   ['미디엄', '가벼움']  2.62525    99
# 52                   ['미디엄', '가벼움']  2.65792   404
# 0       ['드라이', '깔끔함', '가벼움', '탄산']   2.2925    80
# 28  ['드라이', '깔끔함', '가벼움', '풍부한 탄산']  2.04615    39

# %%
beer_data[['맥주이름','맥주스타일',something,'평점평균','평가횟수']].sort_values('평점평균', ascending=False)[:3]
# Out:
#                        맥주이름                   맥주스타일  \
# 37  Paulaner Hefe-Weissbier  Weissbier - Hefeweizen
# 50               Hoegaarden               Wheat Ale
# 29         Guinness Draught     Stout - Dry / Irish
#
#                           Body     평점평균  평가횟수
# 37               ['걸쭉', '드라이']  3.55755  1807
# 50        ['걸쭉', '드라이', '가벼움']  3.46274  2048
# 29  ['드라이', '가벼운 탄산화', '부드러움']   3.3069  2100

# %% [markdown]
# ## 가중평점(평점&평가횟수) 반영한 영화 추천

# %%
# 실습에서 한 식 그대로 사용
# 상위 60%에 해당하는 평가 횟수를 최소 투표 횟수인 m으로 활용
C = beer_data['평점평균'].mean()
m = beer_data['평가횟수'].quantile(0.6)

# %%
print('C:',round(C,3), 'm:',round(m,3))
# Out:
# C: 2.396 m: 500.8

# %% [markdown]
# ## 가중평점을 계산하는 함수

# %%
# 가중평점을 계산하는 함수
def weighted_vote_average(data):
    v = data['평가횟수']
    R = data['평점평균']
    
    return ( (v/(v+m)) * R) + (m/(m+v) * C)

# %%
# 기존 데이터에 가중평점 칼럼 추가
beer_data['가중평점'] = beer_data.apply(weighted_vote_average, axis=1)

# %%
# 추천을 받기위해 넣었던 데이터
beer_data[beer_data['맥주이름']=='Pilsner Urquell'][['Main Category','맥주스타일','맥주이름',something,
           '평점평균','평가횟수']]
# Out:
#    Main Category                        맥주스타일             맥주이름  \
# 32            라거  Pilsener - Bohemian / Czech  Pilsner Urquell
#
#                            Body     평점평균  평가횟수
# 32  ['미디엄', '깔끔함', '탄산', '가벼움']  3.24791  2077

# %%
# 가중 평균까지 구하여 넣은 값
beer_data[['가중평점','맥주이름','맥주스타일','Main Category', something,
           '평점평균','평가횟수']].sort_values('가중평점', ascending=False)[:3]
# Out:
#         가중평점                     맥주이름                   맥주스타일  \
# 37  3.305564  Paulaner Hefe-Weissbier  Weissbier - Hefeweizen
# 50  3.253210               Hoegaarden               Wheat Ale
# 29  3.131567         Guinness Draught     Stout - Dry / Irish
#
#                Main Category                        Body     평점평균  평가횟수
# 37  컨티넨털 에일/바이스비어/에일-라거하이브리드               ['걸쭉', '드라이']  3.55755  1807
# 50                    벨기에 맥주        ['걸쭉', '드라이', '가벼움']  3.46274  2048
# 29                영국-아일랜드 에일  ['드라이', '가벼운 탄산화', '부드러움']   3.3069  2100

# %% [markdown]
# ### 추천 ver2. 먼저 장르 유사성 높은 영화 20개 선정 후 (F1), 가중 평점순 10개 선정
#
# #### 하나의 맥주에 대해 장르 유사성, 가중평점 반영한 추천 맥주 10개를 뽑아보자

# %%
def find_sim_beer_ver2(data, sorted_ind, beer_name, top_n=10):
    beer_name = data[data['맥주이름'] == beer_name]
    beer_index = beer_name.index.values
    
    # top_n의 2배에 해당하는 쟝르 유사성이 높은 index 추출
    similar_indexes = sorted_ind[beer_index, :(top_n*2)]
    similar_indexes = similar_indexes.reshape(-1)

    # 기준 영화 index는 제외(자기자신 제외)
    similar_indexes = similar_indexes[similar_indexes != beer_index]
    
    # top_n의 2배에 해당하는 후보군에서 weighted_vote 높은 순으로 top_n 만큼 추출 
    return data.iloc[similar_indexes].sort_values('가중평점', ascending=False)[:top_n]

# %%
similar_beers = find_sim_beer_ver2(beer_data, something_sim_sorted_ind, 'Paulaner Hefe-Weissbier',3)
similar_beers[['맥주이름','맥주스타일',something,'평점평균','평가횟수']]
# Out:
#                          맥주이름                     맥주스타일                  Body  \
# 50                 Hoegaarden                 Wheat Ale  ['걸쭉', '드라이', '가벼움']
# 59  Erdinger Weissbier Dunkel  Weissbier - Dunkelweizen         ['걸쭉', '드라이']
# 34          Krombacher Weizen    Weissbier - Hefeweizen  ['걸쭉', '드라이', '가벼움']
#
#        평점평균  평가횟수
# 50  3.46274  2048
# 59  3.20258  1354
# 34  3.13954   526
