# %%
import pandas as pd
import numpy as np

import warnings

warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('맥주.csv', encoding='utf-8', index_col=0)

# %% [markdown]
# data

# %%
data.shape
# Out:
# (76287, 3)

# %% [markdown]
# # 리뷰 5개 이상인 유저만 남기기

# %%
tmp = data.copy()

# %%
def preprocessing(data, n):
    min_id = data['아이디'].value_counts() >= n
    min_id = min_id[min_id].index.to_list()
    data = data[data['아이디'].isin(min_id)]
    
    min_beer = data['맥주'].value_counts() >= n
    min_beer = min_beer[min_beer].index.to_list()
    data = data[data['맥주'].isin(min_beer)]
    
    return data

# %%
temp=tmp.copy()

for i in range(1,10):
    temp = preprocessing(temp, 5)
    print(temp.shape)
# Out:
# (59164, 3)
# (59164, 3)
# (59164, 3)
# (59164, 3)
# (59164, 3)
# (59164, 3)
# (59164, 3)
# (59164, 3)
# (59164, 3)

# %%
temp.to_csv('맥주_5.csv', encoding='utf-8')

# %% [markdown]
# # 모든 사용자 평점을 기준으로 맥주 유사도 판별

# %%
data = pd.read_csv('맥주_10.csv', encoding='utf-8', index_col=0)

# %%
ratings = data.copy()
# 피벗 테이블을 이용해 유저-아이디 매트릭스 구성
ratings_matrix = ratings.pivot_table('평점', index='아이디', columns='맥주')
ratings_matrix.head(3)
# fillna함수를 이용해 Nan처리
ratings_matrix = ratings_matrix.fillna(0)

# %%
ratings_matrix
# Out:
# 맥주                  Asahi Super Dry  Asahi Super Dry Black  \
# 아이디
# 007lund(92)                     0.0                    0.0
# 00cobraR(1,103)                 0.0                    0.0
# 1010(309)                       2.4                    0.0
# 12HundredBaud(262)              2.3                    0.0
# 16erBlech(561)                  0.0                    0.0
# ...                             ...                    ...
# zenkis(954)                     0.0                    0.0
# ziobarba2000(91)                0.0                    0.0
# zombywoof(483)                  0.0                    0.0
# zvikar(11,249)                  1.2                    2.5
# zvsn(5,413)                     0.0                    0.0
#
# 맥주                  Bavaria 8.6 (Original)  Bavaria Pilsener / Premium Beer  \
# 아이디
# 007lund(92)                            0.0                              0.0
# 00cobraR(1,103)                        0.0                              0.0
# 1010(309)                              0.0                              0.0
# 12HundredBaud(262)                     0.0                              0.0
# 16erBlech(561)                         0.0                              0.0
# ...                                    ...                              ...
# zenkis(954)                            0.0                              0.0
# ziobarba2000(91)                       0.0                              1.6
# zombywoof(483)                         0.0                              1.5
# zvikar(11,249)                         0.0                              0.0
# zvsn(5,413)                            0.0                              0.0
#
# 맥주                  Beck's  Berliner Kindl Jubiläums Pilsener Premium  \
# 아이디
# 007lund(92)            2.6                                        0.0
# 00cobraR(1,103)        2.3                                        0.0
# 1010(309)              2.0                                        0.0
# 12HundredBaud(262)     0.0                                        0.0
# 16erBlech(561)         0.0                                        3.0
# ...                    ...                                        ...
# zenkis(954)            0.0                                        0.0
# ziobarba2000(91)       1.6                                        0.0
# zombywoof(483)         1.8                                        0.0
# zvikar(11,249)         2.1                                        0.0
# zvsn(5,413)            1.9                                        0.0
#
# 맥주                  Bintang Pilsener  Budweiser  Carlsberg Pilsner  \
# 아이디
# 007lund(92)                      0.0        2.0                1.8
# 00cobraR(1,103)                  0.0        1.4                0.0
# 1010(309)                        0.0        0.5                0.0
# 12HundredBaud(262)               0.0        0.0                0.0
# 16erBlech(561)                   0.0        0.0                0.0
# ...                              ...        ...                ...
# zenkis(954)                      0.0        0.0                0.0
# ziobarba2000(91)                 0.0        2.4                0.0
# zombywoof(483)                   0.0        1.0                2.0
# zvikar(11,249)                   0.0        1.4                1.7
# zvsn(5,413)                      0.0        0.0                0.0
#
# 맥주                  Cass Fresh  ...  Stephans Bräu Premium Lager  \
# 아이디                             ...
# 007lund(92)                0.0  ...                          0.0
# 00cobraR(1,103)            0.0  ...                          0.0
# 1010(309)                  0.0  ...                          0.0
# 12HundredBaud(262)         0.0  ...                          0.0
# 16erBlech(561)             0.0  ...                          0.0
# ...                        ...  ...                          ...
# zenkis(954)                0.0  ...                          0.0
# ziobarba2000(91)           0.0  ...                          0.0
# zombywoof(483)             0.0  ...                          0.0
# zvikar(11,249)             1.9  ...                          2.2
# zvsn(5,413)                0.0  ...                          0.0
#
# 맥주                  Stephans Bräu Premium Pilsener  \
# 아이디
# 007lund(92)                                    0.0
# 00cobraR(1,103)                                0.0
# 1010(309)                                      0.0
# 12HundredBaud(262)                             0.0
# 16erBlech(561)                                 0.0
# ...                                            ...
# zenkis(954)                                    0.0
# ziobarba2000(91)                               0.0
# zombywoof(483)                                 0.0
# zvikar(11,249)                                 0.0
# zvsn(5,413)                                    0.0
#
# 맥주                  Suntory The Premium Malt's  Tiger Beer  \
# 아이디
# 007lund(92)                                0.0         0.0
# 00cobraR(1,103)                            0.0         0.0
# 1010(309)                                  0.0         0.0
# 12HundredBaud(262)                         0.0         0.0
# 16erBlech(561)                             0.0         0.0
# ...                                        ...         ...
# zenkis(954)                                0.0         0.0
# ziobarba2000(91)                           0.0         0.0
# zombywoof(483)                             0.0         0.0
# zvikar(11,249)                             0.0         1.7
# zvsn(5,413)                                0.0         0.0
#
# 맥주                  Tiger Radler Lemon  Tsingtao  Tsingtao Wheat Beer  \
# 아이디
# 007lund(92)                        0.0       2.5                  0.0
# 00cobraR(1,103)                    0.0       2.1                  0.0
# 1010(309)                          0.0       0.0                  0.0
# 12HundredBaud(262)                 0.0       0.0                  0.0
# 16erBlech(561)                     0.0       3.0                  0.0
# ...                                ...       ...                  ...
# zenkis(954)                        0.0       0.0                  0.0
# ziobarba2000(91)                   0.0       0.0                  0.0
# zombywoof(483)                     0.0       0.0                  0.0
# zvikar(11,249)                     0.0       1.7                  0.0
# zvsn(5,413)                        0.0       0.0                  0.0
#
# 맥주                  Victoria Bitter  Volfas Engelman Grünberger Hefeweizen  \
# 아이디
# 007lund(92)                     0.0                                    0.0
# 00cobraR(1,103)                 0.0                                    0.0
# 1010(309)                       0.0                                    0.0
# 12HundredBaud(262)              0.0                                    0.0
# 16erBlech(561)                  2.0                                    0.0
# ...                             ...                                    ...
# zenkis(954)                     0.0                                    0.0
# ziobarba2000(91)                0.0                                    0.0
# zombywoof(483)                  0.0                                    0.0
# zvikar(11,249)                  1.4                                    0.0
# zvsn(5,413)                     0.0                                    0.0
#
# 맥주                  Warsteiner Premium Verum
# 아이디
# 007lund(92)                              4.1
# 00cobraR(1,103)                          0.0
# 1010(309)                                0.0
# 12HundredBaud(262)                       0.0
# 16erBlech(561)                           2.5
# ...                                      ...
# zenkis(954)                              0.0
# ziobarba2000(91)                         2.4
# zombywoof(483)                           2.5
# zvikar(11,249)                           2.3
# zvsn(5,413)                              2.5
#
# [2496 rows x 65 columns]

# %%
# 유사도 계산을 위해 트랜스포즈
ratings_matrix_T = ratings_matrix.transpose()
ratings_matrix_T.head(3)
# Out:
# 아이디                     007lund(92)  00cobraR(1,103)  1010(309)  \
# 맥주
# Asahi Super Dry                 0.0              0.0        2.4
# Asahi Super Dry Black           0.0              0.0        0.0
# Bavaria 8.6 (Original)          0.0              0.0        0.0
#
# 아이디                     12HundredBaud(262)  16erBlech(561)  17Beer(1,268)  \
# 맥주
# Asahi Super Dry                        2.3             0.0            3.4
# Asahi Super Dry Black                  0.0             0.0            0.0
# Bavaria 8.6 (Original)                 0.0             0.0            0.0
#
# 아이디                     17thfloor(2,444)  17wojownik(1,308)  184601(206)  \
# 맥주
# Asahi Super Dry                      2.0                0.0          2.4
# Asahi Super Dry Black                0.0                0.0          0.0
# Bavaria 8.6 (Original)               0.0                0.0          0.0
#
# 아이디                     1FastSTi(3,361)  ...  zathrus13(1,776)  zborgerd(187)  \
# 맥주                                       ...
# Asahi Super Dry                     0.0  ...               0.0            1.8
# Asahi Super Dry Black               0.0  ...               0.0            0.0
# Bavaria 8.6 (Original)              0.0  ...               0.0            0.0
#
# 아이디                     zdet444dd(440)  zdk(1,917)  zebracakes(1,339)  \
# 맥주
# Asahi Super Dry                    1.8         1.8                2.7
# Asahi Super Dry Black              0.0         0.0                0.0
# Bavaria 8.6 (Original)             0.0         0.0                0.0
#
# 아이디                     zenkis(954)  ziobarba2000(91)  zombywoof(483)  \
# 맥주
# Asahi Super Dry                 0.0               0.0             0.0
# Asahi Super Dry Black           0.0               0.0             0.0
# Bavaria 8.6 (Original)          0.0               0.0             0.0
#
# 아이디                     zvikar(11,249)  zvsn(5,413)
# 맥주
# Asahi Super Dry                    1.2          0.0
# Asahi Super Dry Black              2.5          0.0
# Bavaria 8.6 (Original)             0.0          0.0
#
# [3 rows x 2496 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# 아이템-유저 매트릭스로부터 코사인 유사도 구하기
item_sim = cosine_similarity(ratings_matrix_T, ratings_matrix_T)

# cosine_similarity()로 반환된 넘파이 행렬에 영화명을 매핑해 DataFrame으로 변환
item_sim_df = pd.DataFrame(data=item_sim, index=ratings_matrix.columns,
                          columns=ratings_matrix.columns)

print(item_sim_df.shape)
item_sim_df.head(3)
# Out:
# (65, 65)
# 맥주                      Asahi Super Dry  Asahi Super Dry Black  \
# 맥주
# Asahi Super Dry                1.000000               0.219475
# Asahi Super Dry Black          0.219475               1.000000
# Bavaria 8.6 (Original)         0.336155               0.119513
#
# 맥주                      Bavaria 8.6 (Original)  \
# 맥주
# Asahi Super Dry                       0.336155
# Asahi Super Dry Black                 0.119513
# Bavaria 8.6 (Original)                1.000000
#
# 맥주                      Bavaria Pilsener / Premium Beer    Beck's  \
# 맥주
# Asahi Super Dry                                0.496283  0.616674
# Asahi Super Dry Black                          0.162549  0.167964
# Bavaria 8.6 (Original)                         0.382242  0.316128
#
# 맥주                      Berliner Kindl Jubiläums Pilsener Premium  \
# 맥주
# Asahi Super Dry                                          0.287000
# Asahi Super Dry Black                                    0.117110
# Bavaria 8.6 (Original)                                   0.225198
#
# 맥주                      Bintang Pilsener  Budweiser  Carlsberg Pilsner  \
# 맥주
# Asahi Super Dry                 0.400071   0.616359           0.591944
# Asahi Super Dry Black           0.205522   0.163879           0.139805
# Bavaria 8.6 (Original)          0.296262   0.298225           0.321233
#
# 맥주                      Cass Fresh  ...  Stephans Bräu Premium Lager  \
# 맥주                                  ...
# Asahi Super Dry           0.303869  ...                     0.130393
# Asahi Super Dry Black     0.286947  ...                     0.073779
# Bavaria 8.6 (Original)    0.243614  ...                     0.166927
#
# 맥주                      Stephans Bräu Premium Pilsener  \
# 맥주
# Asahi Super Dry                               0.148458
# Asahi Super Dry Black                         0.055203
# Bavaria 8.6 (Original)                        0.198763
#
# 맥주                      Suntory The Premium Malt's  Tiger Beer  \
# 맥주
# Asahi Super Dry                           0.264131    0.619950
# Asahi Super Dry Black                     0.377817    0.201275
# Bavaria 8.6 (Original)                    0.104290    0.320936
#
# 맥주                      Tiger Radler Lemon  Tsingtao  Tsingtao Wheat Beer  \
# 맥주
# Asahi Super Dry                   0.102329  0.645360             0.114778
# Asahi Super Dry Black             0.167004  0.153091             0.074836
# Bavaria 8.6 (Original)            0.095430  0.309975             0.095734
#
# 맥주                      Victoria Bitter  \
# 맥주
# Asahi Super Dry                0.421173
# Asahi Super Dry Black          0.220178
# Bavaria 8.6 (Original)         0.286150
#
# 맥주                      Volfas Engelman Grünberger Hefeweizen  \
# 맥주
# Asahi Super Dry                                      0.026709
# Asahi Super Dry Black                                0.026870
# Bavaria 8.6 (Original)                               0.000000
#
# 맥주                      Warsteiner Premium Verum
# 맥주
# Asahi Super Dry                         0.596806
# Asahi Super Dry Black                   0.167260
# Bavaria 8.6 (Original)                  0.321158
#
# [3 rows x 65 columns]

# %%
ratings_matrix.columns
# Out:
# Index(['Asahi Super Dry', 'Asahi Super Dry Black', 'Bavaria 8.6 (Original)',
#        'Bavaria Pilsener / Premium Beer', 'Beck's',
#        'Berliner Kindl Jubiläums Pilsener Premium', 'Bintang Pilsener',
#        'Budweiser', 'Carlsberg Pilsner', 'Cass Fresh',
#        'Castlemaine XXXX Gold Lager', 'Desperados',
#        'Edelweiss Weissbier Snowfresh', 'Egger Grapefruit Radler',
#        'Egger Märzenbier', 'Eichbaum Apostel Bräu', 'Erdinger Weissbier',
#        'Erdinger Weissbier Dunkel',
#        'Franziskaner Hefe-Weissbier / Weissbier Naturtrub',
#        'Gambrinus Originál 10° (Desítka)', 'Grolsch Premium Lager',
#        'Guinness Draught', 'Guinness Original 4.2% (Ireland/UK)',
#        'Harbin Beer', 'Heineken', 'Heineken Dark Lager', 'Hite D (Dry Finish)',
#        'Hite Extra Cold', 'Hite Prime Max', 'Hoegaarden', 'Hoegaarden Rosée',
#        'Holsten Premium Bier', 'Jeju Wit Ale', 'Kirin Ichiban',
#        'Kloud Fitz Super Clear', 'Kloud Original Gravity',
#        'Kozel Černý (Dark) 10°', 'Krombacher Weizen', 'Kronenbourg 1664 Blanc',
#        'Lapin Kulta IV A', 'Leffe Brune / Bruin / Brown',
#        'Löwenbräu Original (4.2%)', 'Miller Genuine Draft (MGD)',
#        'OB Premier Pilsner', 'Paulaner Hefe-Weissbier',
#        'Peroni Nastro Azzurro', 'Pilsner Urquell', 'Red Rock',
#        'Reeper B. Exotisches IPA', 'San Miguel',
#        'Sapporo Premium Beer / Draft Beer', 'Sapporo Yebisu',
#        'Schöfferhofer Grapefruit', 'Stella Artois',
#        'Stephans Bräu Hefe-Weizen Naturtrüb', 'Stephans Bräu Premium Lager',
#        'Stephans Bräu Premium Pilsener', 'Suntory The Premium Malt's',
#        'Tiger Beer', 'Tiger Radler Lemon', 'Tsingtao', 'Tsingtao Wheat Beer',
#        'Victoria Bitter', 'Volfas Engelman Grünberger Hefeweizen',
#        'Warsteiner Premium Verum'],
#       dtype='object', name='맥주')

# %%
# 코젤 맥주와 유사도가 높은 맥주 3개만 추출하기
item_sim_df['Kozel Černý (Dark) 10°'].sort_values(ascending=False)[:5]
# Out:
# 맥주
# Kozel Černý (Dark) 10°         1.000000
# Leffe Brune / Bruin / Brown    0.556338
# Pilsner Urquell                0.533667
# Erdinger Weissbier             0.513917
# Erdinger Weissbier Dunkel      0.511169
# Name: Kozel Černý (Dark) 10°, dtype: float64

# %%
# 호가든 맥주와 유사도가 높은 맥주 5개만 추출하기
item_sim_df['Hoegaarden'].sort_values(ascending=False)[:10]
# Out:
# 맥주
# Hoegaarden                                           1.000000
# Guinness Draught                                     0.825236
# Pilsner Urquell                                      0.825058
# Franziskaner Hefe-Weissbier / Weissbier Naturtrub    0.806542
# Paulaner Hefe-Weissbier                              0.795980
# Stella Artois                                        0.787441
# Erdinger Weissbier                                   0.766370
# Heineken                                             0.766204
# Warsteiner Premium Verum                             0.726723
# Leffe Brune / Bruin / Brown                          0.720695
# Name: Hoegaarden, dtype: float64

# %% [markdown]
# # 아이템 기반 최근접 이웃 CF - 개인화된 맥주 추천

# %% [markdown]
# ## 핵심은 아직 개인이 먹지 않은 맥주를 추천하는 것

# %%
# ratings_arr.dot(item_sim_arr)는 평점 * 맥주 유사도
# ratings_arr는 사용자 u의 아이템 i와 가장 유사도가 높은 Top_N개 아이템에 대한 실제 평점 벡터
# item_sim_arr는 아이템 i와 가장 유사도가 높은 Top_N개 아이템의 유사도 벡터
def predict_rating(ratings_arr, item_sim_arr):
    ratings_pred = ratings_arr.dot(item_sim_arr) / np.array([np.abs(item_sim_arr).sum(axis=1)])
    return ratings_pred

# %%
# 개인화된 예측 평점 구하기
# 평점 value와 유사도 value만 뽑아서 대입
ratings_pred = predict_rating(ratings_matrix.values, item_sim_df.values)
ratings_pred_matrix = pd.DataFrame(data=ratings_pred, index=ratings_matrix.index,
                                  columns = ratings_matrix.columns)

# %%
# 개인별로 계산된 예측 평점
ratings_pred_matrix
# Out:
# 맥주                  Asahi Super Dry  Asahi Super Dry Black  \
# 아이디
# 007lund(92)                0.820129               0.470033
# 00cobraR(1,103)            0.831075               0.475829
# 1010(309)                  0.684728               0.390998
# 12HundredBaud(262)         1.066842               0.687641
# 16erBlech(561)             1.066993               0.748302
# ...                             ...                    ...
# zenkis(954)                0.563719               0.369315
# ziobarba2000(91)           0.541761               0.335926
# zombywoof(483)             1.032241               0.619930
# zvikar(11,249)             1.790695               1.595695
# zvsn(5,413)                1.252215               0.963937
#
# 맥주                  Bavaria 8.6 (Original)  Bavaria Pilsener / Premium Beer  \
# 아이디
# 007lund(92)                       0.644888                         0.752258
# 00cobraR(1,103)                   0.640679                         0.763230
# 1010(309)                         0.499244                         0.591843
# 12HundredBaud(262)                0.913848                         1.004034
# 16erBlech(561)                    0.949833                         1.024799
# ...                                    ...                              ...
# zenkis(954)                       0.485730                         0.538785
# ziobarba2000(91)                  0.459806                         0.552279
# zombywoof(483)                    0.827479                         1.001571
# zvikar(11,249)                    1.626651                         1.734235
# zvsn(5,413)                       1.139026                         1.227283
#
# 맥주                    Beck's  Berliner Kindl Jubiläums Pilsener Premium  \
# 아이디
# 007lund(92)         0.919711                                   0.575619
# 00cobraR(1,103)     0.924861                                   0.593618
# 1010(309)           0.716887                                   0.469462
# 12HundredBaud(262)  1.078731                                   0.866357
# 16erBlech(561)      1.090119                                   1.113806
# ...                      ...                                        ...
# zenkis(954)         0.592727                                   0.483158
# ziobarba2000(91)    0.596765                                   0.410734
# zombywoof(483)      1.139448                                   0.780346
# zvikar(11,249)      1.836444                                   1.597224
# zvsn(5,413)         1.316736                                   1.153420
#
# 맥주                  Bintang Pilsener  Budweiser  Carlsberg Pilsner  \
# 아이디
# 007lund(92)                 0.650242   0.937861           0.883892
# 00cobraR(1,103)             0.656564   0.939060           0.861397
# 1010(309)                   0.511219   0.722164           0.669563
# 12HundredBaud(262)          0.914226   1.089835           1.060798
# 16erBlech(561)              0.982503   1.094316           1.077064
# ...                              ...        ...                ...
# zenkis(954)                 0.491556   0.598593           0.583591
# ziobarba2000(91)            0.457984   0.624403           0.559004
# zombywoof(483)              0.829059   1.148969           1.116677
# zvikar(11,249)              1.619342   1.839291           1.836866
# zvsn(5,413)                 1.125341   1.289516           1.288055
#
# 맥주                  Cass Fresh  ...  Stephans Bräu Premium Lager  \
# 아이디                             ...
# 007lund(92)           0.576695  ...                     0.432144
# 00cobraR(1,103)       0.572502  ...                     0.431084
# 1010(309)             0.448057  ...                     0.337638
# 12HundredBaud(262)    0.770968  ...                     0.615023
# 16erBlech(561)        0.841385  ...                     0.749838
# ...                        ...  ...                          ...
# zenkis(954)           0.413295  ...                     0.350802
# ziobarba2000(91)      0.405505  ...                     0.282808
# zombywoof(483)        0.724560  ...                     0.565518
# zvikar(11,249)        1.564586  ...                     1.580650
# zvsn(5,413)           0.991135  ...                     0.948224
#
# 맥주                  Stephans Bräu Premium Pilsener  \
# 아이디
# 007lund(92)                               0.449797
# 00cobraR(1,103)                           0.454791
# 1010(309)                                 0.370196
# 12HundredBaud(262)                        0.685788
# 16erBlech(561)                            0.817758
# ...                                            ...
# zenkis(954)                               0.391367
# ziobarba2000(91)                          0.315779
# zombywoof(483)                            0.606729
# zvikar(11,249)                            1.529547
# zvsn(5,413)                               1.105287
#
# 맥주                  Suntory The Premium Malt's  Tiger Beer  \
# 아이디
# 007lund(92)                           0.544166    0.792517
# 00cobraR(1,103)                       0.544571    0.802523
# 1010(309)                             0.435149    0.629907
# 12HundredBaud(262)                    0.752933    1.029867
# 16erBlech(561)                        0.841924    1.073288
# ...                                        ...         ...
# zenkis(954)                           0.397431    0.560725
# ziobarba2000(91)                      0.386911    0.532581
# zombywoof(483)                        0.691698    1.008047
# zvikar(11,249)                        1.510765    1.784897
# zvsn(5,413)                           1.022204    1.250674
#
# 맥주                  Tiger Radler Lemon  Tsingtao  Tsingtao Wheat Beer  \
# 아이디
# 007lund(92)                   0.369792  0.895938             0.393015
# 00cobraR(1,103)               0.380372  0.906061             0.407407
# 1010(309)                     0.307404  0.685209             0.337072
# 12HundredBaud(262)            0.585606  1.070996             0.607740
# 16erBlech(561)                0.578864  1.130956             0.676837
# ...                                ...       ...                  ...
# zenkis(954)                   0.265403  0.583296             0.347196
# ziobarba2000(91)              0.260592  0.565532             0.284961
# zombywoof(483)                0.508338  1.081995             0.532922
# zvikar(11,249)                1.189289  1.825242             1.232984
# zvsn(5,413)                   0.740511  1.284234             0.832041
#
# 맥주                  Victoria Bitter  Volfas Engelman Grünberger Hefeweizen  \
# 아이디
# 007lund(92)                0.667877                               0.389589
# 00cobraR(1,103)            0.672270                               0.417385
# 1010(309)                  0.522043                               0.306426
# 12HundredBaud(262)         0.919729                               0.565664
# 16erBlech(561)             1.041151                               0.717237
# ...                             ...                                    ...
# zenkis(954)                0.495295                               0.369660
# ziobarba2000(91)           0.469067                               0.262035
# zombywoof(483)             0.855586                               0.544758
# zvikar(11,249)             1.679483                               1.307002
# zvsn(5,413)                1.152099                               0.858800
#
# 맥주                  Warsteiner Premium Verum
# 아이디
# 007lund(92)                         0.941658
# 00cobraR(1,103)                     0.910195
# 1010(309)                           0.706827
# 12HundredBaud(262)                  1.096561
# 16erBlech(561)                      1.142814
# ...                                      ...
# zenkis(954)                         0.603391
# ziobarba2000(91)                    0.613169
# zombywoof(483)                      1.161932
# zvikar(11,249)                      1.854484
# zvsn(5,413)                         1.352463
#
# [2496 rows x 65 columns]

# %%
from sklearn.metrics import mean_squared_error

# 우리가 예측한 평점과 실제 평점간의 차이를 MSE로 계산
def get_mse(pred, actual):
    # 평점이 있는 실제 영화만 추출
    pred = pred[actual.nonzero()].flatten()
    actual = actual[actual.nonzero()].flatten()
    return mean_squared_error(pred, actual)

print('아이템 기반 모든 최근접 이웃 MSE: ', 
      get_mse(ratings_pred, ratings_matrix.values))
# Out:
# 아이템 기반 모든 최근접 이웃 MSE:  2.5231445841454554

# %%
ratings_matrix
# Out:
# 맥주                  Asahi Super Dry  Asahi Super Dry Black  \
# 아이디
# 007lund(92)                     0.0                    0.0
# 00cobraR(1,103)                 0.0                    0.0
# 1010(309)                       2.4                    0.0
# 12HundredBaud(262)              2.3                    0.0
# 16erBlech(561)                  0.0                    0.0
# ...                             ...                    ...
# zenkis(954)                     0.0                    0.0
# ziobarba2000(91)                0.0                    0.0
# zombywoof(483)                  0.0                    0.0
# zvikar(11,249)                  1.2                    2.5
# zvsn(5,413)                     0.0                    0.0
#
# 맥주                  Bavaria 8.6 (Original)  Bavaria Pilsener / Premium Beer  \
# 아이디
# 007lund(92)                            0.0                              0.0
# 00cobraR(1,103)                        0.0                              0.0
# 1010(309)                              0.0                              0.0
# 12HundredBaud(262)                     0.0                              0.0
# 16erBlech(561)                         0.0                              0.0
# ...                                    ...                              ...
# zenkis(954)                            0.0                              0.0
# ziobarba2000(91)                       0.0                              1.6
# zombywoof(483)                         0.0                              1.5
# zvikar(11,249)                         0.0                              0.0
# zvsn(5,413)                            0.0                              0.0
#
# 맥주                  Beck's  Berliner Kindl Jubiläums Pilsener Premium  \
# 아이디
# 007lund(92)            2.6                                        0.0
# 00cobraR(1,103)        2.3                                        0.0
# 1010(309)              2.0                                        0.0
# 12HundredBaud(262)     0.0                                        0.0
# 16erBlech(561)         0.0                                        3.0
# ...                    ...                                        ...
# zenkis(954)            0.0                                        0.0
# ziobarba2000(91)       1.6                                        0.0
# zombywoof(483)         1.8                                        0.0
# zvikar(11,249)         2.1                                        0.0
# zvsn(5,413)            1.9                                        0.0
#
# 맥주                  Bintang Pilsener  Budweiser  Carlsberg Pilsner  \
# 아이디
# 007lund(92)                      0.0        2.0                1.8
# 00cobraR(1,103)                  0.0        1.4                0.0
# 1010(309)                        0.0        0.5                0.0
# 12HundredBaud(262)               0.0        0.0                0.0
# 16erBlech(561)                   0.0        0.0                0.0
# ...                              ...        ...                ...
# zenkis(954)                      0.0        0.0                0.0
# ziobarba2000(91)                 0.0        2.4                0.0
# zombywoof(483)                   0.0        1.0                2.0
# zvikar(11,249)                   0.0        1.4                1.7
# zvsn(5,413)                      0.0        0.0                0.0
#
# 맥주                  Cass Fresh  ...  Stephans Bräu Premium Lager  \
# 아이디                             ...
# 007lund(92)                0.0  ...                          0.0
# 00cobraR(1,103)            0.0  ...                          0.0
# 1010(309)                  0.0  ...                          0.0
# 12HundredBaud(262)         0.0  ...                          0.0
# 16erBlech(561)             0.0  ...                          0.0
# ...                        ...  ...                          ...
# zenkis(954)                0.0  ...                          0.0
# ziobarba2000(91)           0.0  ...                          0.0
# zombywoof(483)             0.0  ...                          0.0
# zvikar(11,249)             1.9  ...                          2.2
# zvsn(5,413)                0.0  ...                          0.0
#
# 맥주                  Stephans Bräu Premium Pilsener  \
# 아이디
# 007lund(92)                                    0.0
# 00cobraR(1,103)                                0.0
# 1010(309)                                      0.0
# 12HundredBaud(262)                             0.0
# 16erBlech(561)                                 0.0
# ...                                            ...
# zenkis(954)                                    0.0
# ziobarba2000(91)                               0.0
# zombywoof(483)                                 0.0
# zvikar(11,249)                                 0.0
# zvsn(5,413)                                    0.0
#
# 맥주                  Suntory The Premium Malt's  Tiger Beer  \
# 아이디
# 007lund(92)                                0.0         0.0
# 00cobraR(1,103)                            0.0         0.0
# 1010(309)                                  0.0         0.0
# 12HundredBaud(262)                         0.0         0.0
# 16erBlech(561)                             0.0         0.0
# ...                                        ...         ...
# zenkis(954)                                0.0         0.0
# ziobarba2000(91)                           0.0         0.0
# zombywoof(483)                             0.0         0.0
# zvikar(11,249)                             0.0         1.7
# zvsn(5,413)                                0.0         0.0
#
# 맥주                  Tiger Radler Lemon  Tsingtao  Tsingtao Wheat Beer  \
# 아이디
# 007lund(92)                        0.0       2.5                  0.0
# 00cobraR(1,103)                    0.0       2.1                  0.0
# 1010(309)                          0.0       0.0                  0.0
# 12HundredBaud(262)                 0.0       0.0                  0.0
# 16erBlech(561)                     0.0       3.0                  0.0
# ...                                ...       ...                  ...
# zenkis(954)                        0.0       0.0                  0.0
# ziobarba2000(91)                   0.0       0.0                  0.0
# zombywoof(483)                     0.0       0.0                  0.0
# zvikar(11,249)                     0.0       1.7                  0.0
# zvsn(5,413)                        0.0       0.0                  0.0
#
# 맥주                  Victoria Bitter  Volfas Engelman Grünberger Hefeweizen  \
# 아이디
# 007lund(92)                     0.0                                    0.0
# 00cobraR(1,103)                 0.0                                    0.0
# 1010(309)                       0.0                                    0.0
# 12HundredBaud(262)              0.0                                    0.0
# 16erBlech(561)                  2.0                                    0.0
# ...                             ...                                    ...
# zenkis(954)                     0.0                                    0.0
# ziobarba2000(91)                0.0                                    0.0
# zombywoof(483)                  0.0                                    0.0
# zvikar(11,249)                  1.4                                    0.0
# zvsn(5,413)                     0.0                                    0.0
#
# 맥주                  Warsteiner Premium Verum
# 아이디
# 007lund(92)                              4.1
# 00cobraR(1,103)                          0.0
# 1010(309)                                0.0
# 12HundredBaud(262)                       0.0
# 16erBlech(561)                           2.5
# ...                                      ...
# zenkis(954)                              0.0
# ziobarba2000(91)                         2.4
# zombywoof(483)                           2.5
# zvikar(11,249)                           2.3
# zvsn(5,413)                              2.5
#
# [2496 rows x 65 columns]

# %%
ratings_matrix.shape[1]
# Out:
# 65

# %%
ratings_matrix.shape[0]
# Out:
# 2496

# %% [markdown]
# ### 오차가 큰 이유는? : 많은 맥주들의 유사도 벡터를 모두 사용

# %%
pred = np.zeros(ratings_matrix.shape)
pred.shape
# Out:
# (2496, 65)

# %%
# 3개의 col까지만. 3개의 맥주에 대해서 유사도가 큰 5개 선택
top_n_items = [np.argsort(item_sim_df.values[:,3])[:-5:-1]]
top_n_items
# Out:
# [array([ 3, 20, 46, 29], dtype=int64)]

# %%
# 따라서 가장 비슷한 유사도를 가지는 맥주만 유사도 벡터 적용
# 특정 맥주와 비슷한 유사도를 가지는 맥주 Top_N에 대해서만 적용 -> 시간오래걸림

def predict_rating_topsim(ratings_arr, item_sim_arr, n=20):
    # 사용자-아이템 평점 행렬 크기만큼 0으로 채운 예측 행렬 초기화
    pred = np.zeros(ratings_arr.shape)
    
    # 사용자-아이템 평점 행렬의 맥주 개수만큼 루프
    for col in range(ratings_arr.shape[1]):
        # 유사도 행렬에서 유사도가 큰 순으로 n개의 데이터 행렬의 인덱스 반환
        top_n_items = [np.argsort(item_sim_arr[:, col])[:-n-1:-1]]
        # 개인화된 예측 평점 계산 : 각 col 맥주별(1개), 2496 사용자들의 예측평점
        for row in range(ratings_arr.shape[0]):
            pred[row, col] = item_sim_arr[col,:][top_n_items].dot(
            ratings_arr[row, :][top_n_items].T)
            pred[row, col] /= np.sum(item_sim_arr[col,:][top_n_items])
            
    return pred

# %%
ratings_pred = predict_rating_topsim(ratings_matrix.values, item_sim_df.values, n=10)
print('아이템 기반 최근접 TOP-N 이웃 MSE: ', 
      get_mse(ratings_pred, ratings_matrix.values))

# 계산된 예측 평점 데이터는 DataFrame으로 재생성
ratings_pred_matrix = pd.DataFrame(data=ratings_pred, index=ratings_matrix.index,
                                  columns=ratings_matrix.columns)
# Out:
# 아이템 기반 최근접 TOP-N 이웃 MSE:  0.7698908583671297

# %% [markdown]
# # 아이템 기반 추천 : 특정 사용자를 대상으로

# %%
ratings_matrix
# Out:
# 맥주                  Asahi Super Dry  Asahi Super Dry Black  \
# 아이디
# 007lund(92)                     0.0                    0.0
# 00cobraR(1,103)                 0.0                    0.0
# 1010(309)                       2.4                    0.0
# 12HundredBaud(262)              2.3                    0.0
# 16erBlech(561)                  0.0                    0.0
# ...                             ...                    ...
# zenkis(954)                     0.0                    0.0
# ziobarba2000(91)                0.0                    0.0
# zombywoof(483)                  0.0                    0.0
# zvikar(11,249)                  1.2                    2.5
# zvsn(5,413)                     0.0                    0.0
#
# 맥주                  Bavaria 8.6 (Original)  Bavaria Pilsener / Premium Beer  \
# 아이디
# 007lund(92)                            0.0                              0.0
# 00cobraR(1,103)                        0.0                              0.0
# 1010(309)                              0.0                              0.0
# 12HundredBaud(262)                     0.0                              0.0
# 16erBlech(561)                         0.0                              0.0
# ...                                    ...                              ...
# zenkis(954)                            0.0                              0.0
# ziobarba2000(91)                       0.0                              1.6
# zombywoof(483)                         0.0                              1.5
# zvikar(11,249)                         0.0                              0.0
# zvsn(5,413)                            0.0                              0.0
#
# 맥주                  Beck's  Berliner Kindl Jubiläums Pilsener Premium  \
# 아이디
# 007lund(92)            2.6                                        0.0
# 00cobraR(1,103)        2.3                                        0.0
# 1010(309)              2.0                                        0.0
# 12HundredBaud(262)     0.0                                        0.0
# 16erBlech(561)         0.0                                        3.0
# ...                    ...                                        ...
# zenkis(954)            0.0                                        0.0
# ziobarba2000(91)       1.6                                        0.0
# zombywoof(483)         1.8                                        0.0
# zvikar(11,249)         2.1                                        0.0
# zvsn(5,413)            1.9                                        0.0
#
# 맥주                  Bintang Pilsener  Budweiser  Carlsberg Pilsner  \
# 아이디
# 007lund(92)                      0.0        2.0                1.8
# 00cobraR(1,103)                  0.0        1.4                0.0
# 1010(309)                        0.0        0.5                0.0
# 12HundredBaud(262)               0.0        0.0                0.0
# 16erBlech(561)                   0.0        0.0                0.0
# ...                              ...        ...                ...
# zenkis(954)                      0.0        0.0                0.0
# ziobarba2000(91)                 0.0        2.4                0.0
# zombywoof(483)                   0.0        1.0                2.0
# zvikar(11,249)                   0.0        1.4                1.7
# zvsn(5,413)                      0.0        0.0                0.0
#
# 맥주                  Cass Fresh  ...  Stephans Bräu Premium Lager  \
# 아이디                             ...
# 007lund(92)                0.0  ...                          0.0
# 00cobraR(1,103)            0.0  ...                          0.0
# 1010(309)                  0.0  ...                          0.0
# 12HundredBaud(262)         0.0  ...                          0.0
# 16erBlech(561)             0.0  ...                          0.0
# ...                        ...  ...                          ...
# zenkis(954)                0.0  ...                          0.0
# ziobarba2000(91)           0.0  ...                          0.0
# zombywoof(483)             0.0  ...                          0.0
# zvikar(11,249)             1.9  ...                          2.2
# zvsn(5,413)                0.0  ...                          0.0
#
# 맥주                  Stephans Bräu Premium Pilsener  \
# 아이디
# 007lund(92)                                    0.0
# 00cobraR(1,103)                                0.0
# 1010(309)                                      0.0
# 12HundredBaud(262)                             0.0
# 16erBlech(561)                                 0.0
# ...                                            ...
# zenkis(954)                                    0.0
# ziobarba2000(91)                               0.0
# zombywoof(483)                                 0.0
# zvikar(11,249)                                 0.0
# zvsn(5,413)                                    0.0
#
# 맥주                  Suntory The Premium Malt's  Tiger Beer  \
# 아이디
# 007lund(92)                                0.0         0.0
# 00cobraR(1,103)                            0.0         0.0
# 1010(309)                                  0.0         0.0
# 12HundredBaud(262)                         0.0         0.0
# 16erBlech(561)                             0.0         0.0
# ...                                        ...         ...
# zenkis(954)                                0.0         0.0
# ziobarba2000(91)                           0.0         0.0
# zombywoof(483)                             0.0         0.0
# zvikar(11,249)                             0.0         1.7
# zvsn(5,413)                                0.0         0.0
#
# 맥주                  Tiger Radler Lemon  Tsingtao  Tsingtao Wheat Beer  \
# 아이디
# 007lund(92)                        0.0       2.5                  0.0
# 00cobraR(1,103)                    0.0       2.1                  0.0
# 1010(309)                          0.0       0.0                  0.0
# 12HundredBaud(262)                 0.0       0.0                  0.0
# 16erBlech(561)                     0.0       3.0                  0.0
# ...                                ...       ...                  ...
# zenkis(954)                        0.0       0.0                  0.0
# ziobarba2000(91)                   0.0       0.0                  0.0
# zombywoof(483)                     0.0       0.0                  0.0
# zvikar(11,249)                     0.0       1.7                  0.0
# zvsn(5,413)                        0.0       0.0                  0.0
#
# 맥주                  Victoria Bitter  Volfas Engelman Grünberger Hefeweizen  \
# 아이디
# 007lund(92)                     0.0                                    0.0
# 00cobraR(1,103)                 0.0                                    0.0
# 1010(309)                       0.0                                    0.0
# 12HundredBaud(262)              0.0                                    0.0
# 16erBlech(561)                  2.0                                    0.0
# ...                             ...                                    ...
# zenkis(954)                     0.0                                    0.0
# ziobarba2000(91)                0.0                                    0.0
# zombywoof(483)                  0.0                                    0.0
# zvikar(11,249)                  1.4                                    0.0
# zvsn(5,413)                     0.0                                    0.0
#
# 맥주                  Warsteiner Premium Verum
# 아이디
# 007lund(92)                              4.1
# 00cobraR(1,103)                          0.0
# 1010(309)                                0.0
# 12HundredBaud(262)                       0.0
# 16erBlech(561)                           2.5
# ...                                      ...
# zenkis(954)                              0.0
# ziobarba2000(91)                         2.4
# zombywoof(483)                           2.5
# zvikar(11,249)                           2.3
# zvsn(5,413)                              2.5
#
# [2496 rows x 65 columns]

# %%
# username='snoworsummer(8,581)'
username='007lund(92)'

# %%
# 특정 유저 ex) 11번 유저 대상으로 맥주추천
user_rating_id = ratings_matrix.loc[username, :]
# 11번 유저가 먹었던 맥주들 출력
user_rating_id[user_rating_id > 0].sort_values(ascending=False)[:10]
# Out:
# 맥주
# Warsteiner Premium Verum             4.1
# Guinness Draught                     3.7
# Paulaner Hefe-Weissbier              3.3
# Pilsner Urquell                      3.1
# Stella Artois                        2.9
# Sapporo Premium Beer / Draft Beer    2.6
# Beck's                               2.6
# Tsingtao                             2.5
# Miller Genuine Draft (MGD)           2.0
# Heineken                             2.0
# Name: 007lund(92), dtype: float64

# %%
# 사용자가 안 먹어본 맥주를 추천하자.
def get_not_tried_beer(ratings_matrix, userId):
    # userId로 입력받은 사용자의 모든 맥주 정보를 추출해 Series로 반환
    # 반환된 user_rating은 영화명(title)을 인덱스로 가지는 Series 객체
    user_rating = ratings_matrix.loc[userId, :]
    
    # user_rating이 0보다 크면 기존에 관란함 영화.
    # 대상 인덱스를 추출해 list 객체로 만듦
    tried = user_rating[user_rating>0].index.tolist()
    
    # 모든 맥주명을 list 객체로 만듦
    beer_list = ratings_matrix.columns.tolist()
    
    # list comprehension으로 tried에 해당하는 영화는 beer_list에서 제외
    not_tried = [beer for beer in beer_list if beer not in tried]
    
    return not_tried

# %%
# 예측 평점 DataFrame에서 사용자 id 인덱스와 not_tried로 들어온 맥주명 추출 후
# 가장 예측 평점이 높은 순으로 정렬
def recomm_beer_by_userid(pred_df, userId, not_tried, top_n):
    recomm_beer = pred_df.loc[userId, not_tried].sort_values(ascending=False)[:top_n]
    return recomm_beer

# %%
# 유저가 먹지 않은 맥주이름 추출
not_tried = get_not_tried_beer(ratings_matrix, username)
not_tried
# Out:
# ['Asahi Super Dry',
#  'Asahi Super Dry Black',
#  'Bavaria 8.6 (Original)',
#  'Bavaria Pilsener / Premium Beer',
#  'Berliner Kindl Jubiläums Pilsener Premium',
#  'Bintang Pilsener',
#  'Cass Fresh',
#  'Castlemaine XXXX Gold Lager',
#  'Desperados',
#  'Edelweiss Weissbier Snowfresh',
#  'Egger Grapefruit Radler',
#  'Egger Märzenbier',
#  'Eichbaum Apostel Bräu',
#  'Erdinger Weissbier',
#  'Erdinger Weissbier Dunkel',
#  'Franziskaner Hefe-Weissbier / Weissbier Naturtrub',
#  'Gambrinus Originál 10° (Desítka)',
#  'Grolsch Premium Lager',
#  'Guinness Original 4.2% (Ireland/UK)',
#  'Harbin Beer',
#  'Heineken Dark Lager',
#  'Hite D (Dry Finish)',
#  'Hite Extra Cold',
#  'Hite Prime Max',
#  'Hoegaarden',
#  'Hoegaarden Rosée',
#  'Holsten Premium Bier',
#  'Jeju Wit Ale',
#  'Kirin Ichiban',
#  'Kloud Fitz Super Clear',
#  'Kloud Original Gravity',
#  'Kozel Černý (Dark) 10°',
#  'Krombacher Weizen',
#  'Kronenbourg 1664 Blanc',
#  'Lapin Kulta IV A',
#  'Leffe Brune / Bruin / Brown',
#  'Löwenbräu Original (4.2%)',
#  'OB Premier Pilsner',
#  'Peroni Nastro Azzurro',
#  'Red Rock',
#  'Reeper B. Exotisches IPA',
#  'San Miguel',
#  'Sapporo Yebisu',
#  'Schöfferhofer Grapefruit',
#  'Stephans Bräu Hefe-Weizen Naturtrüb',
#  'Stephans Bräu Premium Lager',
#  'Stephans Bräu Premium Pilsener',
#  "Suntory The Premium Malt's",
#  'Tiger Beer',
#  'Tiger Radler Lemon',
#  'Tsingtao Wheat Beer',
#  'Victoria Bitter',
#  'Volfas Engelman Grünberger Hefeweizen']

# %%
# 아이템 기반의 최근접 이웃 CF로 맥주 추천
recomm_beer = recomm_beer_by_userid(ratings_pred_matrix, username, not_tried, top_n=10)
recomm_beer = pd.DataFrame(data=recomm_beer.values, index=recomm_beer.index,
                          columns=['예측평점'])

# %%
recomm_beer
# Out:
#                                                        예측평점
# 맥주
# Grolsch Premium Lager                              2.266929
# Heineken Dark Lager                                1.976256
# Hoegaarden                                         1.874423
# Franziskaner Hefe-Weissbier / Weissbier Naturtrub  1.853702
# Bavaria Pilsener / Premium Beer                    1.672898
# Asahi Super Dry                                    1.662351
# Kirin Ichiban                                      1.655398
# Erdinger Weissbier Dunkel                          1.508589
# Leffe Brune / Bruin / Brown                        1.417283
# Erdinger Weissbier                                 1.409270

# %%
add1 = ['신구현', 'Hoegaarden', 3.5]
add2 = ['신구현', 'Erdinger Weissbier', 3.0]
add3 = ['신구현', 'Asahi Super Dry', 4.0]
