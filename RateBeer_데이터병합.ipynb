# %%
import pandas as pd

# %%
tmp = pd.read_csv(r'C:\Users\Ghyeon\SBA_Rec\크롤링\data\beer_n_1.csv', encoding='utf-8')
tmp.head()
# Out:
#    Unnamed: 0                                               맥주정보  \
# 0           0  HighSparkDiesel(597)\n🇹🇼Taipei City, Taiwan\n1...
# 1           1  futre7(339)\n🇹🇼Taipei, Taiwan\n1.8February 22,...
# 2           2  Oakes(25,346)\n🇨🇦Kelowna, Canada\n1.7January 1...
# 3           3  YantarCoast(3,141)\n🇷🇺Moscow, Russia\n1.5Decem...
# 4           4  mkel07(8,991)\n🇦🇺Brisbane, Australia\n2.2Septe...
#
#                검색이름                    맥주이름  인덱스                    편의점
# 0  fitz super clear  Kloud Fitz Super Clear    1  CU GS25 7/11 ministop
# 1  fitz super clear  Kloud Fitz Super Clear    1  CU GS25 7/11 ministop
# 2  fitz super clear  Kloud Fitz Super Clear    1  CU GS25 7/11 ministop
# 3  fitz super clear  Kloud Fitz Super Clear    1  CU GS25 7/11 ministop
# 4  fitz super clear  Kloud Fitz Super Clear    1  CU GS25 7/11 ministop

# %%
data = pd.DataFrame(data=[], columns=['맥주정보', '검색이름', '맥주이름'])

# %%
for i in range(0, 656):
    
    try : 
        print(r'C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_'+str(i)+'.csv')
        tmp = pd.read_csv(r'C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_'+str(i)+'.csv', index_col=0)
        data = pd.concat([data,tmp])
    except :
        print(i, '번째에서 오류가 발생했습니다. 다음 파일로 넘어갑니다.')
# Out:
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_0.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_1.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_2.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_3.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_4.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_5.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_6.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_7.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_8.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_9.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_10.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_11.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_12.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_13.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_14.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_15.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_16.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_17.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_18.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_19.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_20.csv
# C:\Users\Ghyeon\SBA_Rec\크롤링\beer_n_21.csv
# ...

# %%
data.to_csv('추가맥주종합데이터.csv', encoding='utf-8')

# %%
data.to_csv('Raw_data.csv', encoding='utf-8')

# %%
data = data[['맥주이름','맥주정보','편의점']]

# %%
data.to_csv('beer_rawdata.csv', encoding='utf-8')

# %%
data.head()
# Out:
#                      맥주이름                                               맥주정보  \
# 0  Kloud Original Gravity  patjenner(3)\n4.0December 31, 2020\nStrong hop...
# 1  Kloud Original Gravity  pictoman(1,959)\n🇨🇦Vancouver, Canada\n2.0April...
# 2  Kloud Original Gravity  snoworsummer(8,581)\n🇺🇸baltimore, United State...
# 3  Kloud Original Gravity  mickmac(726)\n🇦🇺Ngunnawal, Australia\n2.9Febru...
# 4  Kloud Original Gravity  GuideDogSaint(2,549)\n🇨🇳Xiamen, China\n2.2Febr...
#
#                      편의점
# 0  CU GS25 7/11 ministop
# 1  CU GS25 7/11 ministop
# 2  CU GS25 7/11 ministop
# 3  CU GS25 7/11 ministop
# 4  CU GS25 7/11 ministop

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109627 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   맥주이름    109627 non-null  object
#  1   맥주정보    109627 non-null  object
#  2   편의점     109627 non-null  object
# dtypes: object(3)
# memory usage: 3.3+ MB
