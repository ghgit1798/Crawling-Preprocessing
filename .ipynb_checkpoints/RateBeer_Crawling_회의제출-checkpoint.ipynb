# %%
import pandas as pd
import numpy as np
import time

import re

from selenium import webdriver

# %%
# 수집할 맥주 종류 기입
beers = ['cass', 'hite', 'kloud', 'kloud fitz' ,'guiness draught', 'tsingtao',
         'blanc', 'heineken', 'stella', 'hogaarden', 'sapporo premium',
        'ashhi', 'budweiser', 'pilsner urquell', 'kozel dark', ' Ob golden larger',
        'filite']

# %%
# 데이터 프레임 생성
data = pd.DataFrame(data=[], columns=['맥주정보'])

# %%
# 테스트용 예제 파일
beers = ['kloud fitz', 'kloud', 'cass', 'hite']

# %%
chromedriver = 'chromedriver.exe'
url = 'https://www.ratebeer.com/search?tab=beer'

# %%
driver = webdriver.Chrome(chromedriver)
driver.get(url)
time.sleep(1)

# %% [markdown]
# ## 실제 구현 함수

# %%
type(1)
# Out:
# int

# %%
def crawl(driver, beer, data):
    # url open
    print('url_open... {0} 맥주 데이터를 수집합니다..'.format(beer))
    driver = webdriver.Chrome(chromedriver)
    driver.get(url)
    
    # 맥주 검색
    time.sleep(3)
    element = driver.find_element_by_xpath('//*[@id="root"]/div[2]/header/div[2]/div[1]/div[2]/div/div/input')
    time.sleep(2)
    element.click()
    time.sleep(3)
    element.send_keys(beer)
    time.sleep(5)
    
    # 상품 선택
    driver.find_element_by_xpath('//*[@id="root"]/div[2]/header/div[2]/div[1]/div[2]/div/div[2]/a[1]/div/div[2]').click()
    
    while 1:
        try :
            # 전체 리뷰 수 수집
            time.sleep(2)
            string = driver.find_element_by_class_name('MuiTypography-root.Text___StyledTypographyTypeless-bukSfn.pzIrn.text-500.colorized__WrappedComponent-hrwcZr.hwjOn.MuiTypography-h6').text

            # ,가 포함되어 있는지에 대한 로직
            extract = re.compile('[0-9]*,*[0-9]+')
            str_num = extract.findall(string)
            str_num = str_num[0]
            
            print('성공... while문을 탈출합니다.')
            break
        except :
            print('오류 발생.. 다시 시작합니다.')
    
    if ',' in str_num:
        str_num = str_num.split(',')
        str_num = int(str_num[0]+str_num[1])
        num = str_num
    else:
        num = int(str_num)
        
    print('num = ',num)
    
    page_num = num // 15 + 1

    for i in range(page_num+1):
        print(i+1, '번째 페이지입니다.')

        # Score breakdown 클릭
        time.sleep(2)
    #     element = driver.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/div/div/div/div[2]/div[4]/div/div[2]/div[1]/div[2]')
    #     element = driver.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/div/div/div/div[2]/div[4]/div/div[2]/div[1]/div[2]')
        element = driver.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/div/div/div/div[2]/div[4]/div/div[2]/div[1]/div[2]')
        time.sleep(2)
        driver.execute_script("arguments[0].click();", element)

        # 전체 맥주 정보를 통쨰로 수집
        tmp = []
        beer = driver.find_elements_by_css_selector('.px-4.fj-s.f-wrap')

        # 수집한 것을 데이터프레임에 저장
        for i in range(len(beer)):
            tmp.append(beer[i].text)

        tmp = pd.DataFrame(data=tmp, columns=['맥주정보'])
        data = pd.concat([data, tmp])

        # div, span, title 태그 후 속성은 class 외에도 사용 가능
        try :        
            time.sleep(2)
            element = driver.find_element_by_xpath('//button[@title="Next page"]/span[@class="MuiIconButton-label"]')
            driver.execute_script("arguments[0].click();", element)
        except:
            print('마지막 페이지입니다.')
    
    driver.quit()
    
    return data

# %%
for beer in beers:
    data = crawl(driver, beer, data)
# Out:
# url_open... cass 맥주 데이터를 수집합니다..
# 성공... while문을 탈출합니다.
# num =  292
# 1 번째 페이지입니다.
# 2 번째 페이지입니다.
# 3 번째 페이지입니다.
# 4 번째 페이지입니다.
# 5 번째 페이지입니다.
# 6 번째 페이지입니다.
# 7 번째 페이지입니다.
# 8 번째 페이지입니다.
# 9 번째 페이지입니다.
# 10 번째 페이지입니다.
# 11 번째 페이지입니다.
# 12 번째 페이지입니다.
# 13 번째 페이지입니다.
# 14 번째 페이지입니다.
# 15 번째 페이지입니다.
# 16 번째 페이지입니다.
# 17 번째 페이지입니다.
# 18 번째 페이지입니다.
# 19 번째 페이지입니다.
# 20 번째 페이지입니다.
# 21 번째 페이지입니다.
# url_open... hite 맥주 데이터를 수집합니다..
# 오류 발생.. 다시 시작합니다.
# 성공... while문을 탈출합니다.
# num =  785
# 1 번째 페이지입니다.
# 2 번째 페이지입니다.
# 3 번째 페이지입니다.
# 4 번째 페이지입니다.
# 5 번째 페이지입니다.
# 6 번째 페이지입니다.
# 7 번째 페이지입니다.
# 8 번째 페이지입니다.
# 9 번째 페이지입니다.
# 10 번째 페이지입니다.
# 11 번째 페이지입니다.
# 12 번째 페이지입니다.
# 13 번째 페이지입니다.
# 14 번째 페이지입니다.
# 15 번째 페이지입니다.
# 16 번째 페이지입니다.
# 17 번째 페이지입니다.
# 18 번째 페이지입니다.
# 19 번째 페이지입니다.
# 20 번째 페이지입니다.
# 21 번째 페이지입니다.
# 22 번째 페이지입니다.
# 23 번째 페이지입니다.
# 24 번째 페이지입니다.
# 25 번째 페이지입니다.
# 26 번째 페이지입니다.
# 27 번째 페이지입니다.
# 28 번째 페이지입니다.
# 29 번째 페이지입니다.
# 30 번째 페이지입니다.
# 31 번째 페이지입니다.
# 32 번째 페이지입니다.
# 33 번째 페이지입니다.
# 34 번째 페이지입니다.
# 35 번째 페이지입니다.
# 36 번째 페이지입니다.
# 37 번째 페이지입니다.
# 38 번째 페이지입니다.
# 39 번째 페이지입니다.
# 40 번째 페이지입니다.
# 41 번째 페이지입니다.
# 42 번째 페이지입니다.
# 43 번째 페이지입니다.
# 44 번째 페이지입니다.
# 45 번째 페이지입니다.
# 46 번째 페이지입니다.
# 47 번째 페이지입니다.
# 48 번째 페이지입니다.
# 49 번째 페이지입니다.
# 50 번째 페이지입니다.
# 51 번째 페이지입니다.
# 52 번째 페이지입니다.
# 53 번째 페이지입니다.
# 54 번째 페이지입니다.
# url_open... kloud 맥주 데이터를 수집합니다..
# 성공... while문을 탈출합니다.
# num =  103
# 1 번째 페이지입니다.
# 2 번째 페이지입니다.
# 3 번째 페이지입니다.
# 4 번째 페이지입니다.
# 5 번째 페이지입니다.
# 6 번째 페이지입니다.
# 7 번째 페이지입니다.
# 8 번째 페이지입니다.
# url_open... kloud fitz 맥주 데이터를 수집합니다..
# 성공... while문을 탈출합니다.
# num =  26
# 1 번째 페이지입니다.
# 2 번째 페이지입니다.
# 3 번째 페이지입니다.
# url_open... guiness draught 맥주 데이터를 수집합니다..
# 성공... while문을 탈출합니다.
# num =  5708
# 1 번째 페이지입니다.
# 2 번째 페이지입니다.
# 3 번째 페이지입니다.
# 4 번째 페이지입니다.
# 5 번째 페이지입니다.
# 6 번째 페이지입니다.
# 7 번째 페이지입니다.
# 8 번째 페이지입니다.
# 9 번째 페이지입니다.
# 10 번째 페이지입니다.
# 11 번째 페이지입니다.
# 12 번째 페이지입니다.
# 13 번째 페이지입니다.
# 14 번째 페이지입니다.
# 15 번째 페이지입니다.
# 16 번째 페이지입니다.
# 17 번째 페이지입니다.
# 18 번째 페이지입니다.
# 19 번째 페이지입니다.
# 20 번째 페이지입니다.
# 21 번째 페이지입니다.
# 22 번째 페이지입니다.
# 23 번째 페이지입니다.
# 24 번째 페이지입니다.
# 25 번째 페이지입니다.
# 26 번째 페이지입니다.
# 27 번째 페이지입니다.
# 28 번째 페이지입니다.
# 29 번째 페이지입니다.
# 30 번째 페이지입니다.
# 31 번째 페이지입니다.
# 32 번째 페이지입니다.
# 33 번째 페이지입니다.
# 34 번째 페이지입니다.
# 35 번째 페이지입니다.
# 36 번째 페이지입니다.
# 37 번째 페이지입니다.
# 38 번째 페이지입니다.
# 39 번째 페이지입니다.
# 40 번째 페이지입니다.
# 41 번째 페이지입니다.
# 42 번째 페이지입니다.
# 43 번째 페이지입니다.
# 44 번째 페이지입니다.
# 45 번째 페이지입니다.
# 46 번째 페이지입니다.
# 47 번째 페이지입니다.
# 48 번째 페이지입니다.
# 49 번째 페이지입니다.
# 50 번째 페이지입니다.
# 51 번째 페이지입니다.
# 52 번째 페이지입니다.
# 53 번째 페이지입니다.
# 54 번째 페이지입니다.
# 55 번째 페이지입니다.
# 56 번째 페이지입니다.
# 57 번째 페이지입니다.
# 58 번째 페이지입니다.
# 59 번째 페이지입니다.
# 60 번째 페이지입니다.
# 61 번째 페이지입니다.
# 62 번째 페이지입니다.
# 63 번째 페이지입니다.
# 64 번째 페이지입니다.
# 65 번째 페이지입니다.
# 66 번째 페이지입니다.
# 67 번째 페이지입니다.
# 68 번째 페이지입니다.
# 69 번째 페이지입니다.
# 70 번째 페이지입니다.
# 71 번째 페이지입니다.
# 72 번째 페이지입니다.
# 73 번째 페이지입니다.
# 74 번째 페이지입니다.
# 75 번째 페이지입니다.
# 76 번째 페이지입니다.
# 77 번째 페이지입니다.
# 78 번째 페이지입니다.
# 79 번째 페이지입니다.
# 80 번째 페이지입니다.
# 81 번째 페이지입니다.
# 82 번째 페이지입니다.
# 83 번째 페이지입니다.
# 84 번째 페이지입니다.
# 85 번째 페이지입니다.
# 86 번째 페이지입니다.
# 87 번째 페이지입니다.
# 88 번째 페이지입니다.
# 89 번째 페이지입니다.
# 90 번째 페이지입니다.
# 91 번째 페이지입니다.
# 92 번째 페이지입니다.
# 93 번째 페이지입니다.
# 94 번째 페이지입니다.
# 95 번째 페이지입니다.
# 96 번째 페이지입니다.
# 97 번째 페이지입니다.
# 98 번째 페이지입니다.
# 99 번째 페이지입니다.
# 100 번째 페이지입니다.
# 101 번째 페이지입니다.
# 102 번째 페이지입니다.
# 103 번째 페이지입니다.
# 104 번째 페이지입니다.
# 105 번째 페이지입니다.
# 106 번째 페이지입니다.
# 107 번째 페이지입니다.
# 108 번째 페이지입니다.
# 109 번째 페이지입니다.
# 110 번째 페이지입니다.
# 111 번째 페이지입니다.
# 112 번째 페이지입니다.
# 113 번째 페이지입니다.
# 114 번째 페이지입니다.
# 115 번째 페이지입니다.
# 116 번째 페이지입니다.
# 117 번째 페이지입니다.
# 118 번째 페이지입니다.
# 119 번째 페이지입니다.
# 120 번째 페이지입니다.
# 121 번째 페이지입니다.
# 122 번째 페이지입니다.
# 123 번째 페이지입니다.
# 124 번째 페이지입니다.
# 125 번째 페이지입니다.
# 126 번째 페이지입니다.
# 127 번째 페이지입니다.
# 128 번째 페이지입니다.
# 129 번째 페이지입니다.
# 130 번째 페이지입니다.
# 131 번째 페이지입니다.
# 132 번째 페이지입니다.
# 133 번째 페이지입니다.
# 134 번째 페이지입니다.
# 135 번째 페이지입니다.
# 136 번째 페이지입니다.
# 137 번째 페이지입니다.
# 138 번째 페이지입니다.
# 139 번째 페이지입니다.
# 140 번째 페이지입니다.
# 141 번째 페이지입니다.
# 142 번째 페이지입니다.
# 143 번째 페이지입니다.
# 144 번째 페이지입니다.
# 145 번째 페이지입니다.
# 146 번째 페이지입니다.
# 147 번째 페이지입니다.
# 148 번째 페이지입니다.
# 149 번째 페이지입니다.
# 150 번째 페이지입니다.
# 151 번째 페이지입니다.
# 152 번째 페이지입니다.
# 153 번째 페이지입니다.
# 154 번째 페이지입니다.
# 155 번째 페이지입니다.
# 156 번째 페이지입니다.
# 157 번째 페이지입니다.
# 158 번째 페이지입니다.
# 159 번째 페이지입니다.
# 160 번째 페이지입니다.
# 161 번째 페이지입니다.
# 162 번째 페이지입니다.
# 163 번째 페이지입니다.
# 164 번째 페이지입니다.
# 165 번째 페이지입니다.
# 166 번째 페이지입니다.
# 167 번째 페이지입니다.
# 168 번째 페이지입니다.
# 169 번째 페이지입니다.
# 170 번째 페이지입니다.
# 171 번째 페이지입니다.
# 172 번째 페이지입니다.
# 173 번째 페이지입니다.
# 174 번째 페이지입니다.
# 175 번째 페이지입니다.
# 176 번째 페이지입니다.
# 177 번째 페이지입니다.
# 178 번째 페이지입니다.
# 179 번째 페이지입니다.
# 180 번째 페이지입니다.
# 181 번째 페이지입니다.
# 182 번째 페이지입니다.
# 183 번째 페이지입니다.
# 184 번째 페이지입니다.
# 185 번째 페이지입니다.
# 186 번째 페이지입니다.
# 187 번째 페이지입니다.
# 188 번째 페이지입니다.
# 189 번째 페이지입니다.
# 190 번째 페이지입니다.
# 191 번째 페이지입니다.
# 192 번째 페이지입니다.
# 193 번째 페이지입니다.
# 194 번째 페이지입니다.
# 195 번째 페이지입니다.
# 196 번째 페이지입니다.
# 197 번째 페이지입니다.
# 198 번째 페이지입니다.
# 199 번째 페이지입니다.
# 200 번째 페이지입니다.
# 201 번째 페이지입니다.
# 202 번째 페이지입니다.
# 203 번째 페이지입니다.
# 204 번째 페이지입니다.
# 205 번째 페이지입니다.
# 206 번째 페이지입니다.
# 207 번째 페이지입니다.
# 208 번째 페이지입니다.
# 209 번째 페이지입니다.
# 210 번째 페이지입니다.
# 211 번째 페이지입니다.
# 212 번째 페이지입니다.
# 213 번째 페이지입니다.
# 214 번째 페이지입니다.
# 215 번째 페이지입니다.
# 216 번째 페이지입니다.
# 217 번째 페이지입니다.
# 218 번째 페이지입니다.
# 219 번째 페이지입니다.
# 220 번째 페이지입니다.
# 221 번째 페이지입니다.
# 222 번째 페이지입니다.
# 223 번째 페이지입니다.
# 224 번째 페이지입니다.
# 225 번째 페이지입니다.
# 226 번째 페이지입니다.
# 227 번째 페이지입니다.
# 228 번째 페이지입니다.
# 229 번째 페이지입니다.
# 230 번째 페이지입니다.
# 231 번째 페이지입니다.
# 232 번째 페이지입니다.
# 233 번째 페이지입니다.
# 234 번째 페이지입니다.
# 235 번째 페이지입니다.
# 236 번째 페이지입니다.
# 237 번째 페이지입니다.
# 238 번째 페이지입니다.
# 239 번째 페이지입니다.
# 240 번째 페이지입니다.
# 241 번째 페이지입니다.
# 242 번째 페이지입니다.
# 243 번째 페이지입니다.
# 244 번째 페이지입니다.
# 245 번째 페이지입니다.
# 246 번째 페이지입니다.
# 247 번째 페이지입니다.
# 248 번째 페이지입니다.
# 249 번째 페이지입니다.
# 250 번째 페이지입니다.
# 251 번째 페이지입니다.
# 252 번째 페이지입니다.
# 253 번째 페이지입니다.
# 254 번째 페이지입니다.
# 255 번째 페이지입니다.
# 256 번째 페이지입니다.
# 257 번째 페이지입니다.
# 258 번째 페이지입니다.
# 259 번째 페이지입니다.
# 260 번째 페이지입니다.
# 261 번째 페이지입니다.
# 262 번째 페이지입니다.
# 263 번째 페이지입니다.
# 264 번째 페이지입니다.
# 265 번째 페이지입니다.
# 266 번째 페이지입니다.
# 267 번째 페이지입니다.
# 268 번째 페이지입니다.
# 269 번째 페이지입니다.
# 270 번째 페이지입니다.
# 271 번째 페이지입니다.
# 272 번째 페이지입니다.
# 273 번째 페이지입니다.
# 274 번째 페이지입니다.
# 275 번째 페이지입니다.
# 276 번째 페이지입니다.
# 277 번째 페이지입니다.
# 278 번째 페이지입니다.
# 279 번째 페이지입니다.
# 280 번째 페이지입니다.
# 281 번째 페이지입니다.
# 282 번째 페이지입니다.
# 283 번째 페이지입니다.
# 284 번째 페이지입니다.
# 285 번째 페이지입니다.
# 286 번째 페이지입니다.
# 287 번째 페이지입니다.
# 288 번째 페이지입니다.
# 289 번째 페이지입니다.
# 290 번째 페이지입니다.
# 291 번째 페이지입니다.
# 292 번째 페이지입니다.
# 293 번째 페이지입니다.
# 294 번째 페이지입니다.
# 295 번째 페이지입니다.
# 296 번째 페이지입니다.
# 297 번째 페이지입니다.
# 298 번째 페이지입니다.
# 299 번째 페이지입니다.
# 300 번째 페이지입니다.
# 301 번째 페이지입니다.
# 302 번째 페이지입니다.
# 303 번째 페이지입니다.
# 304 번째 페이지입니다.
# 305 번째 페이지입니다.
# 306 번째 페이지입니다.
# 307 번째 페이지입니다.
# 308 번째 페이지입니다.
# 309 번째 페이지입니다.
# 310 번째 페이지입니다.
# 311 번째 페이지입니다.
# 312 번째 페이지입니다.
# 313 번째 페이지입니다.
# 314 번째 페이지입니다.
# 315 번째 페이지입니다.
# 316 번째 페이지입니다.
# 317 번째 페이지입니다.
# 318 번째 페이지입니다.
# 319 번째 페이지입니다.
# 320 번째 페이지입니다.
# 321 번째 페이지입니다.
# 322 번째 페이지입니다.
# 323 번째 페이지입니다.
# 324 번째 페이지입니다.
# 325 번째 페이지입니다.
# 326 번째 페이지입니다.
# 327 번째 페이지입니다.
# 328 번째 페이지입니다.
# 329 번째 페이지입니다.
# 330 번째 페이지입니다.
# 331 번째 페이지입니다.
# 332 번째 페이지입니다.
# 333 번째 페이지입니다.
# 334 번째 페이지입니다.
# 335 번째 페이지입니다.
# 336 번째 페이지입니다.
# 337 번째 페이지입니다.
# 338 번째 페이지입니다.
# 339 번째 페이지입니다.
# 340 번째 페이지입니다.
# 341 번째 페이지입니다.
# 342 번째 페이지입니다.
# 343 번째 페이지입니다.
# 344 번째 페이지입니다.
# 345 번째 페이지입니다.
# 346 번째 페이지입니다.
# 347 번째 페이지입니다.
# 348 번째 페이지입니다.
# 349 번째 페이지입니다.
# 350 번째 페이지입니다.
# 351 번째 페이지입니다.
# 352 번째 페이지입니다.
# 353 번째 페이지입니다.
# 354 번째 페이지입니다.
# 355 번째 페이지입니다.
# 356 번째 페이지입니다.
# 357 번째 페이지입니다.
# 358 번째 페이지입니다.
# 359 번째 페이지입니다.
# 360 번째 페이지입니다.
# 361 번째 페이지입니다.
# 362 번째 페이지입니다.
# 363 번째 페이지입니다.
# 364 번째 페이지입니다.
# 365 번째 페이지입니다.
# 366 번째 페이지입니다.
# 367 번째 페이지입니다.
# 368 번째 페이지입니다.
# 369 번째 페이지입니다.
# 370 번째 페이지입니다.
# 371 번째 페이지입니다.
# 372 번째 페이지입니다.
# 373 번째 페이지입니다.
# 374 번째 페이지입니다.
# 375 번째 페이지입니다.
# 376 번째 페이지입니다.
# 377 번째 페이지입니다.
# 378 번째 페이지입니다.
# 379 번째 페이지입니다.
# 380 번째 페이지입니다.
# 381 번째 페이지입니다.
# 382 번째 페이지입니다.
# url_open... tsingtao 맥주 데이터를 수집합니다..
# 오류 발생.. 다시 시작합니다.
# 성공... while문을 탈출합니다.
# num =  2235
# 1 번째 페이지입니다.
# 2 번째 페이지입니다.
# 3 번째 페이지입니다.
# 4 번째 페이지입니다.
# 5 번째 페이지입니다.
# 6 번째 페이지입니다.
# 7 번째 페이지입니다.
# 8 번째 페이지입니다.
# 9 번째 페이지입니다.
# 10 번째 페이지입니다.
# 11 번째 페이지입니다.
# 12 번째 페이지입니다.
# 13 번째 페이지입니다.
# 14 번째 페이지입니다.
# 15 번째 페이지입니다.
# 16 번째 페이지입니다.
# 17 번째 페이지입니다.
# 18 번째 페이지입니다.
# 19 번째 페이지입니다.
# 20 번째 페이지입니다.
# 21 번째 페이지입니다.
# 22 번째 페이지입니다.
# 23 번째 페이지입니다.
# 24 번째 페이지입니다.
# 25 번째 페이지입니다.
# 26 번째 페이지입니다.
# 27 번째 페이지입니다.
# 28 번째 페이지입니다.
# 29 번째 페이지입니다.
# 30 번째 페이지입니다.
# 31 번째 페이지입니다.
# 32 번째 페이지입니다.
# 33 번째 페이지입니다.
# 34 번째 페이지입니다.
# 35 번째 페이지입니다.
# 36 번째 페이지입니다.
# 37 번째 페이지입니다.
# 38 번째 페이지입니다.
# 39 번째 페이지입니다.
# 40 번째 페이지입니다.
# 41 번째 페이지입니다.
# 42 번째 페이지입니다.
# 43 번째 페이지입니다.
# 44 번째 페이지입니다.
# 45 번째 페이지입니다.
# 46 번째 페이지입니다.
# 47 번째 페이지입니다.
# 48 번째 페이지입니다.
# 49 번째 페이지입니다.
# 50 번째 페이지입니다.
# 51 번째 페이지입니다.
# 52 번째 페이지입니다.
# 53 번째 페이지입니다.
# 54 번째 페이지입니다.
# 55 번째 페이지입니다.
# 56 번째 페이지입니다.
# 57 번째 페이지입니다.
# 58 번째 페이지입니다.
# 59 번째 페이지입니다.
# 60 번째 페이지입니다.
# 61 번째 페이지입니다.
# 62 번째 페이지입니다.
# 63 번째 페이지입니다.
# 64 번째 페이지입니다.
# 65 번째 페이지입니다.
# 66 번째 페이지입니다.
# 67 번째 페이지입니다.
# 68 번째 페이지입니다.
# 69 번째 페이지입니다.
# 70 번째 페이지입니다.
# 71 번째 페이지입니다.
# 72 번째 페이지입니다.
# 73 번째 페이지입니다.
# 74 번째 페이지입니다.
# 75 번째 페이지입니다.
# 76 번째 페이지입니다.
# 77 번째 페이지입니다.
# 78 번째 페이지입니다.
# 79 번째 페이지입니다.
# 80 번째 페이지입니다.
# 81 번째 페이지입니다.
# 82 번째 페이지입니다.
# 83 번째 페이지입니다.
# 84 번째 페이지입니다.
# 85 번째 페이지입니다.
# 86 번째 페이지입니다.
# 87 번째 페이지입니다.
# 88 번째 페이지입니다.
# 89 번째 페이지입니다.
# 90 번째 페이지입니다.
# 91 번째 페이지입니다.
# 92 번째 페이지입니다.
# 93 번째 페이지입니다.
# 94 번째 페이지입니다.
# 95 번째 페이지입니다.
# 96 번째 페이지입니다.
# 97 번째 페이지입니다.
# 98 번째 페이지입니다.
# 99 번째 페이지입니다.
# 100 번째 페이지입니다.
# 101 번째 페이지입니다.
# 102 번째 페이지입니다.
# 103 번째 페이지입니다.
# 104 번째 페이지입니다.
# 105 번째 페이지입니다.
# 106 번째 페이지입니다.
# 107 번째 페이지입니다.
# 108 번째 페이지입니다.
# 109 번째 페이지입니다.
# 110 번째 페이지입니다.
# 111 번째 페이지입니다.
# 112 번째 페이지입니다.
# 113 번째 페이지입니다.
# 114 번째 페이지입니다.
# 115 번째 페이지입니다.
# 116 번째 페이지입니다.
# 117 번째 페이지입니다.
# 118 번째 페이지입니다.
# 119 번째 페이지입니다.
# 120 번째 페이지입니다.
# 121 번째 페이지입니다.
# 122 번째 페이지입니다.
# 123 번째 페이지입니다.
# 124 번째 페이지입니다.
# 125 번째 페이지입니다.
# 126 번째 페이지입니다.
# 127 번째 페이지입니다.
# 128 번째 페이지입니다.
# 129 번째 페이지입니다.
# 130 번째 페이지입니다.
# 131 번째 페이지입니다.
# 132 번째 페이지입니다.
# 133 번째 페이지입니다.
# 134 번째 페이지입니다.
# 135 번째 페이지입니다.
# 136 번째 페이지입니다.
# 137 번째 페이지입니다.
# 138 번째 페이지입니다.
# 139 번째 페이지입니다.
# 140 번째 페이지입니다.
# 141 번째 페이지입니다.
# 142 번째 페이지입니다.
# 143 번째 페이지입니다.
# 144 번째 페이지입니다.
# 145 번째 페이지입니다.
# 146 번째 페이지입니다.
# 147 번째 페이지입니다.
# 148 번째 페이지입니다.
# 149 번째 페이지입니다.
# 150 번째 페이지입니다.
# 151 번째 페이지입니다.
# url_open... blanc 맥주 데이터를 수집합니다..
# 성공... while문을 탈출합니다.
# num =  972
# 1 번째 페이지입니다.
# 2 번째 페이지입니다.
# 3 번째 페이지입니다.
# 4 번째 페이지입니다.
# 5 번째 페이지입니다.
# 6 번째 페이지입니다.
# 7 번째 페이지입니다.
# 8 번째 페이지입니다.
# 9 번째 페이지입니다.
# 10 번째 페이지입니다.
# 11 번째 페이지입니다.
# 12 번째 페이지입니다.
# 13 번째 페이지입니다.
# 14 번째 페이지입니다.
# 15 번째 페이지입니다.
# 16 번째 페이지입니다.
# 17 번째 페이지입니다.
# 18 번째 페이지입니다.
# 19 번째 페이지입니다.
# 20 번째 페이지입니다.
# 21 번째 페이지입니다.
# 22 번째 페이지입니다.
# 23 번째 페이지입니다.
# 24 번째 페이지입니다.
# 25 번째 페이지입니다.
# 26 번째 페이지입니다.
# 27 번째 페이지입니다.
# 28 번째 페이지입니다.
# 29 번째 페이지입니다.
# 30 번째 페이지입니다.
# 31 번째 페이지입니다.
# 32 번째 페이지입니다.
# 33 번째 페이지입니다.
# 34 번째 페이지입니다.
# 35 번째 페이지입니다.
# 36 번째 페이지입니다.
# 37 번째 페이지입니다.
# 38 번째 페이지입니다.
# 39 번째 페이지입니다.
# 40 번째 페이지입니다.
# 41 번째 페이지입니다.
# 42 번째 페이지입니다.
# 43 번째 페이지입니다.
# 44 번째 페이지입니다.
# 45 번째 페이지입니다.
# 46 번째 페이지입니다.
# 47 번째 페이지입니다.
# 48 번째 페이지입니다.
# 49 번째 페이지입니다.
# 50 번째 페이지입니다.
# 51 번째 페이지입니다.
# 52 번째 페이지입니다.
# 53 번째 페이지입니다.
# 54 번째 페이지입니다.
# 55 번째 페이지입니다.
# 56 번째 페이지입니다.
# 57 번째 페이지입니다.
# 58 번째 페이지입니다.
# 59 번째 페이지입니다.
# 60 번째 페이지입니다.
# 61 번째 페이지입니다.
# 62 번째 페이지입니다.
# 63 번째 페이지입니다.
# 64 번째 페이지입니다.
# 65 번째 페이지입니다.
# 66 번째 페이지입니다.
# url_open... heineken 맥주 데이터를 수집합니다..
# 성공... while문을 탈출합니다.
# num =  4191
# 1 번째 페이지입니다.
# 2 번째 페이지입니다.
# 3 번째 페이지입니다.
# 4 번째 페이지입니다.
# 5 번째 페이지입니다.
# 6 번째 페이지입니다.
# 7 번째 페이지입니다.
# 8 번째 페이지입니다.
# 9 번째 페이지입니다.
# 10 번째 페이지입니다.
# 11 번째 페이지입니다.
# 12 번째 페이지입니다.
# 13 번째 페이지입니다.
# 14 번째 페이지입니다.
# 15 번째 페이지입니다.
# 16 번째 페이지입니다.
# 17 번째 페이지입니다.
# 18 번째 페이지입니다.
# 19 번째 페이지입니다.
# 20 번째 페이지입니다.
# 21 번째 페이지입니다.
# 22 번째 페이지입니다.
# 23 번째 페이지입니다.
# 24 번째 페이지입니다.
# 25 번째 페이지입니다.
# 26 번째 페이지입니다.
# 27 번째 페이지입니다.
# 28 번째 페이지입니다.
# 29 번째 페이지입니다.
# 30 번째 페이지입니다.
# 31 번째 페이지입니다.
# 32 번째 페이지입니다.
# 33 번째 페이지입니다.
# 34 번째 페이지입니다.
# 35 번째 페이지입니다.
# 36 번째 페이지입니다.
# 37 번째 페이지입니다.
# 38 번째 페이지입니다.
# 39 번째 페이지입니다.
# 40 번째 페이지입니다.
# 41 번째 페이지입니다.
# 42 번째 페이지입니다.
# 43 번째 페이지입니다.
# 44 번째 페이지입니다.
# 45 번째 페이지입니다.
# 46 번째 페이지입니다.
# 47 번째 페이지입니다.
# 48 번째 페이지입니다.
# 49 번째 페이지입니다.
# 50 번째 페이지입니다.
# 51 번째 페이지입니다.
# 52 번째 페이지입니다.
# 53 번째 페이지입니다.
# 54 번째 페이지입니다.
# 55 번째 페이지입니다.
# 56 번째 페이지입니다.
# 57 번째 페이지입니다.
# 58 번째 페이지입니다.
# 59 번째 페이지입니다.
# 60 번째 페이지입니다.
# 61 번째 페이지입니다.
# 62 번째 페이지입니다.
# 63 번째 페이지입니다.
# 64 번째 페이지입니다.
# 65 번째 페이지입니다.
# 66 번째 페이지입니다.
# 67 번째 페이지입니다.
# 68 번째 페이지입니다.
# 69 번째 페이지입니다.
# 70 번째 페이지입니다.
# 71 번째 페이지입니다.
# 72 번째 페이지입니다.
# 73 번째 페이지입니다.
# 74 번째 페이지입니다.
# 75 번째 페이지입니다.
# 76 번째 페이지입니다.
# 77 번째 페이지입니다.
# 78 번째 페이지입니다.
# 79 번째 페이지입니다.
# 80 번째 페이지입니다.
# 81 번째 페이지입니다.
# 82 번째 페이지입니다.
# 83 번째 페이지입니다.
# 84 번째 페이지입니다.
# 85 번째 페이지입니다.
# 86 번째 페이지입니다.
# 87 번째 페이지입니다.
# 88 번째 페이지입니다.
# 89 번째 페이지입니다.
# 90 번째 페이지입니다.
# 91 번째 페이지입니다.
# 92 번째 페이지입니다.
# 93 번째 페이지입니다.
# 94 번째 페이지입니다.
# 95 번째 페이지입니다.
# 96 번째 페이지입니다.
# 97 번째 페이지입니다.
# 98 번째 페이지입니다.
# 99 번째 페이지입니다.
# 100 번째 페이지입니다.
# 101 번째 페이지입니다.
# 102 번째 페이지입니다.
# 103 번째 페이지입니다.
# 104 번째 페이지입니다.
# 105 번째 페이지입니다.
# 106 번째 페이지입니다.
# 107 번째 페이지입니다.
# 108 번째 페이지입니다.
# 109 번째 페이지입니다.
# 110 번째 페이지입니다.
# 111 번째 페이지입니다.
# 112 번째 페이지입니다.
# 113 번째 페이지입니다.
# 114 번째 페이지입니다.
# 115 번째 페이지입니다.
# 116 번째 페이지입니다.
# 117 번째 페이지입니다.
# 118 번째 페이지입니다.
# 119 번째 페이지입니다.
# 120 번째 페이지입니다.
# 121 번째 페이지입니다.
# 122 번째 페이지입니다.
# 123 번째 페이지입니다.
# 124 번째 페이지입니다.
# 125 번째 페이지입니다.
# 126 번째 페이지입니다.
# 127 번째 페이지입니다.
# 128 번째 페이지입니다.
# 129 번째 페이지입니다.
# 130 번째 페이지입니다.
# 131 번째 페이지입니다.
# 132 번째 페이지입니다.
# 133 번째 페이지입니다.
# 134 번째 페이지입니다.
# 135 번째 페이지입니다.
# 136 번째 페이지입니다.
# 137 번째 페이지입니다.
# 138 번째 페이지입니다.
# 139 번째 페이지입니다.
# 140 번째 페이지입니다.
# 141 번째 페이지입니다.
# 142 번째 페이지입니다.
# 143 번째 페이지입니다.
# 144 번째 페이지입니다.
# 145 번째 페이지입니다.
# 146 번째 페이지입니다.
# 147 번째 페이지입니다.
# 148 번째 페이지입니다.
# 149 번째 페이지입니다.
# 150 번째 페이지입니다.
# 151 번째 페이지입니다.
# 152 번째 페이지입니다.
# 153 번째 페이지입니다.
# 154 번째 페이지입니다.
# 155 번째 페이지입니다.
# 156 번째 페이지입니다.
# 157 번째 페이지입니다.
# 158 번째 페이지입니다.
# 159 번째 페이지입니다.
# 160 번째 페이지입니다.
# 161 번째 페이지입니다.
# 162 번째 페이지입니다.
# 163 번째 페이지입니다.
# 164 번째 페이지입니다.
# 165 번째 페이지입니다.
# 166 번째 페이지입니다.
# 167 번째 페이지입니다.
# 168 번째 페이지입니다.
# 169 번째 페이지입니다.
# 170 번째 페이지입니다.
# 171 번째 페이지입니다.
# 172 번째 페이지입니다.
# 173 번째 페이지입니다.
# 174 번째 페이지입니다.
# 175 번째 페이지입니다.
# 176 번째 페이지입니다.
# 177 번째 페이지입니다.
# 178 번째 페이지입니다.
# 179 번째 페이지입니다.
# 180 번째 페이지입니다.
# 181 번째 페이지입니다.
# 182 번째 페이지입니다.
# 183 번째 페이지입니다.
# 184 번째 페이지입니다.
# 185 번째 페이지입니다.
# 186 번째 페이지입니다.
# 187 번째 페이지입니다.
# 188 번째 페이지입니다.
# 189 번째 페이지입니다.
# 190 번째 페이지입니다.
# 191 번째 페이지입니다.
# 192 번째 페이지입니다.
# 193 번째 페이지입니다.
# 194 번째 페이지입니다.
# 195 번째 페이지입니다.
# 196 번째 페이지입니다.
# 197 번째 페이지입니다.
# 198 번째 페이지입니다.
# 199 번째 페이지입니다.
# 200 번째 페이지입니다.
# 201 번째 페이지입니다.
# 202 번째 페이지입니다.
# 203 번째 페이지입니다.
# 204 번째 페이지입니다.
# 205 번째 페이지입니다.
# 206 번째 페이지입니다.
# 207 번째 페이지입니다.
# 208 번째 페이지입니다.
# 209 번째 페이지입니다.
# 210 번째 페이지입니다.
# 211 번째 페이지입니다.
# 212 번째 페이지입니다.
# 213 번째 페이지입니다.
# 214 번째 페이지입니다.
# 215 번째 페이지입니다.
# 216 번째 페이지입니다.
# 217 번째 페이지입니다.
# 218 번째 페이지입니다.
# 219 번째 페이지입니다.
# 220 번째 페이지입니다.
# 221 번째 페이지입니다.
# 222 번째 페이지입니다.
# 223 번째 페이지입니다.
# 224 번째 페이지입니다.
# 225 번째 페이지입니다.
# 226 번째 페이지입니다.
# 227 번째 페이지입니다.
# 228 번째 페이지입니다.
# 229 번째 페이지입니다.
# 230 번째 페이지입니다.
# 231 번째 페이지입니다.
# 232 번째 페이지입니다.
# 233 번째 페이지입니다.
# 234 번째 페이지입니다.
# 235 번째 페이지입니다.
# 236 번째 페이지입니다.
# 237 번째 페이지입니다.
# 238 번째 페이지입니다.
# 239 번째 페이지입니다.
# 240 번째 페이지입니다.
# 241 번째 페이지입니다.
# 242 번째 페이지입니다.
# 243 번째 페이지입니다.
# 244 번째 페이지입니다.
# 245 번째 페이지입니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-dd1a91bc6b7b> in <module>
#       1 for beer in beers:
# ----> 2     data = crawl(driver, beer, data)
#
# <ipython-input-38-7bf87453b017> in crawl(driver, beer, data)
#      48
#      49         # Score breakdown 클릭
# ---> 50         time.sleep(2)
#      51     #     element = driver.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/div/div/div/div[2]/div[4]/div/div[2]/div[1]/div[2]')
#      52     #     element = driver.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/div/div/div/div[2]/div[4]/div/div[2]/div[1]/div[2]')
#
# KeyboardInterrupt:

# %%
# 데이터 저장
data.to_csv("RateBeer.csv", encoding='utf-8')
data.to_excel("RateBeer.xlsx")

# %% [markdown]
# # 단계적 구현 과정

# %% [markdown]
# ## 맥주 수집 단계

# %%
# 맥주 검색
time.sleep(2)
element = driver.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/div/div[2]/div[1]/input')
element.click()
time.sleep(1)
element.send_keys('hite')
time.sleep(2)
driver.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/div/div[2]/div[2]/a[1]/div/div[2]').click()
# Out:
# --------------------------------------------------------------------------
# NoSuchElementException                   Traceback (most recent call last)
# <ipython-input-169-5d05b598c237> in <module>
#       1 # 맥주 검색
#       2 time.sleep(2)
# ----> 3 element = driver.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/div/div[2]/div[1]/input')
#       4 element.click()
#       5 time.sleep(1)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="root"]/div[2]/div[2]/div/div[2]/div[1]/input"}
#   (Session info: chrome=87.0.4280.141)

# %%
# 전체 리뷰 수 수집
time.sleep(2)
string = driver.find_element_by_class_name('MuiTypography-root.Text___StyledTypographyTypeless-bukSfn.pzIrn.text-500.colorized__WrappedComponent-hrwcZr.hwjOn.MuiTypography-h6').text

# %%
# ,가 포함되어 있는지에 대한 로직
extract = re.compile('[0-9]*,*[0-9]+')
str_num = extract.findall(string)[0]
str_num

if ',' in str_num:
    str_num = str_num.split(',')
    str_num = int(str_num[0]+str_num[1])
    num = str_num
else:
    num = int(str_num)
    
print(num)
# Out:
# 785

# %%
# 정규표현식을 사용해 리뷰 수만 추출
extract = re.compile('[0-9]+')
num = int(extract.findall(string)[0])
num
# Out:
# 292

# %%
# 만약 ,가 있는 경우는 어떻게?
extract = re.compile('[0-9]*,*[0-9]+')
str_num = extract.findall(string)[0]
str_num = str_num.split(',')
str_num = int(str_num[0]+str_num[1])
num = str_num
num
# Out:
# --------------------------------------------------------------------------
# IndexError                               Traceback (most recent call last)
# <ipython-input-138-00c64a488e3f> in <module>
#       3 str_num = extract.findall(string)[0]
#       4 str_num = str_num.split(',')
# ----> 5 str_num = int(str_num[0]+str_num[1])
#       6 num = str_num
#       7 num
#
# IndexError: list index out of range

# %%
# 정규표현식을 사용해 리뷰 수만 추출
extract = re.compile('[0-9]+')
num = int(extract.findall(string)[0])
num
# Out:
# 2

# %% [markdown]
# ## 리뷰 수집 단계

# %%
# 전체 맥주 정보를 통째로 수집
tmp = []
beer = driver.find_elements_by_css_selector('.px-4.fj-s.f-wrap')

# 수집한 것을 데이터프레임에 저장
for i in range(len(beer)):
    tmp.append(beer[i].text)
    
tmp = pd.DataFrame(data=tmp, columns=['맥주정보'])
tmp
# Out:
#                                                  맥주정보
# 0   BarleyTapper58(2)\n🇧🇪Belgium\n0.5June 9, 2020\...
# 1   qczian(6)\n4.1June 9, 2020\nWygląd: Czarny kol...
# 2   d.de.bruijn(32)\n3.6June 4, 2020\nLekker, drin...
# 3   kaziopiwosz(828)\n🇵🇱Warszawa / Wałbrzych, Pola...
# 4   Samuel214(3,806)\n🇸🇪Örebro, Sweden\n2.0May 30,...
# 5   BineMonger51(1)\n3.8May 23, 2020\nGuinness bou...
# 6   FrothyChamp43(3)\n5.0May 18, 2020\nAn all-time...
# 7   Almogabar(607)\n🇪🇸MARIA DE HUERVA (ZARAGOZA), ...
# 8   mile(4,635)\n🇫🇮Helsinki, Finland\n3.1May 13, 2...
# 9   neil_d(114)\n4.9May 9, 2020\nQuite simply the ...
# 10  meditatemadness(1)\n4.5May 6, 2020\nOnly out o...
# 11  shivermetimber.gray(13)\n3.5April 27, 2020\nA ...
# 12  lotte(2)\n2.1April 27, 2020\nHavde forventet e...
# 13  MeadScout61(38)\n🇮🇹Catania, Italy\n2.0April 26...
# 14  bowling(790)\n🇬🇧Bury ST Edmunds, England\n3.5A...

# %%
data
# Out:
#                                                  맥주정보
# 0   vinivini(6,192)\n🇧🇾Homiel, Belarus\n2.2April 1...
# 1   통통냥이코(6)\n1.4January 28, 2019\n맥주 특유의 맛이 적습니다....
# 2   CurlyJoe(731)\n🇦🇺Australia\n2.0December 27, 20...
# 3   brewperman(31)\n🇺🇸United States\n1.8November 2...
# 4   DraftSensei110(497)\n1.4November 18, 2018\nCer...
# 5   jjgmd(3,257)\n🇺🇸Parkland, United States\n0.5Oc...
# 6   Iphonephan(9,544)\n🇺🇸Jackson Hole/McLean, Unit...
# 7   Ralexander89(3)\n4.0October 4, 2018\nReally re...
# 8   BeerTickers28(1)\n5.0September 12, 2018\nblood...
# 9   kwik-lime(3,822)\n🇬🇧London, England\n2.0August...
# 10  Cimbasso(1,752)\n🇬🇧London, England\n1.8August ...
# 11  one shot(1)\n2.5July 26, 2018\n여름 시원하게 쭉 들이키기 ...
# 12  brandonjoe(1)\n4.6July 19, 2018\nThis is not a...
# 13  TBone(23,236)\n🇫🇮Pori, Finland\n1.6July 3, 201...
# 14  foyle(628)\n🇺🇸United States\n3.0June 25, 2018\...

# %%
data = pd.concat([data, tmp])
data
# Out:
#                                                  맥주정보
# 0   vinivini(6,192)\n🇧🇾Homiel, Belarus\n2.2April 1...
# 1   통통냥이코(6)\n1.4January 28, 2019\n맥주 특유의 맛이 적습니다....
# 2   CurlyJoe(731)\n🇦🇺Australia\n2.0December 27, 20...
# 3   brewperman(31)\n🇺🇸United States\n1.8November 2...
# 4   DraftSensei110(497)\n1.4November 18, 2018\nCer...
# 5   jjgmd(3,257)\n🇺🇸Parkland, United States\n0.5Oc...
# 6   Iphonephan(9,544)\n🇺🇸Jackson Hole/McLean, Unit...
# 7   Ralexander89(3)\n4.0October 4, 2018\nReally re...
# 8   BeerTickers28(1)\n5.0September 12, 2018\nblood...
# 9   kwik-lime(3,822)\n🇬🇧London, England\n2.0August...
# 10  Cimbasso(1,752)\n🇬🇧London, England\n1.8August ...
# 11  one shot(1)\n2.5July 26, 2018\n여름 시원하게 쭉 들이키기 ...
# 12  brandonjoe(1)\n4.6July 19, 2018\nThis is not a...
# 13  TBone(23,236)\n🇫🇮Pori, Finland\n1.6July 3, 201...
# 14  foyle(628)\n🇺🇸United States\n3.0June 25, 2018\...
# 0   vinivini(6,192)\n🇧🇾Homiel, Belarus\n2.2April 1...
# 1   통통냥이코(6)\n1.4January 28, 2019\n맥주 특유의 맛이 적습니다....
# 2   CurlyJoe(731)\n🇦🇺Australia\n2.0December 27, 20...
# 3   brewperman(31)\n🇺🇸United States\n1.8November 2...
# 4   DraftSensei110(497)\n1.4November 18, 2018\nCer...
# 5   jjgmd(3,257)\n🇺🇸Parkland, United States\n0.5Oc...
# 6   Iphonephan(9,544)\n🇺🇸Jackson Hole/McLean, Unit...
# 7   Ralexander89(3)\n4.0October 4, 2018\nReally re...
# 8   BeerTickers28(1)\n5.0September 12, 2018\nblood...
# 9   kwik-lime(3,822)\n🇬🇧London, England\n2.0August...
# 10  Cimbasso(1,752)\n🇬🇧London, England\n1.8August ...
# 11  one shot(1)\n2.5July 26, 2018\n여름 시원하게 쭉 들이키기 ...
# 12  brandonjoe(1)\n4.6July 19, 2018\nThis is not a...
# 13  TBone(23,236)\n🇫🇮Pori, Finland\n1.6July 3, 201...
# 14  foyle(628)\n🇺🇸United States\n3.0June 25, 2018\...

# %%
# 데이터 프레임 생성
data = pd.DataFrame(data=[], columns=['맥주정보'])

# %%
time.sleep(2)
# div, span, title 태그 후 속성은 class 외에도 사용 가능
element = driver.find_elements_by_link_text('Score breakdown')
driver.execute_script("arguments[0].click();", element)
# Out:
# ---------------------------------------------------------------------------
# JavascriptException                       Traceback (most recent call last)
# <ipython-input-281-12bfaada9f46> in <module>
#       2 # div, span, title 태그 후 속성은 class 외에도 사용 가능
#       3 element = driver.find_elements_by_link_text('Score breakdown')
# ----> 4 driver.execute_script("arguments[0].click();", element)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     632             command = Command.EXECUTE_SCRIPT
#     633
# --> 634         return self.execute(command, {
#     635             'script': script,
#     636             'args': converted_args})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# JavascriptException: Message: javascript error: arguments[0].click is not a function
#   (Session info: chrome=87.0.4280.141)

# %% [markdown]
# ## 실제 리뷰 데이터 수집

# %%
page_num = num // 15 + 1

# 데이터 프레임 생성
data = pd.DataFrame(data=[], columns=['맥주정보'])

for i in range(page_num+1):
    print(i+1, '번째 페이지입니다.')
    
    # Score breakdown 클릭
    time.sleep(2)
#     element = driver.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/div/div/div/div[2]/div[4]/div/div[2]/div[1]/div[2]')
#     element = driver.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/div/div/div/div[2]/div[4]/div/div[2]/div[1]/div[2]')
    element = driver.find_element_by_xpath('//*[@id="root"]/div[2]/div[2]/div/div/div/div[2]/div[4]/div/div[2]/div[1]/div[2]')
    time.sleep(2)
    driver.execute_script("arguments[0].click();", element)
    
    # 전체 맥주 정보를 통쨰로 수집
    tmp = []
    beer = driver.find_elements_by_css_selector('.px-4.fj-s.f-wrap')

    # 수집한 것을 데이터프레임에 저장
    for i in range(len(beer)):
        tmp.append(beer[i].text)

    tmp = pd.DataFrame(data=tmp, columns=['맥주정보'])
    data = pd.concat([data, tmp])
    
    # div, span, title 태그 후 속성은 class 외에도 사용 가능
    time.sleep(2)
    try :        
        element = driver.find_element_by_xpath('//button[@title="Next page"]/span[@class="MuiIconButton-label"]')
        driver.execute_script("arguments[0].click();", element)
    except:
        print('마지막 페이지입니다.')
# Out:
# 1 번째 페이지입니다.
# 2 번째 페이지입니다.
# 3 번째 페이지입니다.
# 4 번째 페이지입니다.
# 5 번째 페이지입니다.
# 6 번째 페이지입니다.
# 7 번째 페이지입니다.
# 8 번째 페이지입니다.
# 9 번째 페이지입니다.
# 10 번째 페이지입니다.
# 11 번째 페이지입니다.
# 12 번째 페이지입니다.
# 13 번째 페이지입니다.
# 14 번째 페이지입니다.
# 15 번째 페이지입니다.
# 16 번째 페이지입니다.
# 17 번째 페이지입니다.
# 18 번째 페이지입니다.
# 19 번째 페이지입니다.
# 20 번째 페이지입니다.
# 21 번째 페이지입니다.
# 22 번째 페이지입니다.
# 23 번째 페이지입니다.
# 24 번째 페이지입니다.
# 25 번째 페이지입니다.
# 26 번째 페이지입니다.
# 27 번째 페이지입니다.
# 28 번째 페이지입니다.
# 29 번째 페이지입니다.
# 30 번째 페이지입니다.
# 31 번째 페이지입니다.
# 32 번째 페이지입니다.
# 33 번째 페이지입니다.
# 34 번째 페이지입니다.
# 35 번째 페이지입니다.
# 36 번째 페이지입니다.
# 37 번째 페이지입니다.
# 38 번째 페이지입니다.
# 39 번째 페이지입니다.
# 40 번째 페이지입니다.
# 41 번째 페이지입니다.
# 42 번째 페이지입니다.
# 43 번째 페이지입니다.
# 44 번째 페이지입니다.
# 45 번째 페이지입니다.
# 46 번째 페이지입니다.
# 47 번째 페이지입니다.
# 48 번째 페이지입니다.
# 49 번째 페이지입니다.
# 50 번째 페이지입니다.
# 51 번째 페이지입니다.
# 52 번째 페이지입니다.
# 53 번째 페이지입니다.
# 54 번째 페이지입니다.
# 55 번째 페이지입니다.
# 56 번째 페이지입니다.
# 57 번째 페이지입니다.
# 58 번째 페이지입니다.
# 59 번째 페이지입니다.
# 60 번째 페이지입니다.
# 61 번째 페이지입니다.
# 62 번째 페이지입니다.
# 63 번째 페이지입니다.
# 64 번째 페이지입니다.
# 65 번째 페이지입니다.
# 66 번째 페이지입니다.
# 67 번째 페이지입니다.
# 68 번째 페이지입니다.
# 69 번째 페이지입니다.
# 70 번째 페이지입니다.
# 71 번째 페이지입니다.
# 72 번째 페이지입니다.
# 73 번째 페이지입니다.
# 74 번째 페이지입니다.
# 75 번째 페이지입니다.
# 76 번째 페이지입니다.
# 77 번째 페이지입니다.
# 78 번째 페이지입니다.
# 79 번째 페이지입니다.
# 80 번째 페이지입니다.
# 81 번째 페이지입니다.
# 82 번째 페이지입니다.
# 83 번째 페이지입니다.
# 84 번째 페이지입니다.
# 85 번째 페이지입니다.
# 86 번째 페이지입니다.
# 87 번째 페이지입니다.
# 88 번째 페이지입니다.
# 89 번째 페이지입니다.
# 90 번째 페이지입니다.
# 91 번째 페이지입니다.
# 92 번째 페이지입니다.
# 93 번째 페이지입니다.
# 94 번째 페이지입니다.
# 95 번째 페이지입니다.
# 96 번째 페이지입니다.
# 97 번째 페이지입니다.
# 98 번째 페이지입니다.
# 99 번째 페이지입니다.
# 100 번째 페이지입니다.
# 101 번째 페이지입니다.
# 102 번째 페이지입니다.
# 103 번째 페이지입니다.
# 104 번째 페이지입니다.
# 105 번째 페이지입니다.
# 106 번째 페이지입니다.
# 107 번째 페이지입니다.
# 108 번째 페이지입니다.
# 109 번째 페이지입니다.
# 110 번째 페이지입니다.
# 111 번째 페이지입니다.
# 112 번째 페이지입니다.
# 113 번째 페이지입니다.
# 114 번째 페이지입니다.
# 115 번째 페이지입니다.
# 116 번째 페이지입니다.
# 117 번째 페이지입니다.
# 118 번째 페이지입니다.
# 119 번째 페이지입니다.
# 120 번째 페이지입니다.
# 121 번째 페이지입니다.
# 122 번째 페이지입니다.
# 123 번째 페이지입니다.
# 124 번째 페이지입니다.
# 125 번째 페이지입니다.
# 126 번째 페이지입니다.
# 127 번째 페이지입니다.
# 128 번째 페이지입니다.
# 129 번째 페이지입니다.
# 130 번째 페이지입니다.
# 131 번째 페이지입니다.
# 132 번째 페이지입니다.
# 133 번째 페이지입니다.
# 134 번째 페이지입니다.
# 135 번째 페이지입니다.
# 136 번째 페이지입니다.
# 137 번째 페이지입니다.
# 138 번째 페이지입니다.
# 139 번째 페이지입니다.
# 140 번째 페이지입니다.
# 141 번째 페이지입니다.
# 142 번째 페이지입니다.
# 143 번째 페이지입니다.
# 144 번째 페이지입니다.
# 145 번째 페이지입니다.
# 146 번째 페이지입니다.
# 147 번째 페이지입니다.
# 148 번째 페이지입니다.
# 149 번째 페이지입니다.
# 150 번째 페이지입니다.
# 151 번째 페이지입니다.
# 152 번째 페이지입니다.
# 153 번째 페이지입니다.
# 154 번째 페이지입니다.
# 155 번째 페이지입니다.
# 156 번째 페이지입니다.
# 157 번째 페이지입니다.
# 158 번째 페이지입니다.
# 159 번째 페이지입니다.
# 160 번째 페이지입니다.
# 161 번째 페이지입니다.
# 162 번째 페이지입니다.
# 163 번째 페이지입니다.
# 164 번째 페이지입니다.
# 165 번째 페이지입니다.
# 166 번째 페이지입니다.
# 167 번째 페이지입니다.
# 168 번째 페이지입니다.
# 169 번째 페이지입니다.
# 170 번째 페이지입니다.
# 171 번째 페이지입니다.
# 172 번째 페이지입니다.
# 173 번째 페이지입니다.
# 174 번째 페이지입니다.
# 175 번째 페이지입니다.
# 176 번째 페이지입니다.
# 177 번째 페이지입니다.
# 178 번째 페이지입니다.
# 179 번째 페이지입니다.
# 180 번째 페이지입니다.
# 181 번째 페이지입니다.
# 182 번째 페이지입니다.
# 183 번째 페이지입니다.
# 184 번째 페이지입니다.
# 185 번째 페이지입니다.
# 186 번째 페이지입니다.
# 187 번째 페이지입니다.
# 188 번째 페이지입니다.
# 189 번째 페이지입니다.
# 190 번째 페이지입니다.
# 191 번째 페이지입니다.
# 192 번째 페이지입니다.
# 193 번째 페이지입니다.
# 194 번째 페이지입니다.
# 195 번째 페이지입니다.
# 196 번째 페이지입니다.
# 197 번째 페이지입니다.
# 198 번째 페이지입니다.
# 199 번째 페이지입니다.
# 200 번째 페이지입니다.
# 201 번째 페이지입니다.
# 202 번째 페이지입니다.
# 203 번째 페이지입니다.
# 204 번째 페이지입니다.
# 205 번째 페이지입니다.
# 206 번째 페이지입니다.
# 207 번째 페이지입니다.
# 208 번째 페이지입니다.
# 209 번째 페이지입니다.
# 210 번째 페이지입니다.
# 211 번째 페이지입니다.
# 212 번째 페이지입니다.
# 213 번째 페이지입니다.
# 214 번째 페이지입니다.
# 215 번째 페이지입니다.
# 216 번째 페이지입니다.
# 217 번째 페이지입니다.
# 218 번째 페이지입니다.
# 219 번째 페이지입니다.
# 220 번째 페이지입니다.
# 221 번째 페이지입니다.
# 222 번째 페이지입니다.
# 223 번째 페이지입니다.
# 224 번째 페이지입니다.
# 225 번째 페이지입니다.
# 226 번째 페이지입니다.
# 227 번째 페이지입니다.
# 228 번째 페이지입니다.
# 229 번째 페이지입니다.
# 230 번째 페이지입니다.
# 231 번째 페이지입니다.
# 232 번째 페이지입니다.
# 233 번째 페이지입니다.
# 234 번째 페이지입니다.
# 235 번째 페이지입니다.
# 236 번째 페이지입니다.
# 237 번째 페이지입니다.
# 238 번째 페이지입니다.
# 239 번째 페이지입니다.
# 240 번째 페이지입니다.
# 241 번째 페이지입니다.
# 242 번째 페이지입니다.
# 243 번째 페이지입니다.
# 244 번째 페이지입니다.
# 245 번째 페이지입니다.
# 246 번째 페이지입니다.
# 247 번째 페이지입니다.
# 248 번째 페이지입니다.
# 249 번째 페이지입니다.
# 250 번째 페이지입니다.
# 251 번째 페이지입니다.
# 252 번째 페이지입니다.
# 253 번째 페이지입니다.
# 254 번째 페이지입니다.
# 255 번째 페이지입니다.
# 256 번째 페이지입니다.
# 257 번째 페이지입니다.
# 258 번째 페이지입니다.
# 259 번째 페이지입니다.
# 260 번째 페이지입니다.
# 261 번째 페이지입니다.
# 262 번째 페이지입니다.
# 263 번째 페이지입니다.
# 264 번째 페이지입니다.
# 265 번째 페이지입니다.
# 266 번째 페이지입니다.
# 267 번째 페이지입니다.
# 268 번째 페이지입니다.
# 269 번째 페이지입니다.
# 270 번째 페이지입니다.
# 271 번째 페이지입니다.
# 272 번째 페이지입니다.
# 273 번째 페이지입니다.
# 274 번째 페이지입니다.
# 275 번째 페이지입니다.
# 276 번째 페이지입니다.
# 277 번째 페이지입니다.
# 278 번째 페이지입니다.
# 279 번째 페이지입니다.
# 280 번째 페이지입니다.
# 281 번째 페이지입니다.
# 282 번째 페이지입니다.
# 283 번째 페이지입니다.
# 284 번째 페이지입니다.
# 285 번째 페이지입니다.
# 286 번째 페이지입니다.
# 287 번째 페이지입니다.
# 288 번째 페이지입니다.
# 289 번째 페이지입니다.
# 290 번째 페이지입니다.
# 291 번째 페이지입니다.
# 292 번째 페이지입니다.
# 293 번째 페이지입니다.
# 294 번째 페이지입니다.
# 295 번째 페이지입니다.
# 296 번째 페이지입니다.
# 297 번째 페이지입니다.
# 298 번째 페이지입니다.
# 299 번째 페이지입니다.
# 300 번째 페이지입니다.
# 301 번째 페이지입니다.
# 302 번째 페이지입니다.
# 303 번째 페이지입니다.
# 304 번째 페이지입니다.
# 305 번째 페이지입니다.
# 306 번째 페이지입니다.
# 307 번째 페이지입니다.
# 308 번째 페이지입니다.
# 309 번째 페이지입니다.
# 310 번째 페이지입니다.
# 311 번째 페이지입니다.
# 312 번째 페이지입니다.
# 313 번째 페이지입니다.
# 314 번째 페이지입니다.
# 315 번째 페이지입니다.
# 316 번째 페이지입니다.
# 317 번째 페이지입니다.
# 318 번째 페이지입니다.
# 319 번째 페이지입니다.
# 320 번째 페이지입니다.
# 321 번째 페이지입니다.
# 322 번째 페이지입니다.
# 323 번째 페이지입니다.
# 324 번째 페이지입니다.
# 325 번째 페이지입니다.
# 326 번째 페이지입니다.
# 327 번째 페이지입니다.
# 328 번째 페이지입니다.
# 329 번째 페이지입니다.
# 330 번째 페이지입니다.
# 331 번째 페이지입니다.
# 332 번째 페이지입니다.
# 333 번째 페이지입니다.
# 334 번째 페이지입니다.
# 335 번째 페이지입니다.
# 336 번째 페이지입니다.
# 337 번째 페이지입니다.
# 338 번째 페이지입니다.
# 339 번째 페이지입니다.
# 340 번째 페이지입니다.
# 341 번째 페이지입니다.
# 342 번째 페이지입니다.
# 343 번째 페이지입니다.
# 344 번째 페이지입니다.
# 345 번째 페이지입니다.
# 346 번째 페이지입니다.
# 347 번째 페이지입니다.
# 348 번째 페이지입니다.
# 349 번째 페이지입니다.
# 350 번째 페이지입니다.
# 351 번째 페이지입니다.
# 352 번째 페이지입니다.
# 353 번째 페이지입니다.
# 354 번째 페이지입니다.
# 355 번째 페이지입니다.
# 356 번째 페이지입니다.
# 357 번째 페이지입니다.
# 358 번째 페이지입니다.
# 359 번째 페이지입니다.
# 360 번째 페이지입니다.
# 361 번째 페이지입니다.
# 362 번째 페이지입니다.
# 363 번째 페이지입니다.
# 364 번째 페이지입니다.
# 365 번째 페이지입니다.
# 366 번째 페이지입니다.
# 367 번째 페이지입니다.
# 368 번째 페이지입니다.
# 369 번째 페이지입니다.
# 370 번째 페이지입니다.
# 371 번째 페이지입니다.
# 372 번째 페이지입니다.
# 373 번째 페이지입니다.
# 374 번째 페이지입니다.
# 375 번째 페이지입니다.
# 376 번째 페이지입니다.
# 377 번째 페이지입니다.
# 378 번째 페이지입니다.
# 379 번째 페이지입니다.
# 380 번째 페이지입니다.
# 381 번째 페이지입니다.
# 382 번째 페이지입니다.

# %%
data
# Out:
#                                                  맥주정보
# 0   BlackHaddock(11,440)\n🇬🇧The County Time Forgot...
# 1   ccex(1,799)\n🇺🇸Lansing, United States\n3.0Nove...
# 2   Chudwick(4,289)\n🇺🇸Taylor Mill, United States\...
# 3   saw2k(13)\n3.6July 22, 2019\nGood standard che...
# 4   borre_m(2,399)\n🇳🇴Norway\n2.1March 17, 2019\nP...
# ..                                                ...
# 7   GoufCustom(2,894)\n🇭🇰Hong Kong\n2.1June 23, 20...
# 8   cmc619(501)\n🇺🇸United States\n2.6May 17, 2015\...
# 9   KansaiBeerLvrs(7,279)\n🇯🇵Kyoto, Japan\n2.8May ...
# 10  Ethanolist(10)\n1.8December 22, 2014\nActually...
# 11  fredthecat(522)\n🇨🇦Canada\n1.8December 8, 2014...
#
# [69 rows x 1 columns]

# %%
len(data)
# Out:
# 69

# %% [markdown]
# ## 데이터 저장

# %%
data.to_excel('guiness_draught.xlsx')
