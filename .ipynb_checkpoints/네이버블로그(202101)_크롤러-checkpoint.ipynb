# %%
import platform
print(platform.architecture())
# Out:
# ('64bit', 'WindowsPE')

# %%
# !python --version
# Out:
# Python 3.8.3

# %%
# 네이버에서 검색어 입력받아 검색 한 후 블로그 메뉴를 선택하고
# 오른쪽에 있는 검색옵션 버튼을 눌러서
# 정렬 방식과 기간을 입력하기

#Step 0. 필요한 모듈과 라이브러리를 로딩합니다.
import sys
import os
import pandas as pd
import numpy as np

from bs4 import BeautifulSoup
from selenium import webdriver
import time
from tqdm import tqdm_notebook

# %%
query_txt = input('1.크롤링할 키워드는 무엇입니까?: ')
# query_txt2 = input('2.제외할 첫번째 키워드를 입력하세요: ')
# query_txt3 = input('3.제외할 두번째 키워드를 입력하세요: ')

start_date = input('4.조회를 시작할 날짜를 입력하세요(예:20170101) :')
end_date = input('5.조회를 종료할 날짜를 입력하세요(예:20171231): ')
# Out:
# 1.크롤링할 키워드는 무엇입니까?: 추천시스템
# 4.조회를 시작할 날짜를 입력하세요(예:20170101) :20200101
# 5.조회를 종료할 날짜를 입력하세요(예:20171231): 20210101

# %%
query_txt="김치볶음밥 맛집"
start_date="20201201"
end_date="20210106"

# %% [markdown]
# # 크롤링할 블로그 url 수집하기

# %%
#Step 1. 크롬 웹브라우저 실행
path = "chromedriver.exe"  # 맥 기준  # 윈도우는 "chromedriver.exe"

driver = webdriver.Chrome(path)
# 사이트 주소는 네이버
driver.get('http://www.naver.com')
time.sleep(2)

#Step 2. 네이버 검색창에 "검색어" 검색
element = driver.find_element_by_id("query")
element.send_keys(query_txt)  # query_txt는 위에서 입력한 키워드
element.submit()
time.sleep(1)

# 'VIEW' 클릭
driver.find_element_by_link_text("VIEW").click( )

# '블로그' 클릭
driver.find_element_by_link_text("블로그").click( )
time.sleep(1)

# '검색옵션' 클릭
driver.find_element_by_link_text("검색옵션").click( )
time.sleep(1)

# Step 3. 정렬 : "관련도순" 
# 개발자 도구에서 정렬 버튼의 id 가 보이지 않습니다.
# 이럴 경우 쉽게 사용할 수 있는 방법이 바로 xpath 를 이용하는 방법입니다.
# xpath는 개발자 도구에서 해당 메뉴 부분을 마우스 오른쪽 버튼을 누르고 
# copy -> copy xpath 를 선택하면 됩니다
driver.find_element_by_xpath("""//*[@id="snb"]/div/ul/li[1]/a""").click( )  # 정렬 버튼의 xpath 클릭
driver.find_element_by_xpath("""//*[@id="snb"]/div/ul/li[1]/div/ul/li[1]/a""").click( ) # 관련도순 xpath
time.sleep(1)

# Step 4. 날짜 입력
driver.find_element_by_link_text("기간").click()
time.sleep(2)

# 이 부분이 아주 중요합니다.
# 날짜 부분에 날짜를 입력할 때 입력 속도가 너무 빠를 경우 날짜가 입력이 되다가 
# 오타가 나오는 경우가 많습니다.
# 그래서 날짜를 입력할 때 for 반복문을 사용해서 1 글자씩 입력하도록 코딩했습니다.

# 시작 날짜 입력하기
s_date = driver.find_element_by_id("date_from_input")
driver.find_element_by_id("date_from_input").click()
s_date.clear( )  # 날짜 입력 부분에 기존에 입력되어 있던 날짜를 제거합니다. 
time.sleep(1)
# 아래 코드가 날짜를 for 반복문으로 1 글자씩 입력하는 부분입니다.
for c in start_date:
    s_date.send_keys(c)
    time.sleep(0.1)
time.sleep(1)

# 종료 날짜 입력하기
e_date = driver.find_element_by_id("date_to_input")
driver.find_element_by_id("date_to_input").click()
e_date.clear()
time.sleep(1)

for c in end_date:
    e_date.send_keys(c)
    time.sleep(0.1)
    
# Step5. 날짜 입력 "적용" 버튼을 클릭 합니다.  
driver.find_element_by_class_name("tx").click()
time.sleep(3)

# # Step 8. 상세 검색버튼을 클릭 후 제외할 단어들을 설정합니다.
# ele2 = driver.find_element_by_id("inpop3")
# ele2.send_keys(query_txt2)
# ele2.send_keys(',')
# ele2.send_keys(query_txt3)
# driver.find_element_by_css_selector(".btn_ft.ty_green._search").click( )

## 글 url 크롤링 시작

# %%
# 스크롤 다운 

def scroll_down(driver):
    driver.execute_script("window.scrollTo(0, 99999999)")
    time.sleep(1)

# n: 스크롤할 횟수 설정
n = 10
i = 0
while i < n:
    scroll_down(driver) # 스크롤 다운
    i += 1

# %%
url_list = []
title_list = []

# URL 크롤링 시작
articles = ".api_txt_lines.total_tit"
article_raw = driver.find_elements_by_css_selector(articles)

# url 크롤링 시작    
for article in article_raw:
    url = article.get_attribute('href')   
    url_list.append(url)
time.sleep(1)
    
# 제목 크롤링 시작    
for article in article_raw:
    title = article.text
    title_list.append(title)

    print(title)

print("")
print('url갯수: ', len(url_list))
print('title갯수: ', len(title_list))
# Out:
# 홍대 배달 음식 맛집 [ 삼겹살김치볶음밥, 치킨마요덮밥 맛집...
# [부산해운대구맛집/해운대맛집... 멘보샤, 김치볶음밥, 짬뽕
# [맛집/고터] 김치볶음밥이 맛있는 레트로 맛집 『하트타임』
# [한남동 맛집] 알프키친... 항정살&대파구이 김치볶음밥...
# 서초동 맛집 호주 김치볶음밥이 대박이었던 교대 술집
# 여수 분위기 맛집 바다식탁 : 갓김치볶음밥, 로제 바다파스타
# 찐제주도민맛집 빨강코끼리에서 돈까스쫄면, 새우김치볶음밥...
# 광화문 점심 맛집 도노베아토의 깔끔한 베이컨김치볶음밥!
# 영주맛집 ) 한솥도시락 새치고기고기, 스팸김치볶음밥...
# [대구 맛집]매력적인 김치 볶음밥 "새한분식"
# |성수맛집| '성수명당' 1등은 김치볶음밥!!! (ft.스테이크와...
# [대전술집/대전포차] 코다차야 -김치볶음밥 맛집
# [부경대 맛집] 키다리식당, 부경대 김치볶음밥 맛집
# 의정부배달맛집 스테이크레이브 / 김치볶음밥과 파스타
# 대학생이추천하는 안양1번가 가성비좋은곳 김치볶음밥맛집...
# 대패새우 + 김치볶음밥... 헝그리박스추천메뉴 창원배달맛집
# 이천 포장배달 도시락 맛집 (스팸김치볶음밥/빅치킨마요...
# [청주 봉명동/맛집] 점심에 김치볶음밥이 땡긴다면? "아트쿡...
# 제주 서귀포 맛집 ‘취향의 섬’ 김치볶음밥 꼭 드세요
# 중랑구 브런치 배달 맛집 이문동 카페115, 김치볶음밥...
# (여수맛집) 바다식탁 / 갓김치볶음밥 / 바다라면 / 페퍼로니피자
# 이색적인 브런치 맛집 <보마켓 2호점>
# 고속터미널 맛집 텍사스데브라질 센트럴시티점 가봤어요
# 신불당 맛집 아기자기한 천안 돈까스 맛집 <1982돈까스>
# [경기/용인카페 용인맛집]커피라이커스+바울아저씨
# 애월 돈까스 맛집, 애월 돈까스집
# 파주 야당 맛집 우리감자탕에서 가족외식 하고왔어요 파주...
# 진주 배달 맛집 :: 평거동맛집에서 삼겹살 배달 시켜 먹기 '푸줏간'
# 사당역 소고기 맛집 홍주고깃간 와인 마시기좋은 고기집
# 남양주 맛집/남양주 파스타 : 달빛식탁
# [의정부 맛집] 식호락
# [이천 배달맛집] 집에서 먹으니 추억도 바삭바삭 <또와분식 >
# [한식] 양림동 맛집 : 밥제작소
# [병점 소고기 찐맛집] 진안동 낙원갈비집 시그니처 왕관갈비 후기
# 광화문 디티워 맛집 추천 조선기술 모임장소로 딱!
# 잠실 롯데월드타워 맛집 백프로 만족은
# 신촌 돈까스] "윤오므라이스" - 가성비ㆍ맛 모두 잡은 혼밥 맛집!
# [부산 기장] 샌드위치 맛집
# 고가길 9공탄 삼각지 연탄구이 항정살 맛집
# 단대오거리 맛집 - 남다른감자탕 세이브존 성남점 : 추운 날씨에...
# 북구 맛집 “황금리브런치”
# 논현역 맛집- 오감
# 대구 앞산 맛집 블루웨이브 일부러 찾아가는 맛집!
# [추천 배달음식 : 한식] “맛집”
# 안양일번가 맛집, 안양 '코리안 스테이크 김볶스' 리뷰
# 천안아산맛집 혜화동돈가스 양도푸짐하고 맛있네요.
# 원주카페추천 @원주 분위기좋은 카페 겸 맛집 ::원주 마이테라스
# 불로동맛집 충장로 하고스에서 양식 냠냠냠냠
# Achoo ~
# 영통브런치 꼬메타포레스트 영통파스타맛집
# 우만동맛집 낙원갈비집 수원월드컵점 점심특선 혜자
# 추천해주는 청주 맛집리스트/ 구미사람이 추천해주는 구미 맛집
# 평택 법원 맛집 육풍에서 삼겹살 푸짐하게!
# [영국생활] 2020년 12월 런던일기 1, 런던맛집, 테이트브리튼
# 마초갈비 여의도공원점 : 숯불 돼지왕갈비 맛집 (여의도 고기집)
# [청담사진맛집]데일리청담/55도와인앤다인
# [대전맛집/우송대맛집]제주느낌 올레식탁
#
# url갯수:  330
# title갯수:  330

# %%
df = pd.DataFrame({'url':url_list, 'title':title_list})

# 저장하기
df.to_excel("blog_url.xlsx")

# %% [markdown]
# # 블로그 내용 크롤링하기

# %%
import sys
import os
import pandas as pd
import numpy as np

# %%
# "url_list.csv" 불러오기
url_load = pd.read_excel("blog_url.xlsx") # 기본 모델

num_list = len(url_load)

print(num_list)
url_load
# Out:
# 330
#      Unnamed: 0                                                url  \
# 0             0  https://blog.naver.com/thearly?Redirect=Log&lo...
# 1             1  https://blog.naver.com/dnr6578?Redirect=Log&lo...
# 2             2  https://blog.naver.com/i_believe28?Redirect=Lo...
# 3             3  https://blog.naver.com/woonelee?Redirect=Log&l...
# 4             4  https://blog.naver.com/queen05123?Redirect=Log...
# ..          ...                                                ...
# 325         325  https://blog.naver.com/yurim012?Redirect=Log&l...
# 326         326  https://blog.naver.com/happy_jennychoi?Redirec...
# 327         327  https://blog.naver.com/icaruse2?Redirect=Log&l...
# 328         328              https://yuminimi.blog.me/222159795122
# 329         329  https://blog.naver.com/dpahdtkfkd?Redirect=Log...
#
#                                      title
# 0     홍대 배달 음식 맛집 [ 삼겹살김치볶음밥, 치킨마요덮밥 맛집...
# 1        [부산해운대구맛집/해운대맛집... 멘보샤, 김치볶음밥, 짬뽕
# 2         [맛집/고터] 김치볶음밥이 맛있는 레트로 맛집 『하트타임』
# 3       [한남동 맛집] 알프키친... 항정살&대파구이 김치볶음밥...
# 4             서초동 맛집 호주 김치볶음밥이 대박이었던 교대 술집
# ..                                     ...
# 325                평택 법원 맛집 육풍에서 삼겹살 푸짐하게!
# 326  [영국생활] 2020년 12월 런던일기 1, 런던맛집, 테이트브리튼
# 327    마초갈비 여의도공원점 : 숯불 돼지왕갈비 맛집 (여의도 고기집)
# 328                 [청담사진맛집]데일리청담/55도와인앤다인
# 329                  [대전맛집/우송대맛집]제주느낌 올레식탁
#
# [330 rows x 3 columns]

# %%
dict = {}  # 전체 크롤링 데이터를 담을 그릇

# ★수집할 글 갯수 정하기
number = 30
for i in tqdm_notebook(range(0, number)):
    # 글 띄우기
    url = url_load['url'][i]
    driver = webdriver.Chrome("chromedriver.exe")  # 윈도우는 "chromedriver.exe"
    driver.get(url)   # 글 띄우기
    
    # 크롤링
    
    try : 
        # iframe 접근
        driver.switch_to.frame('mainFrame')

        target_info = {}

        # 제목 크롤링 시작
        overlays = ".se-module.se-module-text.se-title-text"                                 
        tit = driver.find_element_by_css_selector(overlays)          # title
        title = tit.text

        # 글쓴이 크롤링 시작
        overlays = ".nick"                                 
        nick = driver.find_element_by_css_selector(overlays)         # nickname
        nickname = nick.text

        # 날짜 크롤링
        overlays = ".se_publishDate.pcol2"                                 
        date = driver.find_element_by_css_selector(overlays)         # datetime
        datetime = date.text

        # 내용 크롤링
        overlays = ".se-component.se-text.se-l-default"                                 
        contents = driver.find_elements_by_css_selector(overlays)    

        content_list = []
        for content in contents:
            content_list.append(content.text)           
 
        content_str = ' '.join(content_list)                         # content_str

        # 글 하나는 target_info라는 딕셔너리에 담기게 되고,
        target_info['title'] = title
        target_info['nickname'] = nickname
        target_info['datetime'] = datetime
        target_info['content'] = content_str

        # 각각의 글은 dict라는 딕셔너리에 담기게 됩니다.
        dict[i] = target_info
        time.sleep(1)
        
        # 크롤링이 성공하면 글 제목을 출력하게 되고,
        print(i, title)

        # 글 하나 크롤링 후 크롬 창을 닫습니다.
        driver.close()       
    
    # 에러나면 현재 크롬창을 닫고 다음 글(i+1)로 이동합니다.
    except:
        driver.close()
        time.sleep(1)
        continue
    
    # 중간,중간에 파일로 저장하기
    if i == 30 or 50 or 80:
        # 판다스로 만들기
        import pandas as pd
        result_df = pd.DataFrame.from_dict(dict, 'index')

        # 저장하기
        result_df.to_excel("blog_content.xlsx")
        time.sleep(3)

print('수집한 글 갯수: ', len(dict))
print(dict)
# Out:
# <ipython-input-13-10dfad4fafe5>:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range
 기다리면서,\n쇼파로 자리 이동했는데여 창가에 쌓아둔 박스가\n포장 및 배달 나갈 때 사용하고 있더라구요~~!! \n디자인 하신 분들이라 센스 역시 엄지척!!! ㅎㅎ \n차가져오신분들은 사진속에 보이는 제차처럼 \n가게 앞이 주차해주시면 됩니다용~~ ㅎㅎ  메뉴판도 예쁜 노랑노랑,\n눈에 확 띄는게 좋으네요~~ : ) 요것두 취저!!!!  동생 지인분이 하시는 곳이라,\n샤비스로 프라이즈를 주셨지요 ㅎㅎ 감사감사! 화이트라구 너무 좋아하는데ㅠㅠ\n너무 맛있었어용!!!!! 바질 페스토와 찰떡..!!!\n강추 메뉴예용~~~ ㅎㅎㅎㅎ  어머어머 요거는 진심 최고예요!!!!!! \n저희가 들어갔을 때 테이블마다 요게 보여서,\n주문해본건데..... 짱맛!!!!!!!!!!!!!!!!!!!  인기메뉴는 다 시키기 ㅋㅋㅋㅋㅋ \n오 ㅏ.... 이건 사이즈에 놀래버렸어용!!!!! \n완전 크고, 완전 부드러운 오믈렛..\n맛있었는데 양이 너무 많아 ㅠㅠ 냄겼네용~~ 마지막으로 다 나왔으니 잔체샷~~!! 캬캬\n여자 셋이서 먹기엔 어마무시한 양이였어요!!\n그래도 맛있게 다 잘 먹었슴돠... ㅎㅎㅎㅎ \n알프키친 위치는요? 전화번호 : 070-4134-7474\n주소 : 서울 용산구 한남동 1-131\n영업시간 : 평일 12:00 - 10:00 \n                  브레이크 타임 15:00-17:30 \n                  라스트오더 2시30분 / 8시30분\n                  일요일 휴무\n주차 : 가게앞 가능 \n요즘 맛집 사진 엄청 올리네용 ㅎㅎ\n그래듀 내일 또 들고 올게용 ㅋㅋㅋㅋ \nㅂ ㅑㅂ ㅑ'}, 4: {'title': '서초동 맛집 호주 김치볶음밥이 대박이었던 교대 술집', 'nickname': '모과생강\n(queen05123)', 'datetime': '2021. 1. 2. 14:02', 'content': '남자친구 퇴근하고 저녁 먹을 겸 교대 술집을 찾았어요. 지하철 3호선 남부터미널역 6번 출구에서 교대역 방향으로 걷다 보면 금방 찾을 수 있는곳이었습니다. 큰 건물 1층에 위치하고 있는데요. 큰 길로 오셨다면 빌딩 안으로 들어오셔서 뒷문으로 나가면 바로 보이는 위치에 있더라구요. 테라스가 넓은 술집이었습니다. 저희가 방문한 곳은 호주라는 남부터미널 맛집이었어요. 분위기 좋은 이자카야 스타일의 술집이었어요. 매장에 엄청 큰 강아지가 있어요. 저는 모르고 방문했는데 엄청 큰 강아지가 옆을 지나가서 깜짝 놀랐습니다. 사장님이 키우시는 강아지 같은데 항상 매장에 와 있는가 보더라구요. 미리 알고 방문하시는 게 좋을 것 같아요. \n이자카야 호주는 평일에는 4시 반부터,  토요일은 5시부터 영업을 시작하고요. 원래는 새벽 2시까지가 영업 시간인데 현재는 수도권 거리두기로 인 해 9시까지 영업합니다. 매주 일요일은 휴무일이에요.  교대 술 ...

# %%
# 판다스로 만들기
import pandas as pd
result_df = pd.DataFrame.from_dict(dict, 'index')

# 엑셀로 저장하기
result_df.to_excel("blog_content.xlsx")
