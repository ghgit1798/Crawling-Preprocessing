# %% [markdown]
# # 외모지상주의_댓글 수집하기

# %%
import pandas as pd
import numpy as np

import time

# selenium 라이브러리의 webdriver를 가져온다.
from selenium import webdriver

# %%
# webdriver로 크롬을 설정
driver = webdriver.Chrome("chromedriver.exe")
# webdriver의 get 함수로 url 오픈 : 예시입니다.
driver.get("https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no=1")

# %%
data = pd.DataFrame(data=[], columns=['회차','날짜','이름','아이디','댓글','좋아요'])

# %%
def collector(driver, data, k):
    # webdriver.Chorme(path) 설정을 매 번 해줘야 오류가 안나네요.
    driver = webdriver.Chrome("chromedriver.exe")
    url = 'https://comic.naver.com/webtoon/detail.nhn?titleId=641253&no='+str(k)
    driver.get(url)
    
    time.sleep(1)
    
    driver.switch_to.frame('commentIframe')
    
    num = k
    names = driver.find_elements_by_css_selector('.u_cbox_nick')
    dates = driver.find_elements_by_css_selector('.u_cbox_date')
    nicks = driver.find_elements_by_css_selector('.u_cbox_id')
    reviews = driver.find_elements_by_css_selector('.u_cbox_text_wrap')
    likes = driver.find_elements_by_css_selector('.u_cbox_tool')
    
    for i in range(len(names)):
        temp = []
        temp.append(num)
        temp.append(dates[i].text)
        temp.append(names[i].text)
        temp.append(nicks[i].text)
        temp.append(reviews[i].text)
        temp.append(likes[i].text)

        temp = pd.DataFrame(data=[temp], columns=data.columns)
        data = pd.concat([data,temp])

    time.sleep(1)

    driver.close()

    print(str(num) + '화 베댓 수집 완료')

    return data

# %%
for k in range(1, 322):
    data = collector(driver, data, k)
# Out:
# 1화 베댓 수집 완료
# 2화 베댓 수집 완료
# 3화 베댓 수집 완료
# 4화 베댓 수집 완료
# 5화 베댓 수집 완료
# 6화 베댓 수집 완료
# 7화 베댓 수집 완료
# 8화 베댓 수집 완료
# 9화 베댓 수집 완료
# 10화 베댓 수집 완료
# 11화 베댓 수집 완료
# 12화 베댓 수집 완료
# 13화 베댓 수집 완료
# 14화 베댓 수집 완료
# 15화 베댓 수집 완료
# 16화 베댓 수집 완료
# 17화 베댓 수집 완료
# 18화 베댓 수집 완료
# 19화 베댓 수집 완료
# 20화 베댓 수집 완료
# 21화 베댓 수집 완료
# 22화 베댓 수집 완료
# 23화 베댓 수집 완료
# 24화 베댓 수집 완료
# 25화 베댓 수집 완료
# 26화 베댓 수집 완료
# 27화 베댓 수집 완료
# 28화 베댓 수집 완료
# 29화 베댓 수집 완료
# 30화 베댓 수집 완료
# 31화 베댓 수집 완료
# 32화 베댓 수집 완료
# 33화 베댓 수집 완료
# 34화 베댓 수집 완료
# 35화 베댓 수집 완료
# 36화 베댓 수집 완료
# 37화 베댓 수집 완료
# 38화 베댓 수집 완료
# 39화 베댓 수집 완료
# 40화 베댓 수집 완료
# 41화 베댓 수집 완료
# 42화 베댓 수집 완료
# 43화 베댓 수집 완료
# 44화 베댓 수집 완료
# 45화 베댓 수집 완료
# 46화 베댓 수집 완료
# 47화 베댓 수집 완료
# 48화 베댓 수집 완료
# 49화 베댓 수집 완료
# 50화 베댓 수집 완료
# 51화 베댓 수집 완료
# 52화 베댓 수집 완료
# 53화 베댓 수집 완료
# 54화 베댓 수집 완료
# 55화 베댓 수집 완료
# 56화 베댓 수집 완료
# 57화 베댓 수집 완료
# 58화 베댓 수집 완료
# 59화 베댓 수집 완료
# 60화 베댓 수집 완료
# 61화 베댓 수집 완료
# 62화 베댓 수집 완료
# 63화 베댓 수집 완료
# 64화 베댓 수집 완료
# 65화 베댓 수집 완료
# 66화 베댓 수집 완료
# 67화 베댓 수집 완료
# 68화 베댓 수집 완료
# 69화 베댓 수집 완료
# 70화 베댓 수집 완료
# 71화 베댓 수집 완료
# 72화 베댓 수집 완료
# 73화 베댓 수집 완료
# 74화 베댓 수집 완료
# 75화 베댓 수집 완료
# 76화 베댓 수집 완료
# 77화 베댓 수집 완료
# 78화 베댓 수집 완료
# 79화 베댓 수집 완료
# 80화 베댓 수집 완료
# 81화 베댓 수집 완료
# 82화 베댓 수집 완료
# 83화 베댓 수집 완료
# 84화 베댓 수집 완료
# 85화 베댓 수집 완료
# 86화 베댓 수집 완료
# 87화 베댓 수집 완료
# 88화 베댓 수집 완료
# 89화 베댓 수집 완료
# 90화 베댓 수집 완료
# 91화 베댓 수집 완료
# 92화 베댓 수집 완료
# 93화 베댓 수집 완료
# 94화 베댓 수집 완료
# 95화 베댓 수집 완료
# 96화 베댓 수집 완료
# 97화 베댓 수집 완료
# 98화 베댓 수집 완료
# 99화 베댓 수집 완료
# 100화 베댓 수집 완료
# 101화 베댓 수집 완료
# 102화 베댓 수집 완료
# 103화 베댓 수집 완료
# 104화 베댓 수집 완료
# 105화 베댓 수집 완료
# 106화 베댓 수집 완료
# 107화 베댓 수집 완료
# 108화 베댓 수집 완료
# 109화 베댓 수집 완료
# 110화 베댓 수집 완료
# 111화 베댓 수집 완료
# 112화 베댓 수집 완료
# 113화 베댓 수집 완료
# 114화 베댓 수집 완료
# 115화 베댓 수집 완료
# 116화 베댓 수집 완료
# 117화 베댓 수집 완료
# 118화 베댓 수집 완료
# 119화 베댓 수집 완료
# 120화 베댓 수집 완료
# 121화 베댓 수집 완료
# 122화 베댓 수집 완료
# 123화 베댓 수집 완료
# 124화 베댓 수집 완료
# 125화 베댓 수집 완료
# 126화 베댓 수집 완료
# 127화 베댓 수집 완료
# 128화 베댓 수집 완료
# 129화 베댓 수집 완료
# 130화 베댓 수집 완료
# 131화 베댓 수집 완료
# 132화 베댓 수집 완료
# 133화 베댓 수집 완료
# 134화 베댓 수집 완료
# 135화 베댓 수집 완료
# 136화 베댓 수집 완료
# 137화 베댓 수집 완료
# 138화 베댓 수집 완료
# 139화 베댓 수집 완료
# 140화 베댓 수집 완료
# 141화 베댓 수집 완료
# 142화 베댓 수집 완료
# 143화 베댓 수집 완료
# 144화 베댓 수집 완료
# 145화 베댓 수집 완료
# 146화 베댓 수집 완료
# 147화 베댓 수집 완료
# 148화 베댓 수집 완료
# 149화 베댓 수집 완료
# 150화 베댓 수집 완료
# 151화 베댓 수집 완료
# 152화 베댓 수집 완료
# 153화 베댓 수집 완료
# 154화 베댓 수집 완료
# 155화 베댓 수집 완료
# 156화 베댓 수집 완료
# 157화 베댓 수집 완료
# 158화 베댓 수집 완료
# 159화 베댓 수집 완료
# 160화 베댓 수집 완료
# 161화 베댓 수집 완료
# 162화 베댓 수집 완료
# 163화 베댓 수집 완료
# 164화 베댓 수집 완료
# 165화 베댓 수집 완료
# 166화 베댓 수집 완료
# 167화 베댓 수집 완료
# 168화 베댓 수집 완료
# 169화 베댓 수집 완료
# 170화 베댓 수집 완료
# 171화 베댓 수집 완료
# 172화 베댓 수집 완료
# 173화 베댓 수집 완료
# 174화 베댓 수집 완료
# 175화 베댓 수집 완료
# 176화 베댓 수집 완료
# 177화 베댓 수집 완료
# 178화 베댓 수집 완료
# 179화 베댓 수집 완료
# 180화 베댓 수집 완료
# 181화 베댓 수집 완료
# 182화 베댓 수집 완료
# 183화 베댓 수집 완료
# 184화 베댓 수집 완료
# 185화 베댓 수집 완료
# 186화 베댓 수집 완료
# 187화 베댓 수집 완료
# 188화 베댓 수집 완료
# 189화 베댓 수집 완료
# 190화 베댓 수집 완료
# 191화 베댓 수집 완료
# 192화 베댓 수집 완료
# 193화 베댓 수집 완료
# 194화 베댓 수집 완료
# 195화 베댓 수집 완료
# 196화 베댓 수집 완료
# 197화 베댓 수집 완료
# 198화 베댓 수집 완료
# 199화 베댓 수집 완료
# 200화 베댓 수집 완료
# 201화 베댓 수집 완료
# 202화 베댓 수집 완료
# 203화 베댓 수집 완료
# 204화 베댓 수집 완료
# 205화 베댓 수집 완료
# 206화 베댓 수집 완료
# 207화 베댓 수집 완료
# 208화 베댓 수집 완료
# 209화 베댓 수집 완료
# 210화 베댓 수집 완료
# 211화 베댓 수집 완료
# 212화 베댓 수집 완료
# 213화 베댓 수집 완료
# 214화 베댓 수집 완료
# 215화 베댓 수집 완료
# 216화 베댓 수집 완료
# 217화 베댓 수집 완료
# 218화 베댓 수집 완료
# 219화 베댓 수집 완료
# 220화 베댓 수집 완료
# 221화 베댓 수집 완료
# 222화 베댓 수집 완료
# 223화 베댓 수집 완료
# 224화 베댓 수집 완료
# 225화 베댓 수집 완료
# 226화 베댓 수집 완료
# 227화 베댓 수집 완료
# 228화 베댓 수집 완료
# 229화 베댓 수집 완료
# 230화 베댓 수집 완료
# 231화 베댓 수집 완료
# 232화 베댓 수집 완료
# 233화 베댓 수집 완료
# 234화 베댓 수집 완료
# 235화 베댓 수집 완료
# 236화 베댓 수집 완료
# 237화 베댓 수집 완료
# 238화 베댓 수집 완료
# 239화 베댓 수집 완료
# 240화 베댓 수집 완료
# 241화 베댓 수집 완료
# 242화 베댓 수집 완료
# 243화 베댓 수집 완료
# 244화 베댓 수집 완료
# 245화 베댓 수집 완료
# 246화 베댓 수집 완료
# 247화 베댓 수집 완료
# 248화 베댓 수집 완료
# 249화 베댓 수집 완료
# 250화 베댓 수집 완료
# 251화 베댓 수집 완료
# 252화 베댓 수집 완료
# 253화 베댓 수집 완료
# 254화 베댓 수집 완료
# 255화 베댓 수집 완료
# 256화 베댓 수집 완료
# 257화 베댓 수집 완료
# 258화 베댓 수집 완료
# 259화 베댓 수집 완료
# 260화 베댓 수집 완료
# 261화 베댓 수집 완료
# 262화 베댓 수집 완료
# 263화 베댓 수집 완료
# 264화 베댓 수집 완료
# 265화 베댓 수집 완료
# 266화 베댓 수집 완료
# 267화 베댓 수집 완료
# 268화 베댓 수집 완료
# 269화 베댓 수집 완료
# 270화 베댓 수집 완료
# 271화 베댓 수집 완료
# 272화 베댓 수집 완료
# 273화 베댓 수집 완료
# 274화 베댓 수집 완료
# 275화 베댓 수집 완료
# 276화 베댓 수집 완료
# 277화 베댓 수집 완료
# 278화 베댓 수집 완료
# 279화 베댓 수집 완료
# 280화 베댓 수집 완료
# 281화 베댓 수집 완료
# 282화 베댓 수집 완료
# 283화 베댓 수집 완료
# 284화 베댓 수집 완료
# 285화 베댓 수집 완료
# 286화 베댓 수집 완료
# 287화 베댓 수집 완료
# 288화 베댓 수집 완료
# 289화 베댓 수집 완료
# 290화 베댓 수집 완료
# 291화 베댓 수집 완료
# 292화 베댓 수집 완료
# 293화 베댓 수집 완료
# 294화 베댓 수집 완료
# 295화 베댓 수집 완료
# 296화 베댓 수집 완료
# 297화 베댓 수집 완료
# 298화 베댓 수집 완료
# 299화 베댓 수집 완료
# 300화 베댓 수집 완료
# 301화 베댓 수집 완료
# 302화 베댓 수집 완료
# 303화 베댓 수집 완료
# 304화 베댓 수집 완료
# 305화 베댓 수집 완료
# 306화 베댓 수집 완료
# 307화 베댓 수집 완료
# 308화 베댓 수집 완료
# 309화 베댓 수집 완료
# 310화 베댓 수집 완료
# 311화 베댓 수집 완료
# 312화 베댓 수집 완료
# 313화 베댓 수집 완료
# 314화 베댓 수집 완료
# 315화 베댓 수집 완료
# 316화 베댓 수집 완료
# 317화 베댓 수집 완료
# 318화 베댓 수집 완료
# 319화 베댓 수집 완료
# 320화 베댓 수집 완료
# 321화 베댓 수집 완료

# %%
data.head(52)
# Out:
#   회차                날짜           이름         아이디  \
# 0  1  2014-11-20 23:40          김도훈  (smy0****)
# 0  1  2014-11-20 23:22         승현무암  (hodo****)
# 0  1  2014-11-20 23:32           빠담  (tnal****)
# 0  1  2014-11-20 23:22           지원  (0004****)
# 0  1  2014-11-20 23:42               (yasi****)
# 0  1  2014-11-20 23:27               (popo****)
# 0  1  2014-11-20 23:22        아르티노그  (kang****)
# 0  1  2014-11-20 23:38           콩이  (gjdb****)
# 0  1  2014-11-20 23:22          KUA  (jung****)
# 0  1  2014-11-20 23:25               (p1k3****)
# 0  1  2014-11-20 23:22  soul kaltel  (rn30****)
# 0  1  2014-11-27 19:37     당근 천사777  (ok01****)
# 0  1  2017-04-27 23:47          문블리  (hise****)
# 0  1  2015-10-02 17:08          건토리  (gunt****)
# 0  1  2015-10-01 23:41               (hyoy****)
# 0  2  2014-11-27 23:13           왓첩  (gofo****)
# 0  2  2014-11-27 23:12          상상이  (sang****)
# 0  2  2014-11-27 23:13       Legend  (onhw****)
# 0  2  2014-11-27 23:15          세일링  (rlaw****)
# 0  2  2014-11-27 23:11          김가연  (gayu****)
# 0  BEST아 베댓 칸 다찻네 못올라가겟지만 그냥 씀.. 고객센터 지난 2주일동안 몇십...   좋아요\n16003\n싫어요\n1157
# 0  BEST그림체도진짜마음에들고 무엇보다 분량이겁나게길다는게 마음에듭니다. 앞으로도쭉 ...    좋아요\n13983\n싫어요\n804
# 0  BEST1위 축하드리고 핸드폰으로 직접 한겁니다~~ ◆◆ ♪ ◇◇◆◆ ◇◇ ◆◆ ♪...   좋아요\n10261\n싫어요\n1276
# 0                               BEST역시 외모는 모든 것을 바꾼다     좋아요\n2525\n싫어요\n157
# 0       BEST다시 생각해보니, 문제점...평생 잠을 못 자본다..둘째 꿈을 못 꾼다.       좋아요\n759\n싫어요\n36
# 0                                 BEST슬범이 떡밥 여기나오넼ㅋㅋ       좋아요\n373\n싫어요\n17
# 0  BEST분량줄일거라면서요...하... 이렇게 분량 많다고 좋아할거라고 생각하시면 크...  좋아요\n123042\n싫어요\n5009
# 0                          BEST베도때부터봐서 저여자애머리바뀐줄안다 손   좋아요\n79812\n싫어요\n2475
# 0                              BEST하늘이많이커졋내요..아물론키가요   좋아요\n61824\n싫어요\n2279
# 0                               BEST중간에 코트입은거 정준영닮았다   좋아요\n50105\n싫어요\n2195
# 0                         BEST박형석 박태준작가친구아님..???얼짱둘다   좋아요\n35453\n싫어요\n1044
# 0                                BEST숑물 문의 여기에 하지 마라   좋아요\n31130\n싫어요\n1544
# 0                                      BEST이것만기다렷다 손    좋아요\n25273\n싫어요\n910

# %%
data.to_excel('외모지상주의_데이터.xlsx')

# %%
# 혹시 몰라서, 원본은 data에 남겨둡니다.
tmp = data.copy()

# %%
# 좋아요 컬럼의 str을 \n을 기준으로 나누고, 1번째(좋아요 수)값을 저장합니다.
tmp['좋아요1'] = tmp['좋아요'].str.split('\n').str[1]
tmp['싫어요'] = tmp['좋아요'].str.split('\n').str[3]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-93-f02e1980abe9> in <module>
#       1 # 좋아요 컬럼의 str을 \n을 기준으로 나누고, 1번째(좋아요 수)값을 저장합니다.
# ----> 2 tmp['좋아요1'] = tmp['좋아요'].str.split('\n').str[1]
#       3 tmp['싫어요'] = tmp['좋아요'].str.split('\n').str[3]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
#     189         # http://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\strings.py in __init__(self, data)
#    2039
#    2040     def __init__(self, data):
# -> 2041         self._inferred_dtype = self._validate(data)
#    2042         self._is_categorical = is_categorical_dtype(data)
#    2043         self._is_string = data.dtype.name == "string"
#
# ~\anaconda3\lib\site-packages\pandas\core\strings.py in _validate(data)
#    2096
#    2097         if inferred_dtype not in allowed_types:
# -> 2098             raise AttributeError("Can only use .str accessor with string values!")
#    2099         return inferred_dtype
#    2100
#
# AttributeError: Can only use .str accessor with string values!

# %%
# 좋아요, 싫어요 컬럼명을 df.columns 함수를 이용해 변경합니다.
tmp = tmp[['날짜','이름','아이디','댓글','좋아요1','싫어요']]
tmp.columns = ['날짜','이름','아이디','댓글','좋아요','싫어요']
tmp.head(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-13c3e68b13e1> in <module>
#       1 # 좋아요, 싫어요 컬럼명을 df.columns 함수를 이용해 변경합니다.
# ----> 2 tmp = tmp[['날짜','이름','아이디','댓글','좋아요1','싫어요']]
#       3 tmp.columns = ['날짜','이름','아이디','댓글','좋아요','싫어요']
#       4 tmp.head(3)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1644             if not (self.name == "loc" and not raise_missing):
#    1645                 not_found = list(set(key) - set(ax))
# -> 1646                 raise KeyError(f"{not_found} not in index")
#    1647
#    1648             # we skip the warning on Categorical/Interval
#
# KeyError: "['좋아요1'] not in index"

# %%
tmp.to_excel('외모지상주의_데이터.xlsx')

# %% [markdown]
# # 외모지상주의 댓글 분석하기

# %%
data = pd.read_excel('외모지상주의_데이터.xlsx')

# %%
data.head()
# Out:
#                  날짜    이름         아이디  \
# 0  2014-11-20 23:40   김도훈  (smy0****)
# 1  2014-11-20 23:22  승현무암  (hodo****)
# 2  2014-11-20 23:32    빠담  (tnal****)
# 3  2014-11-20 23:22    지원  (0004****)
# 4  2014-11-20 23:42   NaN  (yasi****)
#
#                                                   댓글       좋아요     싫어요
# 0  BEST내새끼가 남한테 아무 이유 없이 맞고다니는 모습 보면 엄마는 가슴이 얼마나 아플까  121039.0  1151.0
# 1                       BEST아무생각없이 스크롤 내리다가 놀란사람 좋아요   84404.0  3196.0
# 2                             BEST어머님이 너무 안타깝다....ㅠㅠ   67914.0   833.0
# 3                                     BEST이게 드뎌 나왓구나   53391.0  1248.0
# 4                                     BEST마음아파서 못보겠다   48940.0  1024.0

# %%
data.head(3)
# Out:
#                  날짜    이름         아이디  \
# 0  2014-11-20 23:40   김도훈  (smy0****)
# 1  2014-11-20 23:22  승현무암  (hodo****)
# 2  2014-11-20 23:32    빠담  (tnal****)
#
#                                                   댓글       좋아요     싫어요
# 0  BEST내새끼가 남한테 아무 이유 없이 맞고다니는 모습 보면 엄마는 가슴이 얼마나 아플까  121039.0  1151.0
# 1                       BEST아무생각없이 스크롤 내리다가 놀란사람 좋아요   84404.0  3196.0
# 2                             BEST어머님이 너무 안타깝다....ㅠㅠ   67914.0   833.0

# %%
data.sort_values(by='좋아요', ascending=False).head(10)
# Out:
#                    날짜        이름         아이디  \
# 915  2016-01-21 23:19       아리엘  (jayo****)
# 690  2015-10-08 23:17       NaN  (mat0****)
# 285  2015-04-02 23:07        이슬  (yls3****)
# 810  2015-12-03 23:15       NaN  (junw****)
# 450  2015-06-18 23:11        다나  (sung****)
# 570  2015-08-13 23:13      외모정신  (syl3****)
# 705  2015-10-15 23:15  hr인간돌연변이  (hr_b****)
# 555  2015-08-06 23:10        찰스  (kwon****)
# 465  2015-06-25 23:08       NaN  (skm2****)
# 630  2015-09-10 23:09       소리알  (yuna****)
#
#                                          댓글       좋아요     싫어요
# 915                                BEST귀여워♡  347535.0  8498.0
# 690                 BEST재열이 이거 게이끼 슬슬 의심해야댐  239079.0  4661.0
# 285                      BESTㅋㅋㅋㅋㅋㅋㅋㅋ아재열이졸귀  233142.0   985.0
# 810                     BEST노란머리 미쳤지만 맘에 들어  224161.0  1184.0
# 450              BEST와.... 마지막 장면 보고 대박 소오름  218362.0  1122.0
# 570                    BEST재열이 1등일줄몰랐다 손들어라  213727.0  3391.0
# 705                      BEST재열이..진짜 사랑한다..  213039.0   944.0
# 555            BEST그렇게 재열이는 담배를 끊고 형석이를 얻었다  207624.0  1890.0
# 465                           BEST강남건물주 개극혐  207485.0  1190.0
# 630  BEST저 원빈이라는 지도사 아이들을 지켜줘야하는데 할때 진짜 찡했다  202918.0  1027.0
